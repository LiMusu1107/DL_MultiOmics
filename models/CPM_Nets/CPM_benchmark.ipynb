# %%
import numpy as np
import pandas as pd
from util.util import DataSet
from util.get_sn import get_sn
from util.model import CPMNets
import util.classfiy as classfiy
from sklearn.model_selection import StratifiedKFold
import os
import warnings
import time
import psutil
import math
from util.utils2 import evaluate_model
from numpy.random import shuffle
# Out:
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 禁用警告
warnings.filterwarnings('ignore')

# %%
cancer_class_mapping = {
    "AML": 3,
    "BRCA": 5,
    "COAD": 4,
    "GBM": 4,
    "KIRC": 4,
    "LIHC": 4,
    "LUSC": 4,
    "OV": 4,
    "SARC": 4,
    "SKCM": 2
}

# cancer_type = "BRCA"
# class_num = cancer_class_mapping[cancer_type]
# print(f"{cancer_type} 的类别数是: {class_num}")  # 输出: BRCA 的类别数是: 5
# num_class = class_num

# %%
# 实验配置
scenario = 1
nn_type = "CPM"
# signal_prop = "high"
# signal_level = "high"
ratio = 0.75
Normal = 0
n_folds = 4  # 四折交叉验证
# num_class = 3  # 假设有3个类别

# 初始化结果记录表
metrics = {
    "Batch": [], "Fold": [], "Accuracy": [], "F1 Macro": [], "F1 Micro": [], "F1 Weighted": [],
    "Precision Macro": [], "Precision Micro": [], "Precision Weighted": [],
    "Recall Macro": [], "Recall Micro": [], "Recall Weighted": [],
    # "AUC Macro": [], "AUC Micro": [], "AUC Weighted": [],
    # "AUPR Macro": [], "AUPR Micro": [], "AUPR Weighted": [], 
    "Cohen Kappa": [], "Training_time": [], "CPU_memory_allocated": []
}


output_dir = "/public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark"

# %%
# # 加载标签数据
# labels = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata1/scenario2/k-3/label-k3.csv", 
#                   delimiter=',').reshape(-1, 1).astype(int)

# # 如果标签从0开始，加1使其从1开始
# if min(labels)[0] == 0:
#     labels = labels + 1

# %%
# 主循环：处理每个cancer
# for batch_num in range(1, 26):
for cancer_type, class_num in cancer_class_mapping.items():
    print(f"\n=== 处理 癌症类型 {cancer_type} ===")

    class_num = cancer_class_mapping[cancer_type]
    print(f"{cancer_type} 的类别数是: {class_num}")  # 输出: BRCA 的类别数是: 5
    num_class = class_num 

    all_predictions_df = pd.DataFrame()

    # 构建数据路径
    sim_path = f"/public/home/yilab5/Master/methodology/benchmark-TCGA/{cancer_type}"
    
    try:
        # 加载omics数据
        omics1 = pd.read_csv(f"{sim_path}/exp.csv", index_col=0).T.values
        omics2 = pd.read_csv(f"{sim_path}/meth.csv",  index_col=0).T.values
        omics3 = pd.read_csv(f"{sim_path}/mirna.csv", index_col=0).T.values
        
        labels = pd.read_csv(f"{sim_path}/label.csv")
        labels = labels['label'].values.reshape(-1, 1).astype(int)
        
        # 如果标签从0开始，加1使其从1开始
        if min(labels)[0] == 0:
            labels = labels + 1

        # 创建数据字典
        n_views = 3
        X = np.zeros((1, n_views), dtype=object)
        X[0, 0] = omics1.astype(np.float32)
        X[0, 1] = omics2.astype(np.float32)
        X[0, 2] = omics3.astype(np.float32)
        
        data = {'X': X, 'gt': labels}
        
        # 准备交叉验证
        view_number = data['X'].shape[1]
        X_views = np.split(data['X'], view_number, axis=1)
        
        # 提取视图数据
        view_data = []
        for v in range(view_number):
            view_data.append(X_views[v][0][0].transpose())
        
        # 创建分层K折交叉验证
        skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=2023110400)
        
        # 对每一折进行交叉验证
        for fold, (train_index, test_index) in enumerate(skf.split(view_data[0], labels.flatten())):
            print(f"  - 处理第 {fold+1} 折")
            
            # 初始化训练集和测试集
            X_train = []
            X_test = []
            labels_train = labels[train_index]
            labels_test = labels[test_index]
            
            # 处理每个视图的数据
            for v_num in range(view_number):
                # 提取当前视图的训练集和测试集
                X_train_view = view_data[v_num][train_index]
                X_test_view = view_data[v_num][test_index]
                
                # 归一化处理
                if Normal == 1:
                    # 计算训练集的统计量
                    m = np.mean(X_train_view, axis=0)
                    mx = np.max(X_train_view, axis=0)
                    mn = np.min(X_train_view, axis=0)
                    range_val = mx - mn
                    range_val[range_val == 0] = 1  # 避免除零错误
                    
                    # 归一化训练集和测试集
                    X_train_view = (X_train_view - m) / range_val
                    X_test_view = (X_test_view - m) / range_val
                
                X_train.append(X_train_view)
                X_test.append(X_test_view)
            
            # 创建数据集对象
            traindata = DataSet(X_train, view_number, np.array(labels_train))
            testdata = DataSet(X_test, view_number, np.array(labels_test))
            trainData, testData, view_num = traindata, testdata, view_number
            
            # 准备模型参数
            outdim_size = [trainData.data[str(i)].shape[1] for i in range(view_num)]
            layer_size = [[300, outdim_size[i]] for i in range(view_num)]
            
            # 生成Sn（缺失模式矩阵）
            n_total = trainData.num_examples + testData.num_examples
            Sn = get_sn(view_num, n_total, 0)  # 缺失率为0
            Sn_train = Sn[np.arange(trainData.num_examples)]
            Sn_test = Sn[np.arange(testData.num_examples) + trainData.num_examples]
            
            # 模型参数
            lsd_dim = 128
            lamb = 1.
            # epoch = [10, 10]
            epoch = [80, 50]
            learning_rate = [0.01, 0.01]
            
            # 记录训练开始时间和内存
            start_time = time.time()
            # 获取当前进程
            process = psutil.Process(os.getpid())
            # mem_before = psutil.virtual_memory().used
            mem_before = process.memory_info().rss
            # 创建并训练模型
            model = CPMNets(view_num, trainData.num_examples, testData.num_examples, 
                            layer_size, lsd_dim, learning_rate, lamb)
            
            model.train(trainData.data, Sn_train, trainData.labels.reshape(trainData.num_examples), epoch[0])
            H_train = model.get_h_train()
            
            model.test(testData.data, Sn_test, testData.labels.reshape(testData.num_examples), epoch[1])
            H_test = model.get_h_test()
            
            # 记录训练结束时间和内存
            end_time = time.time()
            # mem_after = psutil.virtual_memory().used

            mem_after = process.memory_info().rss
            training_time = end_time - start_time
            cpu_memory_allocated = mem_after - mem_before
            
            # 预测和评估
            label_pred, label_prob = classfiy.ave(H_train, H_test, trainData.labels)
            scores = evaluate_model(testData.labels, label_pred, label_prob, num_class)
            
            # 记录结果
            metrics["Batch"].append(cancer_type)
            metrics["Fold"].append(fold+1)
            metrics["Training_time"].append(training_time)
            metrics["CPU_memory_allocated"].append(cpu_memory_allocated)
            
            # 添加评估指标
            for key in scores:
                if key in metrics:
                    metrics[key].append(scores[key])
                    # 创建当前批次和折次的预测结果 DataFrame
            fold_predictions = pd.DataFrame({
                "Batch": [cancer_type] * len(test_index),
                "Fold": [fold+1] * len(test_index),
                "True_Label": testData.labels.flatten(),
                "Pred_Label": label_pred,
            })
            
            # 添加每个类别的概率列
            for i in range(label_prob.shape[1]):
                fold_predictions[f"Prob_Class_{i}"] = np.round(label_prob[:, i], 4)
            
            # 将当前折次的预测结果添加到总 DataFrame
            all_predictions_df = pd.concat([all_predictions_df, fold_predictions], ignore_index=True)
            
            predictions_path = os.path.join(output_dir, f"cpmnets_predictions_cancers_{cancer_type}.csv")
            all_predictions_df.to_csv(predictions_path, index=False)
            print(f"预测标签结果已保存至: { predictions_path}")

            print(f"    训练时间: {training_time:.2f}秒, 内存使用: {cpu_memory_allocated/1024/1024:.2f}MB")
            print(f"    准确率: {scores['Accuracy']:.4f}")
        
    except Exception as e:
        print(f"处理 Batch {cancer_type} 时出错: {str(e)}")
        continue

# 保存结果到DataFrame
metrics_df = pd.DataFrame(metrics)

# 保存到CSV文件
# output_dir = "/public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark"
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, "cpmnets_metrics_cancers.csv")
metrics_df.to_csv(output_path, index=False)
# 保存所有预测结果到另一个 CSV



print("\n=== 所有批次和折次处理完成 ===")
print(f"结果已保存至: {output_path}")
# Out:
# === 处理 癌症类型 AML ===
# AML 的类别数是: 3
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 257260.3750, Classification Loss = 91.8826
# Epoch : 2  ===> Reconstruction Loss = 187965.1562, Classification Loss = 93.8074
# Epoch : 3  ===> Reconstruction Loss = 158957.0000, Classification Loss = 84.6659
# Epoch : 4  ===> Reconstruction Loss = 135342.5312, Classification Loss = 74.4561
# Epoch : 5  ===> Reconstruction Loss = 122198.3750, Classification Loss = 70.3037
# Epoch : 6  ===> Reconstruction Loss = 114692.0625, Classification Loss = 66.1987
# Epoch : 7  ===> Reconstruction Loss = 109460.8516, Classification Loss = 65.1733
# Epoch : 8  ===> Reconstruction Loss = 104817.4453, Classification Loss = 64.1739
# Epoch : 9  ===> Reconstruction Loss = 102120.0703, Classification Loss = 62.1630
# Epoch : 10  ===> Reconstruction Loss = 99130.2891, Classification Loss = 64.1584
# Epoch : 11  ===> Reconstruction Loss = 97066.6094, Classification Loss = 63.1517
# Epoch : 12  ===> Reconstruction Loss = 95311.1484, Classification Loss = 64.1438
# Epoch : 13  ===> Reconstruction Loss = 93702.5625, Classification Loss = 64.1416
# Epoch : 14  ===> Reconstruction Loss = 92897.2031, Classification Loss = 61.1401
# Epoch : 15  ===> Reconstruction Loss = 91983.0312, Classification Loss = 61.1408
# Epoch : 16  ===> Reconstruction Loss = 90647.1719, Classification Loss = 62.1417
# Epoch : 17  ===> Reconstruction Loss = 90403.1719, Classification Loss = 62.1428
# Epoch : 18  ===> Reconstruction Loss = 89389.1250, Classification Loss = 64.1443
# Epoch : 19  ===> Reconstruction Loss = 89086.7266, Classification Loss = 64.1460
# Epoch : 20  ===> Reconstruction Loss = 88446.1562, Classification Loss = 62.1463
# Epoch : 21  ===> Reconstruction Loss = 88226.7578, Classification Loss = 62.1458
# Epoch : 22  ===> Reconstruction Loss = 87552.0000, Classification Loss = 63.1441
# Epoch : 23  ===> Reconstruction Loss = 87666.1016, Classification Loss = 63.1423
# Epoch : 24  ===> Reconstruction Loss = 86634.7969, Classification Loss = 63.1402
# Epoch : 25  ===> Reconstruction Loss = 86875.0859, Classification Loss = 64.1385
# Epoch : 26  ===> Reconstruction Loss = 86715.6172, Classification Loss = 65.1368
# Epoch : 27  ===> Reconstruction Loss = 86127.7031, Classification Loss = 66.1354
# Epoch : 28  ===> Reconstruction Loss = 86221.5469, Classification Loss = 65.1341
# Epoch : 29  ===> Reconstruction Loss = 86157.5156, Classification Loss = 65.1331
# Epoch : 30  ===> Reconstruction Loss = 85726.0703, Classification Loss = 64.1319
# Epoch : 31  ===> Reconstruction Loss = 85777.7656, Classification Loss = 64.1307
# Epoch : 32  ===> Reconstruction Loss = 85120.5312, Classification Loss = 64.1291
# Epoch : 33  ===> Reconstruction Loss = 85558.6406, Classification Loss = 64.1274
# Epoch : 34  ===> Reconstruction Loss = 85777.0156, Classification Loss = 64.1255
# Epoch : 35  ===> Reconstruction Loss = 85081.9688, Classification Loss = 64.1237
# Epoch : 36  ===> Reconstruction Loss = 85256.0469, Classification Loss = 64.1221
# Epoch : 37  ===> Reconstruction Loss = 85329.0469, Classification Loss = 64.1207
# Epoch : 38  ===> Reconstruction Loss = 85317.2188, Classification Loss = 64.1193
# Epoch : 39  ===> Reconstruction Loss = 84956.1484, Classification Loss = 64.1180
# Epoch : 40  ===> Reconstruction Loss = 84632.0547, Classification Loss = 64.1167
# Epoch : 41  ===> Reconstruction Loss = 84718.2969, Classification Loss = 64.1153
# Epoch : 42  ===> Reconstruction Loss = 84830.2188, Classification Loss = 64.1138
# Epoch : 43  ===> Reconstruction Loss = 84776.3438, Classification Loss = 64.1120
# Epoch : 44  ===> Reconstruction Loss = 85039.7734, Classification Loss = 64.1099
# Epoch : 45  ===> Reconstruction Loss = 85018.7812, Classification Loss = 64.1076
# Epoch : 46  ===> Reconstruction Loss = 85012.6406, Classification Loss = 64.1049
# Epoch : 47  ===> Reconstruction Loss = 85105.6484, Classification Loss = 64.1021
# Epoch : 48  ===> Reconstruction Loss = 84803.2812, Classification Loss = 64.0992
# Epoch : 49  ===> Reconstruction Loss = 84820.1641, Classification Loss = 64.0963
# Epoch : 50  ===> Reconstruction Loss = 84605.5078, Classification Loss = 64.0935
# Epoch : 51  ===> Reconstruction Loss = 85079.2031, Classification Loss = 64.0907
# Epoch : 52  ===> Reconstruction Loss = 85046.3203, Classification Loss = 64.0879
# Epoch : 53  ===> Reconstruction Loss = 85034.8281, Classification Loss = 64.0850
# Epoch : 54  ===> Reconstruction Loss = 84867.8438, Classification Loss = 64.0821
# Epoch : 55  ===> Reconstruction Loss = 84978.8984, Classification Loss = 64.0792
# Epoch : 56  ===> Reconstruction Loss = 84774.3438, Classification Loss = 64.0762
# Epoch : 57  ===> Reconstruction Loss = 84845.5391, Classification Loss = 64.0732
# Epoch : 58  ===> Reconstruction Loss = 84928.3594, Classification Loss = 64.0702
# Epoch : 59  ===> Reconstruction Loss = 84768.6406, Classification Loss = 64.0671
# Epoch : 60  ===> Reconstruction Loss = 84957.6641, Classification Loss = 63.0641
# Epoch : 61  ===> Reconstruction Loss = 85067.9766, Classification Loss = 63.0610
# Epoch : 62  ===> Reconstruction Loss = 85083.2969, Classification Loss = 63.0579
# Epoch : 63  ===> Reconstruction Loss = 84985.2188, Classification Loss = 63.0548
# Epoch : 64  ===> Reconstruction Loss = 84894.1172, Classification Loss = 63.0516
# Epoch : 65  ===> Reconstruction Loss = 85058.7734, Classification Loss = 63.0484
# Epoch : 66  ===> Reconstruction Loss = 84761.3672, Classification Loss = 63.0452
# Epoch : 67  ===> Reconstruction Loss = 84578.2500, Classification Loss = 63.0419
# Epoch : 68  ===> Reconstruction Loss = 85057.7656, Classification Loss = 62.0387
# Epoch : 69  ===> Reconstruction Loss = 84937.5156, Classification Loss = 62.0355
# Epoch : 70  ===> Reconstruction Loss = 84813.6875, Classification Loss = 62.0322
# Epoch : 71  ===> Reconstruction Loss = 85224.6406, Classification Loss = 61.0291
# Epoch : 72  ===> Reconstruction Loss = 84647.5781, Classification Loss = 61.0260
# Epoch : 73  ===> Reconstruction Loss = 84513.5859, Classification Loss = 61.0229
# Epoch : 74  ===> Reconstruction Loss = 84842.5781, Classification Loss = 61.0200
# Epoch : 75  ===> Reconstruction Loss = 84990.2656, Classification Loss = 60.0172
# Epoch : 76  ===> Reconstruction Loss = 84721.7812, Classification Loss = 60.0146
# Epoch : 77  ===> Reconstruction Loss = 85045.4531, Classification Loss = 60.0124
# Epoch : 78  ===> Reconstruction Loss = 84798.3750, Classification Loss = 61.0105
# Epoch : 79  ===> Reconstruction Loss = 85139.0703, Classification Loss = 61.0093
# Epoch : 80  ===> Reconstruction Loss = 85000.8438, Classification Loss = 60.0089
# Epoch : 1  ===> Reconstruction Loss = 96100.5625
# Epoch : 2  ===> Reconstruction Loss = 72526.4922
# Epoch : 3  ===> Reconstruction Loss = 63519.0000
# Epoch : 4  ===> Reconstruction Loss = 57572.9375
# Epoch : 5  ===> Reconstruction Loss = 54680.9609
# Epoch : 6  ===> Reconstruction Loss = 52472.2227
# Epoch : 7  ===> Reconstruction Loss = 51214.5234
# Epoch : 8  ===> Reconstruction Loss = 49947.9375
# Epoch : 9  ===> Reconstruction Loss = 49530.0625
# Epoch : 10  ===> Reconstruction Loss = 49093.8398
# Epoch : 11  ===> Reconstruction Loss = 48483.2500
# Epoch : 12  ===> Reconstruction Loss = 48405.1133
# Epoch : 13  ===> Reconstruction Loss = 48050.6328
# Epoch : 14  ===> Reconstruction Loss = 48109.0703
# Epoch : 15  ===> Reconstruction Loss = 47695.8828
# Epoch : 16  ===> Reconstruction Loss = 47866.9180
# Epoch : 17  ===> Reconstruction Loss = 47686.4023
# Epoch : 18  ===> Reconstruction Loss = 47499.6289
# Epoch : 19  ===> Reconstruction Loss = 47705.2617
# Epoch : 20  ===> Reconstruction Loss = 47581.3945
# Epoch : 21  ===> Reconstruction Loss = 47539.1758
# Epoch : 22  ===> Reconstruction Loss = 47657.9336
# Epoch : 23  ===> Reconstruction Loss = 47438.6289
# Epoch : 24  ===> Reconstruction Loss = 47599.4609
# Epoch : 25  ===> Reconstruction Loss = 47377.4922
# Epoch : 26  ===> Reconstruction Loss = 47671.1172
# Epoch : 27  ===> Reconstruction Loss = 47477.5234
# Epoch : 28  ===> Reconstruction Loss = 47415.0781
# Epoch : 29  ===> Reconstruction Loss = 47527.8633
# Epoch : 30  ===> Reconstruction Loss = 47418.0664
# Epoch : 31  ===> Reconstruction Loss = 47558.6953
# Epoch : 32  ===> Reconstruction Loss = 47404.7734
# Epoch : 33  ===> Reconstruction Loss = 47393.8320
# Epoch : 34  ===> Reconstruction Loss = 47388.1875
# Epoch : 35  ===> Reconstruction Loss = 47443.6875
# Epoch : 36  ===> Reconstruction Loss = 47367.4961
# Epoch : 37  ===> Reconstruction Loss = 47455.9258
# Epoch : 38  ===> Reconstruction Loss = 47429.9023
# Epoch : 39  ===> Reconstruction Loss = 47592.3789
# Epoch : 40  ===> Reconstruction Loss = 47432.2500
# Epoch : 41  ===> Reconstruction Loss = 47380.6172
# Epoch : 42  ===> Reconstruction Loss = 47274.6523
# Epoch : 43  ===> Reconstruction Loss = 47397.5117
# Epoch : 44  ===> Reconstruction Loss = 47392.7578
# Epoch : 45  ===> Reconstruction Loss = 47603.0430
# Epoch : 46  ===> Reconstruction Loss = 47372.3320
# Epoch : 47  ===> Reconstruction Loss = 47543.3516
# Epoch : 48  ===> Reconstruction Loss = 47285.7539
# Epoch : 49  ===> Reconstruction Loss = 47556.6719
# Epoch : 50  ===> Reconstruction Loss = 47471.8047
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_AML.csv
#     训练时间: 35.51秒, 内存使用: 1055.75MB
#     准确率: 0.7143
#   - 处理第 2 折
# Epoch : 1  ===> Reconstruction Loss = 246338.5312, Classification Loss = 85.6241
# Epoch : 2  ===> Reconstruction Loss = 193359.4375, Classification Loss = 85.5800
# Epoch : 3  ===> Reconstruction Loss = 162322.9688, Classification Loss = 79.3977
# Epoch : 4  ===> Reconstruction Loss = 135978.0000, Classification Loss = 65.2135
# Epoch : 5  ===> Reconstruction Loss = 124561.3125, Classification Loss = 60.1058
# Epoch : 6  ===> Reconstruction Loss = 116259.5781, Classification Loss = 55.0325
# Epoch : 7  ===> Reconstruction Loss = 110711.6797, Classification Loss = 56.9701
# Epoch : 8  ===> Reconstruction Loss = 106125.2656, Classification Loss = 59.9343
# Epoch : 9  ===> Reconstruction Loss = 103085.8516, Classification Loss = 58.9154
# Epoch : 10  ===> Reconstruction Loss = 100274.3594, Classification Loss = 57.9123
# Epoch : 11  ===> Reconstruction Loss = 98378.8359, Classification Loss = 57.9136
# Epoch : 12  ===> Reconstruction Loss = 96614.8594, Classification Loss = 57.9180
# Epoch : 13  ===> Reconstruction Loss = 95512.2109, Classification Loss = 58.9169
# Epoch : 14  ===> Reconstruction Loss = 94287.3828, Classification Loss = 57.9170
# Epoch : 15  ===> Reconstruction Loss = 92926.3516, Classification Loss = 56.9172
# Epoch : 16  ===> Reconstruction Loss = 92346.5234, Classification Loss = 56.9178
# Epoch : 17  ===> Reconstruction Loss = 91266.6719, Classification Loss = 56.9170
# Epoch : 18  ===> Reconstruction Loss = 90415.9688, Classification Loss = 56.9182
# Epoch : 19  ===> Reconstruction Loss = 90396.6719, Classification Loss = 56.9160
# Epoch : 20  ===> Reconstruction Loss = 89462.4766, Classification Loss = 57.9139
# Epoch : 21  ===> Reconstruction Loss = 89224.5781, Classification Loss = 57.9099
# Epoch : 22  ===> Reconstruction Loss = 88917.2109, Classification Loss = 57.9068
# Epoch : 23  ===> Reconstruction Loss = 88242.0938, Classification Loss = 56.9030
# Epoch : 24  ===> Reconstruction Loss = 88038.1484, Classification Loss = 56.9002
# Epoch : 25  ===> Reconstruction Loss = 88013.4062, Classification Loss = 56.8972
# Epoch : 26  ===> Reconstruction Loss = 87593.9141, Classification Loss = 56.8942
# Epoch : 27  ===> Reconstruction Loss = 87238.2891, Classification Loss = 56.8909
# Epoch : 28  ===> Reconstruction Loss = 87404.6641, Classification Loss = 58.8877
# Epoch : 29  ===> Reconstruction Loss = 87107.5312, Classification Loss = 58.8853
# Epoch : 30  ===> Reconstruction Loss = 86899.6484, Classification Loss = 58.8824
# Epoch : 31  ===> Reconstruction Loss = 86907.3828, Classification Loss = 60.8802
# Epoch : 32  ===> Reconstruction Loss = 86840.4297, Classification Loss = 58.8780
# Epoch : 33  ===> Reconstruction Loss = 86668.8750, Classification Loss = 58.8767
# Epoch : 34  ===> Reconstruction Loss = 86621.1641, Classification Loss = 57.8759
# Epoch : 35  ===> Reconstruction Loss = 86342.2969, Classification Loss = 56.8753
# Epoch : 36  ===> Reconstruction Loss = 86187.4453, Classification Loss = 56.8750
# Epoch : 37  ===> Reconstruction Loss = 86215.7188, Classification Loss = 56.8743
# Epoch : 38  ===> Reconstruction Loss = 85808.3906, Classification Loss = 55.8734
# Epoch : 39  ===> Reconstruction Loss = 86104.8828, Classification Loss = 56.8721
# Epoch : 40  ===> Reconstruction Loss = 86213.3750, Classification Loss = 56.8703
# Epoch : 41  ===> Reconstruction Loss = 85791.2188, Classification Loss = 56.8682
# Epoch : 42  ===> Reconstruction Loss = 86166.3359, Classification Loss = 56.8658
# Epoch : 43  ===> Reconstruction Loss = 86037.8594, Classification Loss = 56.8633
# Epoch : 44  ===> Reconstruction Loss = 86062.4453, Classification Loss = 56.8608
# Epoch : 45  ===> Reconstruction Loss = 86422.0859, Classification Loss = 55.8582
# Epoch : 46  ===> Reconstruction Loss = 86147.7422, Classification Loss = 55.8557
# Epoch : 47  ===> Reconstruction Loss = 86290.0938, Classification Loss = 55.8531
# Epoch : 48  ===> Reconstruction Loss = 86163.4062, Classification Loss = 55.8505
# Epoch : 49  ===> Reconstruction Loss = 86088.4453, Classification Loss = 55.8477
# Epoch : 50  ===> Reconstruction Loss = 86122.4531, Classification Loss = 55.8449
# Epoch : 51  ===> Reconstruction Loss = 85989.9219, Classification Loss = 55.8421
# Epoch : 52  ===> Reconstruction Loss = 86222.0703, Classification Loss = 55.8392
# Epoch : 53  ===> Reconstruction Loss = 85815.0312, Classification Loss = 55.8363
# Epoch : 54  ===> Reconstruction Loss = 86207.4375, Classification Loss = 54.8333
# Epoch : 55  ===> Reconstruction Loss = 86121.8438, Classification Loss = 55.8304
# Epoch : 56  ===> Reconstruction Loss = 85824.8359, Classification Loss = 55.8275
# Epoch : 57  ===> Reconstruction Loss = 86182.2734, Classification Loss = 55.8245
# Epoch : 58  ===> Reconstruction Loss = 85931.2812, Classification Loss = 55.8214
# Epoch : 59  ===> Reconstruction Loss = 86159.9453, Classification Loss = 55.8183
# Epoch : 60  ===> Reconstruction Loss = 86206.1406, Classification Loss = 54.8152
# Epoch : 61  ===> Reconstruction Loss = 86127.3047, Classification Loss = 55.8121
# Epoch : 62  ===> Reconstruction Loss = 86181.5547, Classification Loss = 54.8089
# Epoch : 63  ===> Reconstruction Loss = 86169.2422, Classification Loss = 55.8058
# Epoch : 64  ===> Reconstruction Loss = 85912.1250, Classification Loss = 53.8026
# Epoch : 65  ===> Reconstruction Loss = 86183.1719, Classification Loss = 53.7995
# Epoch : 66  ===> Reconstruction Loss = 86189.4141, Classification Loss = 53.7964
# Epoch : 67  ===> Reconstruction Loss = 86032.3359, Classification Loss = 53.7932
# Epoch : 68  ===> Reconstruction Loss = 85599.1172, Classification Loss = 50.7901
# Epoch : 69  ===> Reconstruction Loss = 86147.2734, Classification Loss = 51.7870
# Epoch : 70  ===> Reconstruction Loss = 85519.3594, Classification Loss = 50.7839
# Epoch : 71  ===> Reconstruction Loss = 86043.5859, Classification Loss = 51.7808
# Epoch : 72  ===> Reconstruction Loss = 86141.8438, Classification Loss = 52.7777
# Epoch : 73  ===> Reconstruction Loss = 86152.7266, Classification Loss = 50.7745
# Epoch : 74  ===> Reconstruction Loss = 85960.2969, Classification Loss = 51.7714
# Epoch : 75  ===> Reconstruction Loss = 86350.4375, Classification Loss = 50.7681
# Epoch : 76  ===> Reconstruction Loss = 86086.0703, Classification Loss = 51.7649
# Epoch : 77  ===> Reconstruction Loss = 85751.2812, Classification Loss = 49.7617
# Epoch : 78  ===> Reconstruction Loss = 86056.5000, Classification Loss = 50.7586
# Epoch : 79  ===> Reconstruction Loss = 86056.9688, Classification Loss = 51.7554
# Epoch : 80  ===> Reconstruction Loss = 86270.5312, Classification Loss = 49.7522
# Epoch : 1  ===> Reconstruction Loss = 108047.3281
# Epoch : 2  ===> Reconstruction Loss = 83558.7031
# Epoch : 3  ===> Reconstruction Loss = 70042.6797
# Epoch : 4  ===> Reconstruction Loss = 63441.4453
# Epoch : 5  ===> Reconstruction Loss = 58062.8164
# Epoch : 6  ===> Reconstruction Loss = 55065.7148
# Epoch : 7  ===> Reconstruction Loss = 52763.2461
# Epoch : 8  ===> Reconstruction Loss = 50995.2461
# Epoch : 9  ===> Reconstruction Loss = 49867.8125
# Epoch : 10  ===> Reconstruction Loss = 49047.8594
# Epoch : 11  ===> Reconstruction Loss = 48572.5977
# Epoch : 12  ===> Reconstruction Loss = 47936.8125
# Epoch : 13  ===> Reconstruction Loss = 47671.7148
# Epoch : 14  ===> Reconstruction Loss = 47484.4922
# Epoch : 15  ===> Reconstruction Loss = 46902.1836
# Epoch : 16  ===> Reconstruction Loss = 46915.1641
# Epoch : 17  ===> Reconstruction Loss = 46575.3633
# Epoch : 18  ===> Reconstruction Loss = 46494.2070
# Epoch : 19  ===> Reconstruction Loss = 46463.2969
# Epoch : 20  ===> Reconstruction Loss = 46399.1758
# Epoch : 21  ===> Reconstruction Loss = 46111.1680
# Epoch : 22  ===> Reconstruction Loss = 46269.1445
# Epoch : 23  ===> Reconstruction Loss = 45883.8164
# Epoch : 24  ===> Reconstruction Loss = 46027.3359
# Epoch : 25  ===> Reconstruction Loss = 46084.1445
# Epoch : 26  ===> Reconstruction Loss = 45824.5156
# Epoch : 27  ===> Reconstruction Loss = 45857.9570
# Epoch : 28  ===> Reconstruction Loss = 45673.3789
# Epoch : 29  ===> Reconstruction Loss = 45762.7148
# Epoch : 30  ===> Reconstruction Loss = 45912.4766
# Epoch : 31  ===> Reconstruction Loss = 45689.6719
# Epoch : 32  ===> Reconstruction Loss = 45767.3789
# Epoch : 33  ===> Reconstruction Loss = 45823.5977
# Epoch : 34  ===> Reconstruction Loss = 45683.6992
# Epoch : 35  ===> Reconstruction Loss = 45457.1094
# Epoch : 36  ===> Reconstruction Loss = 45596.0117
# Epoch : 37  ===> Reconstruction Loss = 45651.7812
# Epoch : 38  ===> Reconstruction Loss = 45659.7891
# Epoch : 39  ===> Reconstruction Loss = 45651.9102
# Epoch : 40  ===> Reconstruction Loss = 45475.3906
# Epoch : 41  ===> Reconstruction Loss = 45505.1172
# Epoch : 42  ===> Reconstruction Loss = 45557.4492
# Epoch : 43  ===> Reconstruction Loss = 45545.9570
# Epoch : 44  ===> Reconstruction Loss = 45392.8555
# Epoch : 45  ===> Reconstruction Loss = 45435.2969
# Epoch : 46  ===> Reconstruction Loss = 45567.5742
# Epoch : 47  ===> Reconstruction Loss = 45386.1797
# Epoch : 48  ===> Reconstruction Loss = 45302.3477
# Epoch : 49  ===> Reconstruction Loss = 45579.0156
# Epoch : 50  ===> Reconstruction Loss = 45691.5156
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_AML.csv
#     训练时间: 36.36秒, 内存使用: 485.23MB
#     准确率: 0.8333
#   - 处理第 3 折
# Epoch : 1  ===> Reconstruction Loss = 255206.9844, Classification Loss = 73.4489
# Epoch : 2  ===> Reconstruction Loss = 182214.5469, Classification Loss = 75.3833
# Epoch : 3  ===> Reconstruction Loss = 158295.0625, Classification Loss = 66.2647
# Epoch : 4  ===> Reconstruction Loss = 136428.5000, Classification Loss = 64.1686
# Epoch : 5  ===> Reconstruction Loss = 121764.7344, Classification Loss = 64.0981
# Epoch : 6  ===> Reconstruction Loss = 114356.4609, Classification Loss = 59.0667
# Epoch : 7  ===> Reconstruction Loss = 108751.6641, Classification Loss = 58.0545
# Epoch : 8  ===> Reconstruction Loss = 104606.9141, Classification Loss = 56.0451
# Epoch : 9  ===> Reconstruction Loss = 101380.0391, Classification Loss = 55.0394
# Epoch : 10  ===> Reconstruction Loss = 98829.6406, Classification Loss = 54.0262
# Epoch : 11  ===> Reconstruction Loss = 96333.5391, Classification Loss = 52.0118
# Epoch : 12  ===> Reconstruction Loss = 94369.2109, Classification Loss = 53.0008
# Epoch : 13  ===> Reconstruction Loss = 93435.6328, Classification Loss = 52.9917
# Epoch : 14  ===> Reconstruction Loss = 92198.8984, Classification Loss = 53.9849
# Epoch : 15  ===> Reconstruction Loss = 91128.4844, Classification Loss = 53.9804
# Epoch : 16  ===> Reconstruction Loss = 90275.6953, Classification Loss = 55.9776
# Epoch : 17  ===> Reconstruction Loss = 89441.7031, Classification Loss = 56.9745
# Epoch : 18  ===> Reconstruction Loss = 88638.4297, Classification Loss = 55.9704
# Epoch : 19  ===> Reconstruction Loss = 88068.8359, Classification Loss = 55.9657
# Epoch : 20  ===> Reconstruction Loss = 87638.7344, Classification Loss = 54.9614
# Epoch : 21  ===> Reconstruction Loss = 87233.0391, Classification Loss = 54.9573
# Epoch : 22  ===> Reconstruction Loss = 86902.7031, Classification Loss = 54.9541
# Epoch : 23  ===> Reconstruction Loss = 86486.0547, Classification Loss = 54.9513
# Epoch : 24  ===> Reconstruction Loss = 86258.2812, Classification Loss = 53.9490
# Epoch : 25  ===> Reconstruction Loss = 86027.5547, Classification Loss = 53.9470
# Epoch : 26  ===> Reconstruction Loss = 86064.7422, Classification Loss = 53.9455
# Epoch : 27  ===> Reconstruction Loss = 85594.4297, Classification Loss = 53.9441
# Epoch : 28  ===> Reconstruction Loss = 85153.4141, Classification Loss = 54.9430
# Epoch : 29  ===> Reconstruction Loss = 85535.4141, Classification Loss = 54.9418
# Epoch : 30  ===> Reconstruction Loss = 85735.0859, Classification Loss = 54.9407
# Epoch : 31  ===> Reconstruction Loss = 85303.9844, Classification Loss = 54.9394
# Epoch : 32  ===> Reconstruction Loss = 85316.5156, Classification Loss = 54.9383
# Epoch : 33  ===> Reconstruction Loss = 85065.6016, Classification Loss = 54.9371
# Epoch : 34  ===> Reconstruction Loss = 84625.4141, Classification Loss = 54.9357
# Epoch : 35  ===> Reconstruction Loss = 84733.1250, Classification Loss = 54.9342
# Epoch : 36  ===> Reconstruction Loss = 84912.2578, Classification Loss = 54.9325
# Epoch : 37  ===> Reconstruction Loss = 84333.2422, Classification Loss = 54.9305
# Epoch : 38  ===> Reconstruction Loss = 84856.8047, Classification Loss = 53.9284
# Epoch : 39  ===> Reconstruction Loss = 84344.4688, Classification Loss = 53.9265
# Epoch : 40  ===> Reconstruction Loss = 84586.7344, Classification Loss = 53.9245
# Epoch : 41  ===> Reconstruction Loss = 84461.5469, Classification Loss = 53.9225
# Epoch : 42  ===> Reconstruction Loss = 84397.8125, Classification Loss = 53.9203
# Epoch : 43  ===> Reconstruction Loss = 84318.0000, Classification Loss = 53.9181
# Epoch : 44  ===> Reconstruction Loss = 84399.3828, Classification Loss = 53.9156
# Epoch : 45  ===> Reconstruction Loss = 84579.4688, Classification Loss = 53.9131
# Epoch : 46  ===> Reconstruction Loss = 84014.5000, Classification Loss = 53.9106
# Epoch : 47  ===> Reconstruction Loss = 84282.4453, Classification Loss = 53.9082
# Epoch : 48  ===> Reconstruction Loss = 84558.5703, Classification Loss = 53.9058
# Epoch : 49  ===> Reconstruction Loss = 84545.8438, Classification Loss = 52.9033
# Epoch : 50  ===> Reconstruction Loss = 84260.4844, Classification Loss = 52.9008
# Epoch : 51  ===> Reconstruction Loss = 84500.5469, Classification Loss = 52.8982
# Epoch : 52  ===> Reconstruction Loss = 84124.8672, Classification Loss = 52.8956
# Epoch : 53  ===> Reconstruction Loss = 84065.3438, Classification Loss = 52.8930
# Epoch : 54  ===> Reconstruction Loss = 84296.4141, Classification Loss = 51.8904
# Epoch : 55  ===> Reconstruction Loss = 84316.8984, Classification Loss = 50.8877
# Epoch : 56  ===> Reconstruction Loss = 84588.7969, Classification Loss = 51.8851
# Epoch : 57  ===> Reconstruction Loss = 84269.0781, Classification Loss = 51.8825
# Epoch : 58  ===> Reconstruction Loss = 84204.1172, Classification Loss = 51.8799
# Epoch : 59  ===> Reconstruction Loss = 84241.0703, Classification Loss = 52.8772
# Epoch : 60  ===> Reconstruction Loss = 84076.4766, Classification Loss = 51.8746
# Epoch : 61  ===> Reconstruction Loss = 84087.8047, Classification Loss = 51.8720
# Epoch : 62  ===> Reconstruction Loss = 84852.4922, Classification Loss = 51.8694
# Epoch : 63  ===> Reconstruction Loss = 84333.8438, Classification Loss = 51.8668
# Epoch : 64  ===> Reconstruction Loss = 84325.3281, Classification Loss = 51.8643
# Epoch : 65  ===> Reconstruction Loss = 84470.1953, Classification Loss = 51.8618
# Epoch : 66  ===> Reconstruction Loss = 84530.3438, Classification Loss = 51.8594
# Epoch : 67  ===> Reconstruction Loss = 85086.7812, Classification Loss = 51.8570
# Epoch : 68  ===> Reconstruction Loss = 84635.0312, Classification Loss = 52.8547
# Epoch : 69  ===> Reconstruction Loss = 84424.2500, Classification Loss = 53.8527
# Epoch : 70  ===> Reconstruction Loss = 84172.6484, Classification Loss = 52.8511
# Epoch : 71  ===> Reconstruction Loss = 84427.5391, Classification Loss = 53.8500
# Epoch : 72  ===> Reconstruction Loss = 84314.5234, Classification Loss = 53.8494
# Epoch : 73  ===> Reconstruction Loss = 84622.0469, Classification Loss = 53.8487
# Epoch : 74  ===> Reconstruction Loss = 84881.2734, Classification Loss = 53.8481
# Epoch : 75  ===> Reconstruction Loss = 84282.6562, Classification Loss = 55.8476
# Epoch : 76  ===> Reconstruction Loss = 84806.0781, Classification Loss = 56.8482
# Epoch : 77  ===> Reconstruction Loss = 84145.1641, Classification Loss = 56.8486
# Epoch : 78  ===> Reconstruction Loss = 84262.4922, Classification Loss = 56.8487
# Epoch : 79  ===> Reconstruction Loss = 84329.5703, Classification Loss = 54.8491
# Epoch : 80  ===> Reconstruction Loss = 84316.2031, Classification Loss = 53.8505
# Epoch : 1  ===> Reconstruction Loss = 104535.3672
# Epoch : 2  ===> Reconstruction Loss = 79417.6641
# Epoch : 3  ===> Reconstruction Loss = 68117.2812
# Epoch : 4  ===> Reconstruction Loss = 61951.0703
# Epoch : 5  ===> Reconstruction Loss = 57937.2188
# Epoch : 6  ===> Reconstruction Loss = 54969.7109
# Epoch : 7  ===> Reconstruction Loss = 52893.5820
# Epoch : 8  ===> Reconstruction Loss = 51888.1602
# Epoch : 9  ===> Reconstruction Loss = 50894.1797
# Epoch : 10  ===> Reconstruction Loss = 50266.8594
# Epoch : 11  ===> Reconstruction Loss = 49838.7422
# Epoch : 12  ===> Reconstruction Loss = 49447.8398
# Epoch : 13  ===> Reconstruction Loss = 48981.4258
# Epoch : 14  ===> Reconstruction Loss = 48722.8984
# Epoch : 15  ===> Reconstruction Loss = 48827.1289
# Epoch : 16  ===> Reconstruction Loss = 48555.3477
# Epoch : 17  ===> Reconstruction Loss = 48289.8164
# Epoch : 18  ===> Reconstruction Loss = 48139.3633
# Epoch : 19  ===> Reconstruction Loss = 48233.5430
# Epoch : 20  ===> Reconstruction Loss = 48088.1992
# Epoch : 21  ===> Reconstruction Loss = 48076.7812
# Epoch : 22  ===> Reconstruction Loss = 47875.3906
# Epoch : 23  ===> Reconstruction Loss = 47943.4961
# Epoch : 24  ===> Reconstruction Loss = 47896.0625
# Epoch : 25  ===> Reconstruction Loss = 47805.5938
# Epoch : 26  ===> Reconstruction Loss = 47592.3047
# Epoch : 27  ===> Reconstruction Loss = 47814.4023
# Epoch : 28  ===> Reconstruction Loss = 47754.6289
# Epoch : 29  ===> Reconstruction Loss = 47765.7383
# Epoch : 30  ===> Reconstruction Loss = 47611.5078
# Epoch : 31  ===> Reconstruction Loss = 47832.0273
# Epoch : 32  ===> Reconstruction Loss = 47670.6523
# Epoch : 33  ===> Reconstruction Loss = 47570.4883
# Epoch : 34  ===> Reconstruction Loss = 47620.7539
# Epoch : 35  ===> Reconstruction Loss = 47549.3398
# Epoch : 36  ===> Reconstruction Loss = 47655.4219
# Epoch : 37  ===> Reconstruction Loss = 47824.3828
# Epoch : 38  ===> Reconstruction Loss = 47687.1055
# Epoch : 39  ===> Reconstruction Loss = 47650.7578
# Epoch : 40  ===> Reconstruction Loss = 47623.3320
# Epoch : 41  ===> Reconstruction Loss = 47574.1406
# Epoch : 42  ===> Reconstruction Loss = 47770.2734
# Epoch : 43  ===> Reconstruction Loss = 47586.5586
# Epoch : 44  ===> Reconstruction Loss = 47722.7422
# Epoch : 45  ===> Reconstruction Loss = 47633.0000
# Epoch : 46  ===> Reconstruction Loss = 47570.7383
# Epoch : 47  ===> Reconstruction Loss = 47706.8750
# Epoch : 48  ===> Reconstruction Loss = 47555.1289
# Epoch : 49  ===> Reconstruction Loss = 47561.8438
# Epoch : 50  ===> Reconstruction Loss = 47657.9609
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_AML.csv
#     训练时间: 45.11秒, 内存使用: 22.31MB
#     准确率: 0.8571
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 250121.1094, Classification Loss = 89.6869
# Epoch : 2  ===> Reconstruction Loss = 186012.5156, Classification Loss = 85.5653
# Epoch : 3  ===> Reconstruction Loss = 154247.0781, Classification Loss = 80.3723
# Epoch : 4  ===> Reconstruction Loss = 129753.1719, Classification Loss = 71.1843
# Epoch : 5  ===> Reconstruction Loss = 121484.4297, Classification Loss = 65.0873
# Epoch : 6  ===> Reconstruction Loss = 113264.2812, Classification Loss = 68.0628
# Epoch : 7  ===> Reconstruction Loss = 107959.2969, Classification Loss = 67.0706
# Epoch : 8  ===> Reconstruction Loss = 104065.3594, Classification Loss = 66.0697
# Epoch : 9  ===> Reconstruction Loss = 100767.8906, Classification Loss = 65.0650
# Epoch : 10  ===> Reconstruction Loss = 98547.2109, Classification Loss = 65.0512
# Epoch : 11  ===> Reconstruction Loss = 96458.0703, Classification Loss = 65.0360
# Epoch : 12  ===> Reconstruction Loss = 94967.8359, Classification Loss = 62.0247
# Epoch : 13  ===> Reconstruction Loss = 93487.5703, Classification Loss = 61.0221
# Epoch : 14  ===> Reconstruction Loss = 92497.0469, Classification Loss = 61.0205
# Epoch : 15  ===> Reconstruction Loss = 91221.0391, Classification Loss = 61.0203
# Epoch : 16  ===> Reconstruction Loss = 90633.1328, Classification Loss = 61.0228
# Epoch : 17  ===> Reconstruction Loss = 89797.0391, Classification Loss = 62.0264
# Epoch : 18  ===> Reconstruction Loss = 89542.7031, Classification Loss = 62.0293
# Epoch : 19  ===> Reconstruction Loss = 88805.2266, Classification Loss = 62.0331
# Epoch : 20  ===> Reconstruction Loss = 87757.4219, Classification Loss = 61.0352
# Epoch : 21  ===> Reconstruction Loss = 87836.5938, Classification Loss = 61.0363
# Epoch : 22  ===> Reconstruction Loss = 87586.6797, Classification Loss = 61.0351
# Epoch : 23  ===> Reconstruction Loss = 87190.5156, Classification Loss = 61.0340
# Epoch : 24  ===> Reconstruction Loss = 86460.1641, Classification Loss = 61.0315
# Epoch : 25  ===> Reconstruction Loss = 86436.7031, Classification Loss = 61.0294
# Epoch : 26  ===> Reconstruction Loss = 86371.0859, Classification Loss = 60.0269
# Epoch : 27  ===> Reconstruction Loss = 85610.9062, Classification Loss = 61.0253
# Epoch : 28  ===> Reconstruction Loss = 85883.6172, Classification Loss = 61.0231
# Epoch : 29  ===> Reconstruction Loss = 85729.8438, Classification Loss = 62.0210
# Epoch : 30  ===> Reconstruction Loss = 85774.3047, Classification Loss = 63.0182
# Epoch : 31  ===> Reconstruction Loss = 85573.2812, Classification Loss = 63.0154
# Epoch : 32  ===> Reconstruction Loss = 85198.8984, Classification Loss = 63.0116
# Epoch : 33  ===> Reconstruction Loss = 85273.1016, Classification Loss = 64.0081
# Epoch : 34  ===> Reconstruction Loss = 85109.4922, Classification Loss = 64.0043
# Epoch : 35  ===> Reconstruction Loss = 84964.6641, Classification Loss = 62.0007
# Epoch : 36  ===> Reconstruction Loss = 84736.4141, Classification Loss = 61.9973
# Epoch : 37  ===> Reconstruction Loss = 84865.1641, Classification Loss = 61.9943
# Epoch : 38  ===> Reconstruction Loss = 84891.0859, Classification Loss = 61.9912
# Epoch : 39  ===> Reconstruction Loss = 85132.3828, Classification Loss = 61.9879
# Epoch : 40  ===> Reconstruction Loss = 84751.5312, Classification Loss = 59.9847
# Epoch : 41  ===> Reconstruction Loss = 84958.4375, Classification Loss = 60.9813
# Epoch : 42  ===> Reconstruction Loss = 84932.2109, Classification Loss = 60.9778
# Epoch : 43  ===> Reconstruction Loss = 84431.2031, Classification Loss = 58.9746
# Epoch : 44  ===> Reconstruction Loss = 84952.5234, Classification Loss = 58.9715
# Epoch : 45  ===> Reconstruction Loss = 84757.2578, Classification Loss = 59.9687
# Epoch : 46  ===> Reconstruction Loss = 84796.0703, Classification Loss = 59.9660
# Epoch : 47  ===> Reconstruction Loss = 84811.6250, Classification Loss = 58.9636
# Epoch : 48  ===> Reconstruction Loss = 84270.4766, Classification Loss = 57.9613
# Epoch : 49  ===> Reconstruction Loss = 84205.0703, Classification Loss = 57.9590
# Epoch : 50  ===> Reconstruction Loss = 84258.1641, Classification Loss = 56.9567
# Epoch : 51  ===> Reconstruction Loss = 84358.5078, Classification Loss = 56.9542
# Epoch : 52  ===> Reconstruction Loss = 84705.2969, Classification Loss = 56.9516
# Epoch : 53  ===> Reconstruction Loss = 84750.1484, Classification Loss = 56.9490
# Epoch : 54  ===> Reconstruction Loss = 84470.7891, Classification Loss = 56.9463
# Epoch : 55  ===> Reconstruction Loss = 84491.6172, Classification Loss = 54.9437
# Epoch : 56  ===> Reconstruction Loss = 84982.5547, Classification Loss = 54.9412
# Epoch : 57  ===> Reconstruction Loss = 84444.2344, Classification Loss = 54.9386
# Epoch : 58  ===> Reconstruction Loss = 84689.7891, Classification Loss = 53.9360
# Epoch : 59  ===> Reconstruction Loss = 84873.4766, Classification Loss = 53.9333
# Epoch : 60  ===> Reconstruction Loss = 84655.9297, Classification Loss = 53.9306
# Epoch : 61  ===> Reconstruction Loss = 84806.8281, Classification Loss = 53.9278
# Epoch : 62  ===> Reconstruction Loss = 84453.7422, Classification Loss = 53.9249
# Epoch : 63  ===> Reconstruction Loss = 84793.4219, Classification Loss = 53.9220
# Epoch : 64  ===> Reconstruction Loss = 84694.6484, Classification Loss = 53.9190
# Epoch : 65  ===> Reconstruction Loss = 84370.6719, Classification Loss = 52.9159
# Epoch : 66  ===> Reconstruction Loss = 84867.6719, Classification Loss = 51.9128
# Epoch : 67  ===> Reconstruction Loss = 84781.1328, Classification Loss = 51.9096
# Epoch : 68  ===> Reconstruction Loss = 84740.2188, Classification Loss = 51.9062
# Epoch : 69  ===> Reconstruction Loss = 84337.2188, Classification Loss = 53.9029
# Epoch : 70  ===> Reconstruction Loss = 84803.8828, Classification Loss = 53.8993
# Epoch : 71  ===> Reconstruction Loss = 84747.9688, Classification Loss = 53.8956
# Epoch : 72  ===> Reconstruction Loss = 84528.2266, Classification Loss = 53.8917
# Epoch : 73  ===> Reconstruction Loss = 84885.4062, Classification Loss = 53.8877
# Epoch : 74  ===> Reconstruction Loss = 84757.4219, Classification Loss = 53.8836
# Epoch : 75  ===> Reconstruction Loss = 84606.3594, Classification Loss = 54.8795
# Epoch : 76  ===> Reconstruction Loss = 84534.5391, Classification Loss = 54.8752
# Epoch : 77  ===> Reconstruction Loss = 84598.6484, Classification Loss = 54.8707
# Epoch : 78  ===> Reconstruction Loss = 84794.9766, Classification Loss = 53.8663
# Epoch : 79  ===> Reconstruction Loss = 84855.4531, Classification Loss = 54.8618
# Epoch : 80  ===> Reconstruction Loss = 84763.4844, Classification Loss = 55.8575
# Epoch : 1  ===> Reconstruction Loss = 101216.1172
# Epoch : 2  ===> Reconstruction Loss = 76992.7422
# Epoch : 3  ===> Reconstruction Loss = 67151.7266
# Epoch : 4  ===> Reconstruction Loss = 60364.7383
# Epoch : 5  ===> Reconstruction Loss = 57020.5586
# Epoch : 6  ===> Reconstruction Loss = 54416.8047
# Epoch : 7  ===> Reconstruction Loss = 52955.9258
# Epoch : 8  ===> Reconstruction Loss = 51827.2227
# Epoch : 9  ===> Reconstruction Loss = 51169.5508
# Epoch : 10  ===> Reconstruction Loss = 50492.0000
# Epoch : 11  ===> Reconstruction Loss = 50042.9258
# Epoch : 12  ===> Reconstruction Loss = 49750.2148
# Epoch : 13  ===> Reconstruction Loss = 49333.2188
# Epoch : 14  ===> Reconstruction Loss = 49158.4102
# Epoch : 15  ===> Reconstruction Loss = 49275.8867
# Epoch : 16  ===> Reconstruction Loss = 48864.8164
# Epoch : 17  ===> Reconstruction Loss = 48979.5391
# Epoch : 18  ===> Reconstruction Loss = 48747.0312
# Epoch : 19  ===> Reconstruction Loss = 48636.2188
# Epoch : 20  ===> Reconstruction Loss = 48456.8477
# Epoch : 21  ===> Reconstruction Loss = 48499.6055
# Epoch : 22  ===> Reconstruction Loss = 48647.2930
# Epoch : 23  ===> Reconstruction Loss = 48414.3203
# Epoch : 24  ===> Reconstruction Loss = 48361.9883
# Epoch : 25  ===> Reconstruction Loss = 48361.6680
# Epoch : 26  ===> Reconstruction Loss = 48331.7656
# Epoch : 27  ===> Reconstruction Loss = 48204.4297
# Epoch : 28  ===> Reconstruction Loss = 48289.3633
# Epoch : 29  ===> Reconstruction Loss = 48323.8125
# Epoch : 30  ===> Reconstruction Loss = 48337.4414
# Epoch : 31  ===> Reconstruction Loss = 48349.2070
# Epoch : 32  ===> Reconstruction Loss = 48179.4023
# Epoch : 33  ===> Reconstruction Loss = 48020.4805
# Epoch : 34  ===> Reconstruction Loss = 48304.1367
# Epoch : 35  ===> Reconstruction Loss = 48201.2695
# Epoch : 36  ===> Reconstruction Loss = 48256.1602
# Epoch : 37  ===> Reconstruction Loss = 48376.8438
# Epoch : 38  ===> Reconstruction Loss = 47884.0625
# Epoch : 39  ===> Reconstruction Loss = 48104.3789
# Epoch : 40  ===> Reconstruction Loss = 48183.1172
# Epoch : 41  ===> Reconstruction Loss = 48201.4141
# Epoch : 42  ===> Reconstruction Loss = 48050.9062
# Epoch : 43  ===> Reconstruction Loss = 48247.6445
# Epoch : 44  ===> Reconstruction Loss = 47932.9961
# Epoch : 45  ===> Reconstruction Loss = 48107.1328
# Epoch : 46  ===> Reconstruction Loss = 48127.7734
# Epoch : 47  ===> Reconstruction Loss = 48159.0117
# Epoch : 48  ===> Reconstruction Loss = 48306.8555
# Epoch : 49  ===> Reconstruction Loss = 48220.7930
# Epoch : 50  ===> Reconstruction Loss = 48075.4688
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_AML.csv
#     训练时间: 59.00秒, 内存使用: -90.27MB
#     准确率: 0.6667
#
# === 处理 癌症类型 BRCA ===
# BRCA 的类别数是: 5
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 813405.9375, Classification Loss = 365.7784
# Epoch : 2  ===> Reconstruction Loss = 605765.7500, Classification Loss = 343.0756
# Epoch : 3  ===> Reconstruction Loss = 563629.3750, Classification Loss = 311.1685
# Epoch : 4  ===> Reconstruction Loss = 516781.8438, Classification Loss = 294.0376
# Epoch : 5  ===> Reconstruction Loss = 480101.6875, Classification Loss = 254.8713
# Epoch : 6  ===> Reconstruction Loss = 460428.6562, Classification Loss = 237.8263
# Epoch : 7  ===> Reconstruction Loss = 445396.3125, Classification Loss = 227.9373
# Epoch : 8  ===> Reconstruction Loss = 432555.5625, Classification Loss = 223.0559
# Epoch : 9  ===> Reconstruction Loss = 422451.1562, Classification Loss = 221.0798
# Epoch : 10  ===> Reconstruction Loss = 414899.8125, Classification Loss = 214.0659
# Epoch : 11  ===> Reconstruction Loss = 407695.2188, Classification Loss = 207.0522
# Epoch : 12  ===> Reconstruction Loss = 401163.5938, Classification Loss = 202.0382
# Epoch : 13  ===> Reconstruction Loss = 395953.2188, Classification Loss = 203.0684
# Epoch : 14  ===> Reconstruction Loss = 392394.8438, Classification Loss = 198.1008
# Epoch : 15  ===> Reconstruction Loss = 388713.5938, Classification Loss = 199.1048
# Epoch : 16  ===> Reconstruction Loss = 385456.7500, Classification Loss = 200.0980
# Epoch : 17  ===> Reconstruction Loss = 382339.7188, Classification Loss = 201.0947
# Epoch : 18  ===> Reconstruction Loss = 380029.0000, Classification Loss = 200.0901
# Epoch : 19  ===> Reconstruction Loss = 377399.3125, Classification Loss = 199.0852
# Epoch : 20  ===> Reconstruction Loss = 375352.0938, Classification Loss = 199.0818
# Epoch : 21  ===> Reconstruction Loss = 373379.9688, Classification Loss = 199.0779
# Epoch : 22  ===> Reconstruction Loss = 372060.5938, Classification Loss = 198.0743
# Epoch : 23  ===> Reconstruction Loss = 370331.9375, Classification Loss = 197.0682
# Epoch : 24  ===> Reconstruction Loss = 368664.5625, Classification Loss = 194.0632
# Epoch : 25  ===> Reconstruction Loss = 367562.8438, Classification Loss = 192.0596
# Epoch : 26  ===> Reconstruction Loss = 366521.5625, Classification Loss = 192.0531
# Epoch : 27  ===> Reconstruction Loss = 365417.3438, Classification Loss = 191.0452
# Epoch : 28  ===> Reconstruction Loss = 364576.3750, Classification Loss = 191.0388
# Epoch : 29  ===> Reconstruction Loss = 364195.5938, Classification Loss = 191.0333
# Epoch : 30  ===> Reconstruction Loss = 362812.2188, Classification Loss = 191.0274
# Epoch : 31  ===> Reconstruction Loss = 361975.7500, Classification Loss = 189.0217
# Epoch : 32  ===> Reconstruction Loss = 361624.6875, Classification Loss = 188.0170
# Epoch : 33  ===> Reconstruction Loss = 360721.0312, Classification Loss = 189.0118
# Epoch : 34  ===> Reconstruction Loss = 359630.0312, Classification Loss = 189.0059
# Epoch : 35  ===> Reconstruction Loss = 358997.1562, Classification Loss = 188.0022
# Epoch : 36  ===> Reconstruction Loss = 358760.8438, Classification Loss = 188.9986
# Epoch : 37  ===> Reconstruction Loss = 358599.4062, Classification Loss = 188.9942
# Epoch : 38  ===> Reconstruction Loss = 357708.3438, Classification Loss = 187.9894
# Epoch : 39  ===> Reconstruction Loss = 356919.2812, Classification Loss = 189.9849
# Epoch : 40  ===> Reconstruction Loss = 357359.3125, Classification Loss = 188.9811
# Epoch : 41  ===> Reconstruction Loss = 356772.2500, Classification Loss = 188.9746
# Epoch : 42  ===> Reconstruction Loss = 355712.2500, Classification Loss = 187.9685
# Epoch : 43  ===> Reconstruction Loss = 355579.0938, Classification Loss = 187.9620
# Epoch : 44  ===> Reconstruction Loss = 355740.0000, Classification Loss = 189.9557
# Epoch : 45  ===> Reconstruction Loss = 355290.0000, Classification Loss = 188.9485
# Epoch : 46  ===> Reconstruction Loss = 355033.1875, Classification Loss = 188.9402
# Epoch : 47  ===> Reconstruction Loss = 354935.5312, Classification Loss = 188.9334
# Epoch : 48  ===> Reconstruction Loss = 354181.7188, Classification Loss = 189.9258
# Epoch : 49  ===> Reconstruction Loss = 354260.8125, Classification Loss = 191.9195
# Epoch : 50  ===> Reconstruction Loss = 354054.9375, Classification Loss = 190.9132
# Epoch : 51  ===> Reconstruction Loss = 353431.7812, Classification Loss = 190.9066
# Epoch : 52  ===> Reconstruction Loss = 352814.1562, Classification Loss = 193.9021
# Epoch : 53  ===> Reconstruction Loss = 353265.8750, Classification Loss = 195.8967
# Epoch : 54  ===> Reconstruction Loss = 353035.6250, Classification Loss = 198.8931
# Epoch : 55  ===> Reconstruction Loss = 352949.8438, Classification Loss = 199.8918
# Epoch : 56  ===> Reconstruction Loss = 351858.3438, Classification Loss = 201.8900
# Epoch : 57  ===> Reconstruction Loss = 352353.6250, Classification Loss = 201.8866
# Epoch : 58  ===> Reconstruction Loss = 352815.3125, Classification Loss = 200.8842
# Epoch : 59  ===> Reconstruction Loss = 352026.0938, Classification Loss = 200.8796
# Epoch : 60  ===> Reconstruction Loss = 351942.6875, Classification Loss = 200.8730
# Epoch : 61  ===> Reconstruction Loss = 351996.3438, Classification Loss = 199.8707
# Epoch : 62  ===> Reconstruction Loss = 351469.5625, Classification Loss = 199.8670
# Epoch : 63  ===> Reconstruction Loss = 351662.5000, Classification Loss = 199.8590
# Epoch : 64  ===> Reconstruction Loss = 351687.4688, Classification Loss = 200.8527
# Epoch : 65  ===> Reconstruction Loss = 351322.6875, Classification Loss = 199.8434
# Epoch : 66  ===> Reconstruction Loss = 351087.5000, Classification Loss = 200.8302
# Epoch : 67  ===> Reconstruction Loss = 351588.4688, Classification Loss = 199.8223
# Epoch : 68  ===> Reconstruction Loss = 351220.9688, Classification Loss = 199.8160
# Epoch : 69  ===> Reconstruction Loss = 350644.8750, Classification Loss = 197.8039
# Epoch : 70  ===> Reconstruction Loss = 351970.0938, Classification Loss = 197.7970
# Epoch : 71  ===> Reconstruction Loss = 351166.7188, Classification Loss = 196.7900
# Epoch : 72  ===> Reconstruction Loss = 350879.7188, Classification Loss = 196.7783
# Epoch : 73  ===> Reconstruction Loss = 350125.2500, Classification Loss = 195.7665
# Epoch : 74  ===> Reconstruction Loss = 350468.5938, Classification Loss = 194.7510
# Epoch : 75  ===> Reconstruction Loss = 350983.1875, Classification Loss = 192.7333
# Epoch : 76  ===> Reconstruction Loss = 350682.4688, Classification Loss = 190.7208
# Epoch : 77  ===> Reconstruction Loss = 349804.8125, Classification Loss = 191.7084
# Epoch : 78  ===> Reconstruction Loss = 350062.5312, Classification Loss = 189.6932
# Epoch : 79  ===> Reconstruction Loss = 349999.0000, Classification Loss = 191.6815
# Epoch : 80  ===> Reconstruction Loss = 350407.5000, Classification Loss = 190.6670
# Epoch : 1  ===> Reconstruction Loss = 197900.3125
# Epoch : 2  ===> Reconstruction Loss = 169702.4531
# Epoch : 3  ===> Reconstruction Loss = 156183.4375
# Epoch : 4  ===> Reconstruction Loss = 148887.5938
# Epoch : 5  ===> Reconstruction Loss = 145270.5156
# Epoch : 6  ===> Reconstruction Loss = 142685.8438
# Epoch : 7  ===> Reconstruction Loss = 141240.0625
# Epoch : 8  ===> Reconstruction Loss = 140276.8750
# Epoch : 9  ===> Reconstruction Loss = 139764.7656
# Epoch : 10  ===> Reconstruction Loss = 139468.9062
# Epoch : 11  ===> Reconstruction Loss = 139254.9688
# Epoch : 12  ===> Reconstruction Loss = 139039.2344
# Epoch : 13  ===> Reconstruction Loss = 139048.0000
# Epoch : 14  ===> Reconstruction Loss = 139144.1875
# Epoch : 15  ===> Reconstruction Loss = 138869.3750
# Epoch : 16  ===> Reconstruction Loss = 138723.5156
# Epoch : 17  ===> Reconstruction Loss = 138965.5156
# Epoch : 18  ===> Reconstruction Loss = 138557.6094
# Epoch : 19  ===> Reconstruction Loss = 138913.2031
# Epoch : 20  ===> Reconstruction Loss = 138545.9219
# Epoch : 21  ===> Reconstruction Loss = 138409.5156
# Epoch : 22  ===> Reconstruction Loss = 138333.5938
# Epoch : 23  ===> Reconstruction Loss = 138575.9062
# Epoch : 24  ===> Reconstruction Loss = 138724.0156
# Epoch : 25  ===> Reconstruction Loss = 138541.0625
# Epoch : 26  ===> Reconstruction Loss = 138865.2969
# Epoch : 27  ===> Reconstruction Loss = 138503.7969
# Epoch : 28  ===> Reconstruction Loss = 138853.4844
# Epoch : 29  ===> Reconstruction Loss = 139115.2656
# Epoch : 30  ===> Reconstruction Loss = 138619.6562
# Epoch : 31  ===> Reconstruction Loss = 138801.0781
# Epoch : 32  ===> Reconstruction Loss = 138758.6562
# Epoch : 33  ===> Reconstruction Loss = 138774.6094
# Epoch : 34  ===> Reconstruction Loss = 138713.9531
# Epoch : 35  ===> Reconstruction Loss = 138453.6094
# Epoch : 36  ===> Reconstruction Loss = 139044.1250
# Epoch : 37  ===> Reconstruction Loss = 139165.2344
# Epoch : 38  ===> Reconstruction Loss = 138762.4531
# Epoch : 39  ===> Reconstruction Loss = 138720.0781
# Epoch : 40  ===> Reconstruction Loss = 138740.5469
# Epoch : 41  ===> Reconstruction Loss = 138630.1406
# Epoch : 42  ===> Reconstruction Loss = 138997.5469
# Epoch : 43  ===> Reconstruction Loss = 138628.8906
# Epoch : 44  ===> Reconstruction Loss = 138916.5156
# Epoch : 45  ===> Reconstruction Loss = 138927.3594
# Epoch : 46  ===> Reconstruction Loss = 138868.3125
# Epoch : 47  ===> Reconstruction Loss = 138838.5625
# Epoch : 48  ===> Reconstruction Loss = 138805.8281
# Epoch : 49  ===> Reconstruction Loss = 138885.5000
# Epoch : 50  ===> Reconstruction Loss = 138811.7188
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_BRCA.csv
#     训练时间: 138.75秒, 内存使用: 84.28MB
#     准确率: 0.6169
#   - 处理第 2 折
# Epoch : 1  ===> Reconstruction Loss = 821981.9375, Classification Loss = 366.0224
# Epoch : 2  ===> Reconstruction Loss = 602995.2500, Classification Loss = 346.3081
# Epoch : 3  ===> Reconstruction Loss = 569735.1250, Classification Loss = 329.8898
# Epoch : 4  ===> Reconstruction Loss = 516230.5312, Classification Loss = 311.0941
# Epoch : 5  ===> Reconstruction Loss = 480329.7500, Classification Loss = 284.0275
# Epoch : 6  ===> Reconstruction Loss = 462933.9375, Classification Loss = 265.9837
# Epoch : 7  ===> Reconstruction Loss = 447926.7500, Classification Loss = 259.0657
# Epoch : 8  ===> Reconstruction Loss = 434107.8125, Classification Loss = 250.1918
# Epoch : 9  ===> Reconstruction Loss = 424910.7188, Classification Loss = 243.3081
# Epoch : 10  ===> Reconstruction Loss = 416356.1250, Classification Loss = 235.2877
# Epoch : 11  ===> Reconstruction Loss = 409573.0000, Classification Loss = 227.3056
# Epoch : 12  ===> Reconstruction Loss = 403240.0938, Classification Loss = 226.3655
# Epoch : 13  ===> Reconstruction Loss = 398408.1562, Classification Loss = 226.3849
# Epoch : 14  ===> Reconstruction Loss = 394357.6562, Classification Loss = 224.3601
# Epoch : 15  ===> Reconstruction Loss = 390227.5312, Classification Loss = 218.3423
# Epoch : 16  ===> Reconstruction Loss = 387132.6250, Classification Loss = 219.3381
# Epoch : 17  ===> Reconstruction Loss = 383570.7812, Classification Loss = 217.3263
# Epoch : 18  ===> Reconstruction Loss = 381121.9688, Classification Loss = 217.3121
# ...
# Epoch : 37  ===> Reconstruction Loss = 270250.3750, Classification Loss = 149.2040
# Epoch : 38  ===> Reconstruction Loss = 269829.1875, Classification Loss = 149.2012
# Epoch : 39  ===> Reconstruction Loss = 269743.3438, Classification Loss = 149.1980
# Epoch : 40  ===> Reconstruction Loss = 269266.0938, Classification Loss = 147.1949
# Epoch : 41  ===> Reconstruction Loss = 269024.9062, Classification Loss = 145.1918
# Epoch : 42  ===> Reconstruction Loss = 268377.5312, Classification Loss = 145.1884
# Epoch : 43  ===> Reconstruction Loss = 268432.4688, Classification Loss = 144.1850
# Epoch : 44  ===> Reconstruction Loss = 268428.7812, Classification Loss = 143.1805
# Epoch : 45  ===> Reconstruction Loss = 268193.5938, Classification Loss = 143.1766
# Epoch : 46  ===> Reconstruction Loss = 268265.0000, Classification Loss = 142.1740
# Epoch : 47  ===> Reconstruction Loss = 267338.1250, Classification Loss = 141.1717
# Epoch : 48  ===> Reconstruction Loss = 267586.0625, Classification Loss = 141.1681
# Epoch : 49  ===> Reconstruction Loss = 267667.3750, Classification Loss = 142.1619
# Epoch : 50  ===> Reconstruction Loss = 267256.2188, Classification Loss = 142.1558
# Epoch : 51  ===> Reconstruction Loss = 267636.5625, Classification Loss = 142.1489
# Epoch : 52  ===> Reconstruction Loss = 267114.3438, Classification Loss = 139.1433
# Epoch : 53  ===> Reconstruction Loss = 267220.7812, Classification Loss = 139.1351
# Epoch : 54  ===> Reconstruction Loss = 266767.3750, Classification Loss = 141.1255
# Epoch : 55  ===> Reconstruction Loss = 266572.1562, Classification Loss = 142.1171
# Epoch : 56  ===> Reconstruction Loss = 266508.5000, Classification Loss = 143.1086
# Epoch : 57  ===> Reconstruction Loss = 266365.0938, Classification Loss = 146.0998
# Epoch : 58  ===> Reconstruction Loss = 266476.5312, Classification Loss = 145.0900
# Epoch : 59  ===> Reconstruction Loss = 266189.9688, Classification Loss = 142.0798
# Epoch : 60  ===> Reconstruction Loss = 266487.0000, Classification Loss = 145.0694
# Epoch : 61  ===> Reconstruction Loss = 265818.9688, Classification Loss = 143.0587
# Epoch : 62  ===> Reconstruction Loss = 266410.7500, Classification Loss = 144.0474
# Epoch : 63  ===> Reconstruction Loss = 266102.0000, Classification Loss = 144.0355
# Epoch : 64  ===> Reconstruction Loss = 266734.7812, Classification Loss = 142.0240
# Epoch : 65  ===> Reconstruction Loss = 265778.1875, Classification Loss = 143.0127
# Epoch : 66  ===> Reconstruction Loss = 266617.4062, Classification Loss = 142.0019
# Epoch : 67  ===> Reconstruction Loss = 265728.0938, Classification Loss = 139.9904
# Epoch : 68  ===> Reconstruction Loss = 265859.7812, Classification Loss = 139.9783
# Epoch : 69  ===> Reconstruction Loss = 265785.4688, Classification Loss = 141.9689
# Epoch : 70  ===> Reconstruction Loss = 265791.6250, Classification Loss = 142.9609
# Epoch : 71  ===> Reconstruction Loss = 265857.4062, Classification Loss = 140.9557
# Epoch : 72  ===> Reconstruction Loss = 265049.2812, Classification Loss = 140.9542
# Epoch : 73  ===> Reconstruction Loss = 265433.0625, Classification Loss = 138.9596
# Epoch : 74  ===> Reconstruction Loss = 265600.5000, Classification Loss = 139.9727
# Epoch : 75  ===> Reconstruction Loss = 265370.0312, Classification Loss = 143.9983
# Epoch : 76  ===> Reconstruction Loss = 265910.3750, Classification Loss = 143.0398
# Epoch : 77  ===> Reconstruction Loss = 265312.6562, Classification Loss = 142.0957
# Epoch : 78  ===> Reconstruction Loss = 265615.8750, Classification Loss = 138.1528
# Epoch : 79  ===> Reconstruction Loss = 264822.9062, Classification Loss = 134.1985
# Epoch : 80  ===> Reconstruction Loss = 265264.8750, Classification Loss = 134.2295
# Epoch : 1  ===> Reconstruction Loss = 172038.5781
# Epoch : 2  ===> Reconstruction Loss = 141665.7812
# Epoch : 3  ===> Reconstruction Loss = 129110.7422
# Epoch : 4  ===> Reconstruction Loss = 122582.4688
# Epoch : 5  ===> Reconstruction Loss = 119143.7500
# Epoch : 6  ===> Reconstruction Loss = 116277.4453
# Epoch : 7  ===> Reconstruction Loss = 115590.8594
# Epoch : 8  ===> Reconstruction Loss = 114583.0391
# Epoch : 9  ===> Reconstruction Loss = 114168.1562
# Epoch : 10  ===> Reconstruction Loss = 113604.3281
# Epoch : 11  ===> Reconstruction Loss = 113607.2344
# Epoch : 12  ===> Reconstruction Loss = 113423.8203
# Epoch : 13  ===> Reconstruction Loss = 113270.9688
# Epoch : 14  ===> Reconstruction Loss = 113229.3750
# Epoch : 15  ===> Reconstruction Loss = 113196.1250
# Epoch : 16  ===> Reconstruction Loss = 113180.8125
# Epoch : 17  ===> Reconstruction Loss = 113124.3047
# Epoch : 18  ===> Reconstruction Loss = 112980.5000
# Epoch : 19  ===> Reconstruction Loss = 113146.8281
# Epoch : 20  ===> Reconstruction Loss = 113110.3594
# Epoch : 21  ===> Reconstruction Loss = 113099.5156
# Epoch : 22  ===> Reconstruction Loss = 113136.5078
# Epoch : 23  ===> Reconstruction Loss = 112995.7422
# Epoch : 24  ===> Reconstruction Loss = 113372.2188
# Epoch : 25  ===> Reconstruction Loss = 112834.1719
# Epoch : 26  ===> Reconstruction Loss = 113019.6797
# Epoch : 27  ===> Reconstruction Loss = 113207.2344
# Epoch : 28  ===> Reconstruction Loss = 112940.0312
# Epoch : 29  ===> Reconstruction Loss = 113208.6797
# Epoch : 30  ===> Reconstruction Loss = 113136.9531
# Epoch : 31  ===> Reconstruction Loss = 113131.9688
# Epoch : 32  ===> Reconstruction Loss = 113287.2812
# Epoch : 33  ===> Reconstruction Loss = 112989.8203
# Epoch : 34  ===> Reconstruction Loss = 112953.8125
# Epoch : 35  ===> Reconstruction Loss = 112984.4609
# Epoch : 36  ===> Reconstruction Loss = 113280.2734
# Epoch : 37  ===> Reconstruction Loss = 113111.8125
# Epoch : 38  ===> Reconstruction Loss = 113059.2109
# Epoch : 39  ===> Reconstruction Loss = 113143.2969
# Epoch : 40  ===> Reconstruction Loss = 112961.9062
# Epoch : 41  ===> Reconstruction Loss = 113098.1016
# Epoch : 42  ===> Reconstruction Loss = 113456.4375
# Epoch : 43  ===> Reconstruction Loss = 113185.5469
# Epoch : 44  ===> Reconstruction Loss = 112971.2812
# Epoch : 45  ===> Reconstruction Loss = 113395.6094
# Epoch : 46  ===> Reconstruction Loss = 113362.9141
# Epoch : 47  ===> Reconstruction Loss = 113080.6406
# Epoch : 48  ===> Reconstruction Loss = 113231.6641
# Epoch : 49  ===> Reconstruction Loss = 113151.6562
# Epoch : 50  ===> Reconstruction Loss = 112968.6641
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_SKCM.csv
#     训练时间: 87.20秒, 内存使用: 253.09MB
#     准确率: 0.6396
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 639026.6250, Classification Loss = 155.6749
# Epoch : 2  ===> Reconstruction Loss = 491888.2812, Classification Loss = 144.7925
# Epoch : 3  ===> Reconstruction Loss = 446350.9062, Classification Loss = 142.9309
# Epoch : 4  ===> Reconstruction Loss = 406971.4062, Classification Loss = 138.9791
# Epoch : 5  ===> Reconstruction Loss = 378228.9062, Classification Loss = 137.0326
# Epoch : 6  ===> Reconstruction Loss = 360862.8438, Classification Loss = 135.1023
# Epoch : 7  ===> Reconstruction Loss = 347172.3125, Classification Loss = 136.1417
# Epoch : 8  ===> Reconstruction Loss = 335571.1250, Classification Loss = 139.1767
# Epoch : 9  ===> Reconstruction Loss = 327603.4375, Classification Loss = 141.2016
# Epoch : 10  ===> Reconstruction Loss = 319462.7500, Classification Loss = 143.2163
# Epoch : 11  ===> Reconstruction Loss = 313518.9062, Classification Loss = 139.2397
# Epoch : 12  ===> Reconstruction Loss = 308558.0312, Classification Loss = 140.2648
# Epoch : 13  ===> Reconstruction Loss = 303838.2812, Classification Loss = 138.2794
# Epoch : 14  ===> Reconstruction Loss = 299912.5000, Classification Loss = 136.2882
# Epoch : 15  ===> Reconstruction Loss = 297220.2188, Classification Loss = 135.2933
# Epoch : 16  ===> Reconstruction Loss = 293457.3438, Classification Loss = 136.2942
# Epoch : 17  ===> Reconstruction Loss = 291107.3750, Classification Loss = 135.2933
# Epoch : 18  ===> Reconstruction Loss = 289418.3750, Classification Loss = 134.2947
# Epoch : 19  ===> Reconstruction Loss = 287398.5000, Classification Loss = 132.2954
# Epoch : 20  ===> Reconstruction Loss = 286027.8750, Classification Loss = 132.2941
# Epoch : 21  ===> Reconstruction Loss = 284012.2500, Classification Loss = 132.2907
# Epoch : 22  ===> Reconstruction Loss = 283261.2500, Classification Loss = 133.2881
# Epoch : 23  ===> Reconstruction Loss = 281992.5000, Classification Loss = 137.2869
# Epoch : 24  ===> Reconstruction Loss = 280981.9375, Classification Loss = 134.2857
# Epoch : 25  ===> Reconstruction Loss = 279987.7500, Classification Loss = 134.2837
# Epoch : 26  ===> Reconstruction Loss = 279551.2188, Classification Loss = 133.2821
# Epoch : 27  ===> Reconstruction Loss = 278412.1875, Classification Loss = 132.2800
# Epoch : 28  ===> Reconstruction Loss = 277751.5000, Classification Loss = 132.2770
# Epoch : 29  ===> Reconstruction Loss = 277021.8438, Classification Loss = 133.2752
# Epoch : 30  ===> Reconstruction Loss = 277069.0625, Classification Loss = 133.2746
# Epoch : 31  ===> Reconstruction Loss = 276346.8438, Classification Loss = 132.2734
# Epoch : 32  ===> Reconstruction Loss = 275457.5000, Classification Loss = 130.2724
# Epoch : 33  ===> Reconstruction Loss = 275066.8750, Classification Loss = 131.2726
# Epoch : 34  ===> Reconstruction Loss = 274675.5625, Classification Loss = 128.2730
# Epoch : 35  ===> Reconstruction Loss = 273580.3438, Classification Loss = 125.2740
# Epoch : 36  ===> Reconstruction Loss = 273236.4688, Classification Loss = 125.2746
# Epoch : 37  ===> Reconstruction Loss = 273847.5312, Classification Loss = 125.2750
# Epoch : 38  ===> Reconstruction Loss = 273274.9688, Classification Loss = 126.2751
# Epoch : 39  ===> Reconstruction Loss = 272888.4375, Classification Loss = 127.2754
# Epoch : 40  ===> Reconstruction Loss = 272467.6562, Classification Loss = 127.2735
# Epoch : 41  ===> Reconstruction Loss = 272210.4375, Classification Loss = 128.2718
# Epoch : 42  ===> Reconstruction Loss = 272182.2500, Classification Loss = 129.2712
# Epoch : 43  ===> Reconstruction Loss = 271857.0938, Classification Loss = 131.2692
# Epoch : 44  ===> Reconstruction Loss = 271402.5625, Classification Loss = 131.2670
# Epoch : 45  ===> Reconstruction Loss = 270575.0000, Classification Loss = 130.2652
# Epoch : 46  ===> Reconstruction Loss = 271423.4062, Classification Loss = 130.2641
# Epoch : 47  ===> Reconstruction Loss = 271073.4062, Classification Loss = 132.2618
# Epoch : 48  ===> Reconstruction Loss = 270269.5938, Classification Loss = 133.2605
# Epoch : 49  ===> Reconstruction Loss = 270498.6875, Classification Loss = 133.2587
# Epoch : 50  ===> Reconstruction Loss = 270568.6875, Classification Loss = 134.2558
# Epoch : 51  ===> Reconstruction Loss = 270259.0938, Classification Loss = 135.2522
# Epoch : 52  ===> Reconstruction Loss = 269793.2500, Classification Loss = 136.2478
# Epoch : 53  ===> Reconstruction Loss = 269923.1562, Classification Loss = 135.2437
# Epoch : 54  ===> Reconstruction Loss = 269562.2812, Classification Loss = 135.2390
# Epoch : 55  ===> Reconstruction Loss = 269514.1562, Classification Loss = 135.2344
# Epoch : 56  ===> Reconstruction Loss = 270226.5625, Classification Loss = 137.2294
# Epoch : 57  ===> Reconstruction Loss = 269365.2812, Classification Loss = 135.2246
# Epoch : 58  ===> Reconstruction Loss = 269440.3750, Classification Loss = 134.2193
# Epoch : 59  ===> Reconstruction Loss = 269187.7188, Classification Loss = 134.2145
# Epoch : 60  ===> Reconstruction Loss = 269207.2812, Classification Loss = 133.2095
# Epoch : 61  ===> Reconstruction Loss = 269174.5312, Classification Loss = 133.2061
# Epoch : 62  ===> Reconstruction Loss = 269142.8750, Classification Loss = 132.2037
# Epoch : 63  ===> Reconstruction Loss = 268878.8125, Classification Loss = 135.2037
# Epoch : 64  ===> Reconstruction Loss = 268968.6562, Classification Loss = 136.2083
# Epoch : 65  ===> Reconstruction Loss = 268847.7500, Classification Loss = 136.2176
# Epoch : 66  ===> Reconstruction Loss = 269593.8750, Classification Loss = 138.2325
# Epoch : 67  ===> Reconstruction Loss = 268601.6250, Classification Loss = 139.2595
# Epoch : 68  ===> Reconstruction Loss = 268901.7188, Classification Loss = 141.3049
# Epoch : 69  ===> Reconstruction Loss = 268530.5312, Classification Loss = 143.3707
# Epoch : 70  ===> Reconstruction Loss = 268666.2188, Classification Loss = 143.4731
# Epoch : 71  ===> Reconstruction Loss = 268582.2188, Classification Loss = 138.6143
# Epoch : 72  ===> Reconstruction Loss = 268782.4688, Classification Loss = 134.7844
# Epoch : 73  ===> Reconstruction Loss = 268124.2500, Classification Loss = 134.9569
# Epoch : 74  ===> Reconstruction Loss = 268243.7500, Classification Loss = 137.1044
# Epoch : 75  ===> Reconstruction Loss = 269576.4688, Classification Loss = 136.1309
# Epoch : 76  ===> Reconstruction Loss = 268966.1875, Classification Loss = 133.0317
# Epoch : 77  ===> Reconstruction Loss = 268084.5625, Classification Loss = 133.9591
# Epoch : 78  ===> Reconstruction Loss = 268081.9062, Classification Loss = 134.9423
# Epoch : 79  ===> Reconstruction Loss = 268780.5625, Classification Loss = 132.9194
# Epoch : 80  ===> Reconstruction Loss = 267949.5312, Classification Loss = 132.8903
# Epoch : 1  ===> Reconstruction Loss = 169358.2656
# Epoch : 2  ===> Reconstruction Loss = 138757.5000
# Epoch : 3  ===> Reconstruction Loss = 125749.3594
# Epoch : 4  ===> Reconstruction Loss = 119726.6484
# Epoch : 5  ===> Reconstruction Loss = 116034.2344
# Epoch : 6  ===> Reconstruction Loss = 113932.7188
# Epoch : 7  ===> Reconstruction Loss = 112327.7891
# Epoch : 8  ===> Reconstruction Loss = 111523.6797
# Epoch : 9  ===> Reconstruction Loss = 111224.4219
# Epoch : 10  ===> Reconstruction Loss = 110424.1641
# Epoch : 11  ===> Reconstruction Loss = 110398.7578
# Epoch : 12  ===> Reconstruction Loss = 110356.3828
# Epoch : 13  ===> Reconstruction Loss = 110169.1953
# Epoch : 14  ===> Reconstruction Loss = 110361.5078
# Epoch : 15  ===> Reconstruction Loss = 110618.0703
# Epoch : 16  ===> Reconstruction Loss = 110080.5547
# Epoch : 17  ===> Reconstruction Loss = 110505.0703
# Epoch : 18  ===> Reconstruction Loss = 110275.8672
# Epoch : 19  ===> Reconstruction Loss = 109972.7266
# Epoch : 20  ===> Reconstruction Loss = 110111.9766
# Epoch : 21  ===> Reconstruction Loss = 110038.5156
# Epoch : 22  ===> Reconstruction Loss = 110245.4688
# Epoch : 23  ===> Reconstruction Loss = 110167.6562
# Epoch : 24  ===> Reconstruction Loss = 110043.2891
# Epoch : 25  ===> Reconstruction Loss = 110498.9297
# Epoch : 26  ===> Reconstruction Loss = 109919.9219
# Epoch : 27  ===> Reconstruction Loss = 109854.8359
# Epoch : 28  ===> Reconstruction Loss = 110052.3281
# Epoch : 29  ===> Reconstruction Loss = 110248.4375
# Epoch : 30  ===> Reconstruction Loss = 110501.0312
# Epoch : 31  ===> Reconstruction Loss = 110005.7344
# Epoch : 32  ===> Reconstruction Loss = 110097.5859
# Epoch : 33  ===> Reconstruction Loss = 110070.9062
# Epoch : 34  ===> Reconstruction Loss = 109899.9375
# Epoch : 35  ===> Reconstruction Loss = 109855.9844
# Epoch : 36  ===> Reconstruction Loss = 109960.7578
# Epoch : 37  ===> Reconstruction Loss = 110123.5859
# Epoch : 38  ===> Reconstruction Loss = 110135.9219
# Epoch : 39  ===> Reconstruction Loss = 110207.1016
# Epoch : 40  ===> Reconstruction Loss = 110227.7422
# Epoch : 41  ===> Reconstruction Loss = 110056.2344
# Epoch : 42  ===> Reconstruction Loss = 110102.6953
# Epoch : 43  ===> Reconstruction Loss = 110432.8672
# Epoch : 44  ===> Reconstruction Loss = 110092.1016
# Epoch : 45  ===> Reconstruction Loss = 110562.6016
# Epoch : 46  ===> Reconstruction Loss = 110162.0859
# Epoch : 47  ===> Reconstruction Loss = 109955.3984
# Epoch : 48  ===> Reconstruction Loss = 109908.5000
# Epoch : 49  ===> Reconstruction Loss = 110452.1406
# Epoch : 50  ===> Reconstruction Loss = 110228.8828
# 预测标签结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_predictions_cancers_SKCM.csv
#     训练时间: 89.23秒, 内存使用: 161.44MB
#     准确率: 0.5455
#
# === 所有批次和折次处理完成 ===
# 结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-benchmark/cpmnets_metrics_cancers.csv
