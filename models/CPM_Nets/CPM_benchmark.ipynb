# %%
import numpy as np
import pandas as pd
from util.util import DataSet
from util.get_sn import get_sn
from util.model import CPMNets
import util.classfiy as classfiy
from sklearn.model_selection import StratifiedKFold
import os
import warnings
import time
import psutil
import math
from util.utils2 import evaluate_model
from numpy.random import shuffle
# Out:
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 禁用警告
warnings.filterwarnings('ignore')

# %%
# 实验配置
scenario = 2
signal_prop = "high"
signal_level = "mid"
ratio = 0.75
Normal = 0
n_folds = 4  # 四折交叉验证
num_class = 3  # 假设有3个类别

# 初始化结果记录表
metrics = {
    "Batch": [], "Fold": [], "Accuracy": [], "F1 Macro": [], "F1 Micro": [], "F1 Weighted": [],
    "Precision Macro": [], "Precision Micro": [], "Precision Weighted": [],
    "Recall Macro": [], "Recall Micro": [], "Recall Weighted": [],
    # "AUC Macro": [], "AUC Micro": [], "AUC Weighted": [],
    # "AUPR Macro": [], "AUPR Micro": [], "AUPR Weighted": [], 
    "Cohen Kappa": [], "Training_time": [], "CPU_memory_allocated": []
}
all_predictions_df = pd.DataFrame()

# %%
# 加载标签数据
labels = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata1/scenario2/k-3/label-k3.csv", 
                  delimiter=',').reshape(-1, 1).astype(int)

# 如果标签从0开始，加1使其从1开始
if min(labels)[0] == 0:
    labels = labels + 1

# %%
# 主循环：处理每个batch (1-25)
for batch_num in range(1, 26):
    print(f"\n=== 处理 Batch {batch_num} ===")
    
    # 构建数据路径
    sim_path = f"/public/home/yilab5/Master/methodology/simdata1/scenario2/k-3/prop-high/level-mid/sim{batch_num}"
    
    try:
        # 加载omics数据
        omics1 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-mrna.csv", delimiter=',').T
        omics2 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-meth.csv", delimiter=',').T
        omics3 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-mutate.csv", delimiter=',').T
        
        # 创建数据字典
        n_views = 3
        X = np.zeros((1, n_views), dtype=object)
        X[0, 0] = omics1.astype(np.float32)
        X[0, 1] = omics2.astype(np.float32)
        X[0, 2] = omics3.astype(np.float32)
        
        data = {'X': X, 'gt': labels}
        
        # 准备交叉验证
        view_number = data['X'].shape[1]
        X_views = np.split(data['X'], view_number, axis=1)
        
        # 提取视图数据
        view_data = []
        for v in range(view_number):
            view_data.append(X_views[v][0][0].transpose())
        
        # 创建分层K折交叉验证
        skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
        
        # 对每一折进行交叉验证
        for fold, (train_index, test_index) in enumerate(skf.split(view_data[0], labels.flatten())):
            print(f"  - 处理第 {fold+1} 折")
            
            # 初始化训练集和测试集
            X_train = []
            X_test = []
            labels_train = labels[train_index]
            labels_test = labels[test_index]
            
            # 处理每个视图的数据
            for v_num in range(view_number):
                # 提取当前视图的训练集和测试集
                X_train_view = view_data[v_num][train_index]
                X_test_view = view_data[v_num][test_index]
                
                # 归一化处理
                if Normal == 1:
                    # 计算训练集的统计量
                    m = np.mean(X_train_view, axis=0)
                    mx = np.max(X_train_view, axis=0)
                    mn = np.min(X_train_view, axis=0)
                    range_val = mx - mn
                    range_val[range_val == 0] = 1  # 避免除零错误
                    
                    # 归一化训练集和测试集
                    X_train_view = (X_train_view - m) / range_val
                    X_test_view = (X_test_view - m) / range_val
                
                X_train.append(X_train_view)
                X_test.append(X_test_view)
            
            # 创建数据集对象
            traindata = DataSet(X_train, view_number, np.array(labels_train))
            testdata = DataSet(X_test, view_number, np.array(labels_test))
            trainData, testData, view_num = traindata, testdata, view_number
            
            # 准备模型参数
            outdim_size = [trainData.data[str(i)].shape[1] for i in range(view_num)]
            layer_size = [[150, outdim_size[i]] for i in range(view_num)]
            
            # 生成Sn（缺失模式矩阵）
            n_total = trainData.num_examples + testData.num_examples
            Sn = get_sn(view_num, n_total, 0)  # 缺失率为0
            Sn_train = Sn[np.arange(trainData.num_examples)]
            Sn_test = Sn[np.arange(testData.num_examples) + trainData.num_examples]
            
            # 模型参数
            lsd_dim = 128
            lamb = 1.
            # epoch = [10, 10]
            epoch = [100, 50]
            learning_rate = [0.05, 0.2]
            
            # 记录训练开始时间和内存
            start_time = time.time()
            # 获取当前进程
            process = psutil.Process(os.getpid())
            # mem_before = psutil.virtual_memory().used
            mem_before = process.memory_info().rss
            # 创建并训练模型
            model = CPMNets(view_num, trainData.num_examples, testData.num_examples, 
                            layer_size, lsd_dim, learning_rate, lamb)
            
            model.train(trainData.data, Sn_train, trainData.labels.reshape(trainData.num_examples), epoch[0])
            H_train = model.get_h_train()
            
            model.test(testData.data, Sn_test, testData.labels.reshape(testData.num_examples), epoch[1])
            H_test = model.get_h_test()
            
            # 记录训练结束时间和内存
            end_time = time.time()
            # mem_after = psutil.virtual_memory().used

            mem_after = process.memory_info().rss
            training_time = end_time - start_time
            cpu_memory_allocated = mem_after - mem_before
            
            # 预测和评估
            label_pred, label_prob = classfiy.ave(H_train, H_test, trainData.labels)
            scores = evaluate_model(testData.labels, label_pred, label_prob, num_class)
            
            # 记录结果
            metrics["Batch"].append(batch_num)
            metrics["Fold"].append(fold+1)
            metrics["Training_time"].append(training_time)
            metrics["CPU_memory_allocated"].append(cpu_memory_allocated)
            
            # 添加评估指标
            for key in scores:
                if key in metrics:
                    metrics[key].append(scores[key])
                    # 创建当前批次和折次的预测结果 DataFrame
            fold_predictions = pd.DataFrame({
                "Batch": [batch_num] * len(test_index),
                "Fold": [fold+1] * len(test_index),
                "True_Label": testData.labels.flatten(),
                "Pred_Label": label_pred,
            })
            
            # 添加每个类别的概率列
            for i in range(label_prob.shape[1]):
                fold_predictions[f"Prob_Class_{i}"] = np.round(label_prob[:, i], 4)
            
            # 将当前折次的预测结果添加到总 DataFrame
            all_predictions_df = pd.concat([all_predictions_df, fold_predictions], ignore_index=True)

            print(f"    训练时间: {training_time:.2f}秒, 内存使用: {cpu_memory_allocated/1024/1024:.2f}MB")
            print(f"    准确率: {scores['Accuracy']:.4f}")
        
    except Exception as e:
        print(f"处理 Batch {batch_num} 时出错: {str(e)}")
        continue

# 保存结果到DataFrame
metrics_df = pd.DataFrame(metrics)

# 保存到CSV文件
output_dir = "/public/home/yilab5/Master/methodology/result/result_CPM"
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, "cpmnets_cross_validation_results-mid.csv")
metrics_df.to_csv(output_path, index=False)
# 保存所有预测结果到另一个 CSV

predictions_path = os.path.join(output_dir, "cpmnets_all_predictions-mid.csv")
all_predictions_df.to_csv(predictions_path, index=False)

print("\n=== 所有批次和折次处理完成 ===")
print(f"结果已保存至: {output_path}")
# Out:
# === 处理 Batch 1 ===
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 485026976.0000, Classification Loss = 538.0701
# Epoch : 2  ===> Reconstruction Loss = 22456300.0000, Classification Loss = 273.5109
# Epoch : 3  ===> Reconstruction Loss = 10087899.0000, Classification Loss = 283.2769
# Epoch : 4  ===> Reconstruction Loss = 10043994.0000, Classification Loss = 279.5320
# Epoch : 5  ===> Reconstruction Loss = 2366950.7500, Classification Loss = 233.4970
# Epoch : 6  ===> Reconstruction Loss = 2561521.0000, Classification Loss = 233.9035
# Epoch : 7  ===> Reconstruction Loss = 1893330.7500, Classification Loss = 192.9586
# Epoch : 8  ===> Reconstruction Loss = 1208996.0000, Classification Loss = 195.5350
# Epoch : 9  ===> Reconstruction Loss = 995952.5000, Classification Loss = 204.6778
# Epoch : 10  ===> Reconstruction Loss = 877529.7500, Classification Loss = 202.6099
# Epoch : 11  ===> Reconstruction Loss = 766696.5000, Classification Loss = 199.8242
# Epoch : 12  ===> Reconstruction Loss = 731453.1250, Classification Loss = 196.8812
# Epoch : 13  ===> Reconstruction Loss = 725278.2500, Classification Loss = 194.1033
# Epoch : 14  ===> Reconstruction Loss = 685352.9375, Classification Loss = 195.6854
# Epoch : 15  ===> Reconstruction Loss = 684880.6875, Classification Loss = 197.2294
# Epoch : 16  ===> Reconstruction Loss = 682674.4375, Classification Loss = 195.0253
# Epoch : 17  ===> Reconstruction Loss = 679133.1875, Classification Loss = 196.4837
# Epoch : 18  ===> Reconstruction Loss = 669263.2500, Classification Loss = 196.1375
# Epoch : 19  ===> Reconstruction Loss = 674384.4375, Classification Loss = 194.8689
# Epoch : 20  ===> Reconstruction Loss = 673184.1875, Classification Loss = 196.0688
# Epoch : 21  ===> Reconstruction Loss = 670822.6875, Classification Loss = 195.3221
# Epoch : 22  ===> Reconstruction Loss = 675568.3750, Classification Loss = 194.1137
# Epoch : 23  ===> Reconstruction Loss = 658796.4375, Classification Loss = 194.8434
# Epoch : 24  ===> Reconstruction Loss = 663989.3125, Classification Loss = 194.6625
# Epoch : 25  ===> Reconstruction Loss = 671175.1250, Classification Loss = 193.5014
# Epoch : 26  ===> Reconstruction Loss = 668925.9375, Classification Loss = 191.4498
# Epoch : 27  ===> Reconstruction Loss = 659181.0000, Classification Loss = 191.3125
# Epoch : 28  ===> Reconstruction Loss = 661794.1875, Classification Loss = 190.1285
# Epoch : 29  ===> Reconstruction Loss = 659601.6250, Classification Loss = 189.9360
# Epoch : 30  ===> Reconstruction Loss = 655616.0625, Classification Loss = 188.7230
# Epoch : 31  ===> Reconstruction Loss = 661908.1250, Classification Loss = 187.5367
# Epoch : 32  ===> Reconstruction Loss = 664884.6875, Classification Loss = 187.3054
# Epoch : 33  ===> Reconstruction Loss = 654295.3750, Classification Loss = 186.0402
# Epoch : 34  ===> Reconstruction Loss = 654574.4375, Classification Loss = 185.7388
# Epoch : 35  ===> Reconstruction Loss = 656651.5000, Classification Loss = 186.4276
# Epoch : 36  ===> Reconstruction Loss = 653874.1250, Classification Loss = 186.0860
# Epoch : 37  ===> Reconstruction Loss = 661606.1250, Classification Loss = 185.7134
# Epoch : 38  ===> Reconstruction Loss = 664713.1250, Classification Loss = 185.3316
# Epoch : 39  ===> Reconstruction Loss = 649334.5000, Classification Loss = 183.8762
# Epoch : 40  ===> Reconstruction Loss = 653135.5625, Classification Loss = 182.4569
# Epoch : 41  ===> Reconstruction Loss = 644934.8125, Classification Loss = 182.0098
# Epoch : 42  ===> Reconstruction Loss = 656467.5625, Classification Loss = 181.5290
# Epoch : 43  ===> Reconstruction Loss = 643543.6875, Classification Loss = 180.0536
# Epoch : 44  ===> Reconstruction Loss = 634332.0625, Classification Loss = 179.5440
# Epoch : 45  ===> Reconstruction Loss = 644183.8750, Classification Loss = 178.0571
# Epoch : 46  ===> Reconstruction Loss = 645265.0625, Classification Loss = 176.5990
# Epoch : 47  ===> Reconstruction Loss = 640770.0000, Classification Loss = 175.1592
# Epoch : 48  ===> Reconstruction Loss = 651954.9375, Classification Loss = 173.7522
# Epoch : 49  ===> Reconstruction Loss = 639463.8750, Classification Loss = 171.3983
# Epoch : 50  ===> Reconstruction Loss = 649929.3750, Classification Loss = 171.0800
# Epoch : 51  ===> Reconstruction Loss = 638936.8125, Classification Loss = 169.7680
# Epoch : 52  ===> Reconstruction Loss = 636496.0625, Classification Loss = 169.4978
# Epoch : 53  ===> Reconstruction Loss = 636586.1875, Classification Loss = 169.2590
# Epoch : 54  ===> Reconstruction Loss = 635189.3125, Classification Loss = 167.0132
# Epoch : 55  ===> Reconstruction Loss = 639985.3750, Classification Loss = 166.8529
# Epoch : 56  ===> Reconstruction Loss = 631798.5000, Classification Loss = 166.6604
# Epoch : 57  ===> Reconstruction Loss = 637453.5625, Classification Loss = 165.5291
# Epoch : 58  ===> Reconstruction Loss = 638465.7500, Classification Loss = 165.3717
# Epoch : 59  ===> Reconstruction Loss = 634413.5625, Classification Loss = 165.2630
# Epoch : 60  ===> Reconstruction Loss = 631789.6250, Classification Loss = 165.1198
# Epoch : 61  ===> Reconstruction Loss = 632174.8125, Classification Loss = 166.0230
# Epoch : 62  ===> Reconstruction Loss = 637916.0000, Classification Loss = 164.9181
# Epoch : 63  ===> Reconstruction Loss = 626916.4375, Classification Loss = 164.8260
# Epoch : 64  ===> Reconstruction Loss = 627497.8125, Classification Loss = 164.7546
# Epoch : 65  ===> Reconstruction Loss = 630484.7500, Classification Loss = 164.6566
# Epoch : 66  ===> Reconstruction Loss = 631934.1875, Classification Loss = 164.5912
# Epoch : 67  ===> Reconstruction Loss = 627017.3125, Classification Loss = 164.5014
# Epoch : 68  ===> Reconstruction Loss = 633512.8125, Classification Loss = 164.4230
# Epoch : 69  ===> Reconstruction Loss = 624412.0625, Classification Loss = 164.3358
# Epoch : 70  ===> Reconstruction Loss = 628180.8750, Classification Loss = 164.2624
# Epoch : 71  ===> Reconstruction Loss = 627760.5000, Classification Loss = 164.1715
# Epoch : 72  ===> Reconstruction Loss = 622173.1875, Classification Loss = 164.1039
# Epoch : 73  ===> Reconstruction Loss = 623835.7500, Classification Loss = 164.0211
# Epoch : 74  ===> Reconstruction Loss = 622425.1875, Classification Loss = 164.9458
# Epoch : 75  ===> Reconstruction Loss = 626182.8125, Classification Loss = 164.8606
# Epoch : 76  ===> Reconstruction Loss = 618541.4375, Classification Loss = 164.7895
# Epoch : 77  ===> Reconstruction Loss = 623961.1250, Classification Loss = 164.7163
# Epoch : 78  ===> Reconstruction Loss = 624991.8125, Classification Loss = 163.6379
# Epoch : 79  ===> Reconstruction Loss = 620464.4375, Classification Loss = 162.5484
# Epoch : 80  ===> Reconstruction Loss = 622558.0000, Classification Loss = 163.4533
# Epoch : 81  ===> Reconstruction Loss = 613627.6875, Classification Loss = 163.3786
# Epoch : 82  ===> Reconstruction Loss = 608149.1250, Classification Loss = 164.2866
# Epoch : 83  ===> Reconstruction Loss = 619322.5625, Classification Loss = 164.2000
# Epoch : 84  ===> Reconstruction Loss = 612085.1875, Classification Loss = 164.1184
# Epoch : 85  ===> Reconstruction Loss = 614256.4375, Classification Loss = 163.0412
# Epoch : 86  ===> Reconstruction Loss = 615345.0625, Classification Loss = 163.9638
# Epoch : 87  ===> Reconstruction Loss = 607343.8750, Classification Loss = 163.8770
# Epoch : 88  ===> Reconstruction Loss = 620082.3125, Classification Loss = 163.8096
# Epoch : 89  ===> Reconstruction Loss = 614951.5625, Classification Loss = 163.7320
# Epoch : 90  ===> Reconstruction Loss = 620284.5000, Classification Loss = 163.6466
# Epoch : 91  ===> Reconstruction Loss = 615784.8125, Classification Loss = 162.5912
# Epoch : 92  ===> Reconstruction Loss = 607762.3125, Classification Loss = 162.5106
# Epoch : 93  ===> Reconstruction Loss = 616207.7500, Classification Loss = 162.4532
# Epoch : 94  ===> Reconstruction Loss = 617516.0625, Classification Loss = 162.3793
# Epoch : 95  ===> Reconstruction Loss = 606447.0625, Classification Loss = 162.2900
# Epoch : 96  ===> Reconstruction Loss = 613682.5625, Classification Loss = 162.2114
# Epoch : 97  ===> Reconstruction Loss = 613511.5000, Classification Loss = 162.1158
# Epoch : 98  ===> Reconstruction Loss = 607333.1250, Classification Loss = 162.0327
# Epoch : 99  ===> Reconstruction Loss = 606389.3750, Classification Loss = 161.9490
# Epoch : 100  ===> Reconstruction Loss = 604585.7500, Classification Loss = 161.8733
# Epoch : 1  ===> Reconstruction Loss = 1199167.3750
# Epoch : 2  ===> Reconstruction Loss = 720690.3750
# Epoch : 3  ===> Reconstruction Loss = 458860.8750
# Epoch : 4  ===> Reconstruction Loss = 353012.1875
# Epoch : 5  ===> Reconstruction Loss = 291839.8438
# Epoch : 6  ===> Reconstruction Loss = 247513.8594
# Epoch : 7  ===> Reconstruction Loss = 228403.6250
# Epoch : 8  ===> Reconstruction Loss = 225581.6094
# Epoch : 9  ===> Reconstruction Loss = 209483.6562
# Epoch : 10  ===> Reconstruction Loss = 205735.9219
# Epoch : 11  ===> Reconstruction Loss = 203536.2188
# Epoch : 12  ===> Reconstruction Loss = 203570.2969
# Epoch : 13  ===> Reconstruction Loss = 200851.9531
# Epoch : 14  ===> Reconstruction Loss = 200193.6094
# Epoch : 15  ===> Reconstruction Loss = 195626.6406
# Epoch : 16  ===> Reconstruction Loss = 193407.7656
# Epoch : 17  ===> Reconstruction Loss = 199622.3281
# Epoch : 18  ===> Reconstruction Loss = 192731.9219
# Epoch : 19  ===> Reconstruction Loss = 199920.8750
# Epoch : 20  ===> Reconstruction Loss = 194827.7188
# Epoch : 21  ===> Reconstruction Loss = 197253.6875
# Epoch : 22  ===> Reconstruction Loss = 191409.0000
# Epoch : 23  ===> Reconstruction Loss = 197544.0156
# Epoch : 24  ===> Reconstruction Loss = 195021.5781
# Epoch : 25  ===> Reconstruction Loss = 195382.9219
# Epoch : 26  ===> Reconstruction Loss = 196517.1719
# Epoch : 27  ===> Reconstruction Loss = 198210.7031
# Epoch : 28  ===> Reconstruction Loss = 194744.1250
# Epoch : 29  ===> Reconstruction Loss = 197298.0156
# Epoch : 30  ===> Reconstruction Loss = 192072.1250
# Epoch : 31  ===> Reconstruction Loss = 189003.3125
# Epoch : 32  ===> Reconstruction Loss = 197341.3438
# Epoch : 33  ===> Reconstruction Loss = 192725.1719
# Epoch : 34  ===> Reconstruction Loss = 193574.1875
# Epoch : 35  ===> Reconstruction Loss = 196800.8750
# Epoch : 36  ===> Reconstruction Loss = 190225.6562
# Epoch : 37  ===> Reconstruction Loss = 195422.5625
# Epoch : 38  ===> Reconstruction Loss = 195643.3125
# Epoch : 39  ===> Reconstruction Loss = 198149.5781
# Epoch : 40  ===> Reconstruction Loss = 196483.0938
# Epoch : 41  ===> Reconstruction Loss = 192334.9531
# Epoch : 42  ===> Reconstruction Loss = 194021.1562
# Epoch : 43  ===> Reconstruction Loss = 190638.3906
# Epoch : 44  ===> Reconstruction Loss = 193359.9531
# Epoch : 45  ===> Reconstruction Loss = 192800.9219
# Epoch : 46  ===> Reconstruction Loss = 196200.9219
# Epoch : 47  ===> Reconstruction Loss = 195357.2656
# Epoch : 48  ===> Reconstruction Loss = 191198.9375
# Epoch : 49  ===> Reconstruction Loss = 193564.9844
# Epoch : 50  ===> Reconstruction Loss = 193283.6094
#     训练时间: 19.36秒, 内存使用: 80.92MB
#     准确率: 0.7840
#   - 处理第 2 折
# Epoch : 1  ===> Reconstruction Loss = 429622400.0000, Classification Loss = 529.5275
# Epoch : 2  ===> Reconstruction Loss = 17021194.0000, Classification Loss = 277.7636
# Epoch : 3  ===> Reconstruction Loss = 5555037.0000, Classification Loss = 246.6772
# Epoch : 4  ===> Reconstruction Loss = 10024374.0000, Classification Loss = 279.6090
# Epoch : 5  ===> Reconstruction Loss = 4708200.0000, Classification Loss = 237.8865
# Epoch : 6  ===> Reconstruction Loss = 4172391.7500, Classification Loss = 205.2241
# Epoch : 7  ===> Reconstruction Loss = 2236311.0000, Classification Loss = 194.2799
# Epoch : 8  ===> Reconstruction Loss = 1492591.2500, Classification Loss = 182.5555
# Epoch : 9  ===> Reconstruction Loss = 1134671.1250, Classification Loss = 184.5952
# Epoch : 10  ===> Reconstruction Loss = 930006.1250, Classification Loss = 180.9130
# Epoch : 11  ===> Reconstruction Loss = 801969.2500, Classification Loss = 175.4876
# Epoch : 12  ===> Reconstruction Loss = 735088.6875, Classification Loss = 173.0774
# Epoch : 13  ===> Reconstruction Loss = 687534.7500, Classification Loss = 174.9264
# Epoch : 14  ===> Reconstruction Loss = 674656.4375, Classification Loss = 173.5664
# Epoch : 15  ===> Reconstruction Loss = 668849.4375, Classification Loss = 173.6187
# Epoch : 16  ===> Reconstruction Loss = 654888.4375, Classification Loss = 173.2415
# Epoch : 17  ===> Reconstruction Loss = 653901.0000, Classification Loss = 173.1670
# Epoch : 18  ===> Reconstruction Loss = 642687.3750, Classification Loss = 173.3605
# Epoch : 19  ===> Reconstruction Loss = 643816.1875, Classification Loss = 173.4820
# Epoch : 20  ===> Reconstruction Loss = 638331.1250, Classification Loss = 172.4195
# Epoch : 21  ===> Reconstruction Loss = 636930.4375, Classification Loss = 172.1591
# Epoch : 22  ===> Reconstruction Loss = 638017.6250, Classification Loss = 170.9313
# Epoch : 23  ===> Reconstruction Loss = 632876.5625, Classification Loss = 170.7542
# Epoch : 24  ===> Reconstruction Loss = 633463.0625, Classification Loss = 168.5611
# Epoch : 25  ===> Reconstruction Loss = 638197.0625, Classification Loss = 168.2819
# Epoch : 26  ===> Reconstruction Loss = 635954.8125, Classification Loss = 167.9928
# Epoch : 27  ===> Reconstruction Loss = 636956.6875, Classification Loss = 167.7263
# Epoch : 28  ===> Reconstruction Loss = 627100.5000, Classification Loss = 167.4495
# Epoch : 29  ===> Reconstruction Loss = 623280.4375, Classification Loss = 164.1465
# Epoch : 30  ===> Reconstruction Loss = 621838.0000, Classification Loss = 163.8372
# Epoch : 31  ===> Reconstruction Loss = 624219.7500, Classification Loss = 163.5362
# Epoch : 32  ===> Reconstruction Loss = 610338.5625, Classification Loss = 163.2246
# Epoch : 33  ===> Reconstruction Loss = 625357.6875, Classification Loss = 160.9208
# Epoch : 34  ===> Reconstruction Loss = 623965.6250, Classification Loss = 160.6040
# Epoch : 35  ===> Reconstruction Loss = 617419.5625, Classification Loss = 159.3188
# Epoch : 36  ===> Reconstruction Loss = 620814.1250, Classification Loss = 159.0248
# Epoch : 37  ===> Reconstruction Loss = 613859.4375, Classification Loss = 157.7522
# Epoch : 38  ===> Reconstruction Loss = 610575.0000, Classification Loss = 157.5049
# Epoch : 39  ===> Reconstruction Loss = 616386.6250, Classification Loss = 157.2930
# Epoch : 40  ===> Reconstruction Loss = 617006.1875, Classification Loss = 157.0762
# Epoch : 41  ===> Reconstruction Loss = 619473.5000, Classification Loss = 155.9088
# Epoch : 42  ===> Reconstruction Loss = 607289.0000, Classification Loss = 155.7341
# Epoch : 43  ===> Reconstruction Loss = 623775.0000, Classification Loss = 155.6010
# Epoch : 44  ===> Reconstruction Loss = 620060.7500, Classification Loss = 155.4586
# Epoch : 45  ===> Reconstruction Loss = 611718.5000, Classification Loss = 155.3353
# Epoch : 46  ===> Reconstruction Loss = 606570.5625, Classification Loss = 155.2220
# Epoch : 47  ===> Reconstruction Loss = 607773.2500, Classification Loss = 155.1158
# Epoch : 48  ===> Reconstruction Loss = 615197.7500, Classification Loss = 155.0017
# Epoch : 49  ===> Reconstruction Loss = 614647.6250, Classification Loss = 154.8933
# Epoch : 50  ===> Reconstruction Loss = 619590.3125, Classification Loss = 154.7827
# Epoch : 51  ===> Reconstruction Loss = 603586.9375, Classification Loss = 154.6700
# Epoch : 52  ===> Reconstruction Loss = 596750.1250, Classification Loss = 154.5645
# Epoch : 53  ===> Reconstruction Loss = 602663.9375, Classification Loss = 154.4553
# Epoch : 54  ===> Reconstruction Loss = 599850.3125, Classification Loss = 154.3348
# Epoch : 55  ===> Reconstruction Loss = 597392.6875, Classification Loss = 154.2198
# Epoch : 56  ===> Reconstruction Loss = 603262.5000, Classification Loss = 154.0977
# Epoch : 57  ===> Reconstruction Loss = 610168.5000, Classification Loss = 153.9741
# Epoch : 58  ===> Reconstruction Loss = 600484.5000, Classification Loss = 153.8564
# Epoch : 59  ===> Reconstruction Loss = 599852.5000, Classification Loss = 153.7330
# Epoch : 60  ===> Reconstruction Loss = 599208.3750, Classification Loss = 153.6145
# Epoch : 61  ===> Reconstruction Loss = 602625.5000, Classification Loss = 153.4982
# Epoch : 62  ===> Reconstruction Loss = 595308.7500, Classification Loss = 153.3829
# Epoch : 63  ===> Reconstruction Loss = 597887.5625, Classification Loss = 153.2704
# Epoch : 64  ===> Reconstruction Loss = 593521.4375, Classification Loss = 153.1669
# Epoch : 65  ===> Reconstruction Loss = 592303.2500, Classification Loss = 153.0676
# Epoch : 66  ===> Reconstruction Loss = 587029.7500, Classification Loss = 151.9748
# Epoch : 67  ===> Reconstruction Loss = 597624.3750, Classification Loss = 151.8981
# Epoch : 68  ===> Reconstruction Loss = 602804.8750, Classification Loss = 151.8019
# Epoch : 69  ===> Reconstruction Loss = 611330.1250, Classification Loss = 151.6590
# Epoch : 70  ===> Reconstruction Loss = 592933.3125, Classification Loss = 151.5361
# Epoch : 71  ===> Reconstruction Loss = 589437.0625, Classification Loss = 151.4049
# Epoch : 72  ===> Reconstruction Loss = 589694.8750, Classification Loss = 151.3082
# Epoch : 73  ===> Reconstruction Loss = 585649.3125, Classification Loss = 151.2188
# Epoch : 74  ===> Reconstruction Loss = 591449.3125, Classification Loss = 151.1540
# Epoch : 75  ===> Reconstruction Loss = 589725.0625, Classification Loss = 151.0871
# Epoch : 76  ===> Reconstruction Loss = 590395.0625, Classification Loss = 151.0285
# Epoch : 77  ===> Reconstruction Loss = 593703.6250, Classification Loss = 150.9716
# Epoch : 78  ===> Reconstruction Loss = 583813.6875, Classification Loss = 150.9128
# Epoch : 79  ===> Reconstruction Loss = 594509.2500, Classification Loss = 150.8513
# Epoch : 80  ===> Reconstruction Loss = 588136.0625, Classification Loss = 150.8112
# Epoch : 81  ===> Reconstruction Loss = 587498.0000, Classification Loss = 150.7403
# Epoch : 82  ===> Reconstruction Loss = 595626.7500, Classification Loss = 150.6988
# Epoch : 83  ===> Reconstruction Loss = 581090.3750, Classification Loss = 150.6286
# Epoch : 84  ===> Reconstruction Loss = 590703.7500, Classification Loss = 150.5678
# Epoch : 85  ===> Reconstruction Loss = 586976.5625, Classification Loss = 150.5001
# Epoch : 86  ===> Reconstruction Loss = 581874.4375, Classification Loss = 150.4273
# Epoch : 87  ===> Reconstruction Loss = 591699.6250, Classification Loss = 150.3719
# Epoch : 88  ===> Reconstruction Loss = 579404.0000, Classification Loss = 150.3059
# Epoch : 89  ===> Reconstruction Loss = 584639.2500, Classification Loss = 150.2502
# Epoch : 90  ===> Reconstruction Loss = 592320.5000, Classification Loss = 150.1969
# Epoch : 91  ===> Reconstruction Loss = 585312.7500, Classification Loss = 150.1397
# Epoch : 92  ===> Reconstruction Loss = 582871.5625, Classification Loss = 150.0905
# Epoch : 93  ===> Reconstruction Loss = 583591.7500, Classification Loss = 150.0188
# Epoch : 94  ===> Reconstruction Loss = 573473.3750, Classification Loss = 149.9628
# Epoch : 95  ===> Reconstruction Loss = 581906.8750, Classification Loss = 149.8873
# Epoch : 96  ===> Reconstruction Loss = 582491.0625, Classification Loss = 149.8318
# Epoch : 97  ===> Reconstruction Loss = 577979.6875, Classification Loss = 149.7666
# Epoch : 98  ===> Reconstruction Loss = 579913.5000, Classification Loss = 149.7162
# Epoch : 99  ===> Reconstruction Loss = 579686.5625, Classification Loss = 149.6494
# Epoch : 100  ===> Reconstruction Loss = 580929.3125, Classification Loss = 149.5981
# Epoch : 1  ===> Reconstruction Loss = 1208258.5000
# Epoch : 2  ===> Reconstruction Loss = 753873.2500
# Epoch : 3  ===> Reconstruction Loss = 530810.0000
# Epoch : 4  ===> Reconstruction Loss = 392616.4375
# Epoch : 5  ===> Reconstruction Loss = 306889.1562
# Epoch : 6  ===> Reconstruction Loss = 279211.0000
# Epoch : 7  ===> Reconstruction Loss = 264802.7812
# Epoch : 8  ===> Reconstruction Loss = 245292.2344
# Epoch : 9  ===> Reconstruction Loss = 240853.8906
# Epoch : 10  ===> Reconstruction Loss = 237805.4062
# Epoch : 11  ===> Reconstruction Loss = 227428.3906
# Epoch : 12  ===> Reconstruction Loss = 226546.4688
# Epoch : 13  ===> Reconstruction Loss = 234207.9375
# Epoch : 14  ===> Reconstruction Loss = 223915.7656
# Epoch : 15  ===> Reconstruction Loss = 223687.3281
# Epoch : 16  ===> Reconstruction Loss = 226554.7500
# Epoch : 17  ===> Reconstruction Loss = 224747.6250
# Epoch : 18  ===> Reconstruction Loss = 221361.7188
# Epoch : 19  ===> Reconstruction Loss = 225161.2344
# Epoch : 20  ===> Reconstruction Loss = 222271.7656
# Epoch : 21  ===> Reconstruction Loss = 221938.4375
# Epoch : 22  ===> Reconstruction Loss = 214236.4844
# Epoch : 23  ===> Reconstruction Loss = 221746.5469
# Epoch : 24  ===> Reconstruction Loss = 220945.6406
# Epoch : 25  ===> Reconstruction Loss = 217096.1406
# Epoch : 26  ===> Reconstruction Loss = 221959.0469
# Epoch : 27  ===> Reconstruction Loss = 222672.0469
# Epoch : 28  ===> Reconstruction Loss = 220654.3438
# Epoch : 29  ===> Reconstruction Loss = 222752.7500
# Epoch : 30  ===> Reconstruction Loss = 215477.8438
# Epoch : 31  ===> Reconstruction Loss = 220476.4844
# Epoch : 32  ===> Reconstruction Loss = 220924.7500
# Epoch : 33  ===> Reconstruction Loss = 224730.3125
# Epoch : 34  ===> Reconstruction Loss = 221913.8594
# Epoch : 35  ===> Reconstruction Loss = 222293.4219
# Epoch : 36  ===> Reconstruction Loss = 224282.3125
# Epoch : 37  ===> Reconstruction Loss = 220961.7812
# Epoch : 38  ===> Reconstruction Loss = 219693.4375
# Epoch : 39  ===> Reconstruction Loss = 218108.8125
# Epoch : 40  ===> Reconstruction Loss = 224109.5781
# Epoch : 41  ===> Reconstruction Loss = 216750.6406
# Epoch : 42  ===> Reconstruction Loss = 222497.1094
# Epoch : 43  ===> Reconstruction Loss = 217160.4531
# Epoch : 44  ===> Reconstruction Loss = 220476.1562
# Epoch : 45  ===> Reconstruction Loss = 220182.1719
# Epoch : 46  ===> Reconstruction Loss = 220122.4531
# Epoch : 47  ===> Reconstruction Loss = 226440.6094
# Epoch : 48  ===> Reconstruction Loss = 224660.9375
# Epoch : 49  ===> Reconstruction Loss = 216819.8281
# Epoch : 50  ===> Reconstruction Loss = 217637.3594
#     训练时间: 20.95秒, 内存使用: 124.50MB
#     准确率: 0.8080
#   - 处理第 3 折
# Epoch : 1  ===> Reconstruction Loss = 628459008.0000, Classification Loss = 549.0865
# Epoch : 2  ===> Reconstruction Loss = 23313030.0000, Classification Loss = 282.3152
# Epoch : 3  ===> Reconstruction Loss = 14181959.0000, Classification Loss = 385.9107
# Epoch : 4  ===> Reconstruction Loss = 5418868.5000, Classification Loss = 361.0712
# Epoch : 5  ===> Reconstruction Loss = 5549074.0000, Classification Loss = 425.5052
# Epoch : 6  ===> Reconstruction Loss = 2635166.5000, Classification Loss = 460.4763
# Epoch : 7  ===> Reconstruction Loss = 2480866.5000, Classification Loss = 471.5813
# Epoch : 8  ===> Reconstruction Loss = 1153490.0000, Classification Loss = 491.7622
# Epoch : 9  ===> Reconstruction Loss = 1243290.3750, Classification Loss = 506.2948
# Epoch : 10  ===> Reconstruction Loss = 948357.6875, Classification Loss = 503.6062
# Epoch : 11  ===> Reconstruction Loss = 800898.1875, Classification Loss = 516.9339
# Epoch : 12  ===> Reconstruction Loss = 766170.9375, Classification Loss = 514.1021
# Epoch : 13  ===> Reconstruction Loss = 735138.1875, Classification Loss = 521.2328
# Epoch : 14  ===> Reconstruction Loss = 703654.1875, Classification Loss = 518.5450
# Epoch : 15  ===> Reconstruction Loss = 694843.5000, Classification Loss = 520.2991
# Epoch : 16  ===> Reconstruction Loss = 686944.1250, Classification Loss = 518.2595
# Epoch : 17  ===> Reconstruction Loss = 686406.9375, Classification Loss = 518.0922
# Epoch : 18  ===> Reconstruction Loss = 662060.1250, Classification Loss = 515.7151
# Epoch : 19  ===> Reconstruction Loss = 678942.3750, Classification Loss = 514.7194
# Epoch : 20  ===> Reconstruction Loss = 667619.1250, Classification Loss = 514.4374
# Epoch : 21  ===> Reconstruction Loss = 665886.3750, Classification Loss = 514.1437
# Epoch : 22  ===> Reconstruction Loss = 656892.0625, Classification Loss = 513.7054
# Epoch : 23  ===> Reconstruction Loss = 667238.3750, Classification Loss = 513.2361
# Epoch : 24  ===> Reconstruction Loss = 665386.3750, Classification Loss = 512.8607
# Epoch : 25  ===> Reconstruction Loss = 668353.1250, Classification Loss = 511.4403
# Epoch : 26  ===> Reconstruction Loss = 669646.3750, Classification Loss = 510.9934
# Epoch : 27  ===> Reconstruction Loss = 677725.3125, Classification Loss = 510.4835
# Epoch : 28  ===> Reconstruction Loss = 662846.3125, Classification Loss = 509.9969
# Epoch : 29  ===> Reconstruction Loss = 665460.1875, Classification Loss = 509.5020
# Epoch : 30  ===> Reconstruction Loss = 662670.0625, Classification Loss = 508.9625
# Epoch : 31  ===> Reconstruction Loss = 663721.6875, Classification Loss = 508.4343
# Epoch : 32  ===> Reconstruction Loss = 663838.1875, Classification Loss = 507.8477
# Epoch : 33  ===> Reconstruction Loss = 668121.5000, Classification Loss = 507.2846
# Epoch : 34  ===> Reconstruction Loss = 656252.4375, Classification Loss = 507.6625
# Epoch : 35  ===> Reconstruction Loss = 661223.1875, Classification Loss = 507.0412
# Epoch : 36  ===> Reconstruction Loss = 668095.9375, Classification Loss = 506.3767
# Epoch : 37  ===> Reconstruction Loss = 665830.4375, Classification Loss = 505.6743
# Epoch : 38  ===> Reconstruction Loss = 655375.0000, Classification Loss = 504.9618
# Epoch : 39  ===> Reconstruction Loss = 664379.3750, Classification Loss = 504.2000
# Epoch : 40  ===> Reconstruction Loss = 658222.7500, Classification Loss = 503.4389
# Epoch : 41  ===> Reconstruction Loss = 651641.5000, Classification Loss = 502.6337
# Epoch : 42  ===> Reconstruction Loss = 648656.8750, Classification Loss = 501.8251
# Epoch : 43  ===> Reconstruction Loss = 652253.4375, Classification Loss = 500.9487
# Epoch : 44  ===> Reconstruction Loss = 655773.7500, Classification Loss = 500.0802
# Epoch : 45  ===> Reconstruction Loss = 653935.6875, Classification Loss = 499.1921
# Epoch : 46  ===> Reconstruction Loss = 660182.3125, Classification Loss = 498.2982
# Epoch : 47  ===> Reconstruction Loss = 650464.5000, Classification Loss = 497.4095
# Epoch : 48  ===> Reconstruction Loss = 654972.6875, Classification Loss = 496.5722
# Epoch : 49  ===> Reconstruction Loss = 657383.6250, Classification Loss = 495.6884
# Epoch : 50  ===> Reconstruction Loss = 657044.5000, Classification Loss = 494.8452
# Epoch : 51  ===> Reconstruction Loss = 645595.0625, Classification Loss = 494.0146
# Epoch : 52  ===> Reconstruction Loss = 643744.0000, Classification Loss = 493.2375
# Epoch : 53  ===> Reconstruction Loss = 646302.1875, Classification Loss = 492.4500
# Epoch : 54  ===> Reconstruction Loss = 652076.6875, Classification Loss = 491.7274
# Epoch : 55  ===> Reconstruction Loss = 646375.4375, Classification Loss = 491.0114
# Epoch : 56  ===> Reconstruction Loss = 646266.6250, Classification Loss = 490.3293
# Epoch : 57  ===> Reconstruction Loss = 651383.3750, Classification Loss = 489.6927
# Epoch : 58  ===> Reconstruction Loss = 644389.4375, Classification Loss = 489.0540
# Epoch : 59  ===> Reconstruction Loss = 642768.5000, Classification Loss = 488.5039
# Epoch : 60  ===> Reconstruction Loss = 647789.3750, Classification Loss = 487.9408
# Epoch : 61  ===> Reconstruction Loss = 643990.0625, Classification Loss = 487.3950
# Epoch : 62  ===> Reconstruction Loss = 647157.1875, Classification Loss = 486.9168
# Epoch : 63  ===> Reconstruction Loss = 642383.8125, Classification Loss = 486.4555
# Epoch : 64  ===> Reconstruction Loss = 636560.0000, Classification Loss = 485.9709
# Epoch : 65  ===> Reconstruction Loss = 639800.3750, Classification Loss = 485.5182
# Epoch : 66  ===> Reconstruction Loss = 640386.1250, Classification Loss = 485.1263
# Epoch : 67  ===> Reconstruction Loss = 649619.0000, Classification Loss = 484.7061
# Epoch : 68  ===> Reconstruction Loss = 645234.9375, Classification Loss = 484.3334
# Epoch : 69  ===> Reconstruction Loss = 640079.8125, Classification Loss = 483.9633
# Epoch : 70  ===> Reconstruction Loss = 637480.8125, Classification Loss = 483.5934
# Epoch : 71  ===> Reconstruction Loss = 640849.7500, Classification Loss = 483.2407
# Epoch : 72  ===> Reconstruction Loss = 634280.2500, Classification Loss = 482.9181
# Epoch : 73  ===> Reconstruction Loss = 633598.3125, Classification Loss = 483.5376
# Epoch : 74  ===> Reconstruction Loss = 626281.0000, Classification Loss = 483.2390
# Epoch : 75  ===> Reconstruction Loss = 627246.4375, Classification Loss = 482.9362
# Epoch : 76  ===> Reconstruction Loss = 634122.2500, Classification Loss = 482.5878
# Epoch : 77  ===> Reconstruction Loss = 631964.6875, Classification Loss = 482.2894
# Epoch : 78  ===> Reconstruction Loss = 630468.7500, Classification Loss = 482.0045
# Epoch : 79  ===> Reconstruction Loss = 634909.1875, Classification Loss = 481.6812
# Epoch : 80  ===> Reconstruction Loss = 634906.7500, Classification Loss = 481.3891
# Epoch : 81  ===> Reconstruction Loss = 630821.5625, Classification Loss = 481.1004
# Epoch : 82  ===> Reconstruction Loss = 630425.8125, Classification Loss = 480.7710
# Epoch : 83  ===> Reconstruction Loss = 627969.5000, Classification Loss = 480.4586
# Epoch : 84  ===> Reconstruction Loss = 631128.6875, Classification Loss = 480.1387
# Epoch : 85  ===> Reconstruction Loss = 626383.8750, Classification Loss = 479.8118
# Epoch : 86  ===> Reconstruction Loss = 620013.1875, Classification Loss = 478.5033
# Epoch : 87  ===> Reconstruction Loss = 635571.5000, Classification Loss = 478.1428
# Epoch : 88  ===> Reconstruction Loss = 634028.3750, Classification Loss = 477.7301
# Epoch : 89  ===> Reconstruction Loss = 622674.8750, Classification Loss = 477.4168
# Epoch : 90  ===> Reconstruction Loss = 632340.6875, Classification Loss = 477.1104
# Epoch : 91  ===> Reconstruction Loss = 615678.5000, Classification Loss = 476.8302
# Epoch : 92  ===> Reconstruction Loss = 619817.1875, Classification Loss = 476.6153
# Epoch : 93  ===> Reconstruction Loss = 620897.5625, Classification Loss = 475.2775
# Epoch : 94  ===> Reconstruction Loss = 625185.2500, Classification Loss = 474.9831
# Epoch : 95  ===> Reconstruction Loss = 617919.0625, Classification Loss = 475.6989
# Epoch : 96  ===> Reconstruction Loss = 615093.0000, Classification Loss = 475.3691
# Epoch : 97  ===> Reconstruction Loss = 619606.8125, Classification Loss = 475.0282
# Epoch : 98  ===> Reconstruction Loss = 623217.3125, Classification Loss = 474.7297
# Epoch : 99  ===> Reconstruction Loss = 619346.6875, Classification Loss = 474.4153
# Epoch : 100  ===> Reconstruction Loss = 624332.0000, Classification Loss = 474.0371
# Epoch : 1  ===> Reconstruction Loss = 1908746.3750
# Epoch : 2  ===> Reconstruction Loss = 1202389.0000
# Epoch : 3  ===> Reconstruction Loss = 765788.1250
# Epoch : 4  ===> Reconstruction Loss = 498362.5312
# Epoch : 5  ===> Reconstruction Loss = 362608.5312
# Epoch : 6  ===> Reconstruction Loss = 290965.8125
# Epoch : 7  ===> Reconstruction Loss = 259621.6094
# Epoch : 8  ===> Reconstruction Loss = 246561.4844
# Epoch : 9  ===> Reconstruction Loss = 237604.0469
# Epoch : 10  ===> Reconstruction Loss = 229709.4375
# Epoch : 11  ===> Reconstruction Loss = 212461.2031
# Epoch : 12  ===> Reconstruction Loss = 216992.3438
# Epoch : 13  ===> Reconstruction Loss = 213318.3281
# Epoch : 14  ===> Reconstruction Loss = 209578.5781
# Epoch : 15  ===> Reconstruction Loss = 211384.4531
# Epoch : 16  ===> Reconstruction Loss = 211203.3750
# Epoch : 17  ===> Reconstruction Loss = 210300.3438
# Epoch : 18  ===> Reconstruction Loss = 205507.3750
# Epoch : 19  ===> Reconstruction Loss = 210112.6406
# Epoch : 20  ===> Reconstruction Loss = 206230.7969
# Epoch : 21  ===> Reconstruction Loss = 206157.3438
# Epoch : 22  ===> Reconstruction Loss = 209000.7500
# Epoch : 23  ===> Reconstruction Loss = 202951.3438
# Epoch : 24  ===> Reconstruction Loss = 202928.1562
# Epoch : 25  ===> Reconstruction Loss = 202291.0000
# Epoch : 26  ===> Reconstruction Loss = 199720.9062
# Epoch : 27  ===> Reconstruction Loss = 203408.0781
# Epoch : 28  ===> Reconstruction Loss = 201804.0625
# Epoch : 29  ===> Reconstruction Loss = 200312.6406
# Epoch : 30  ===> Reconstruction Loss = 200592.3125
# Epoch : 31  ===> Reconstruction Loss = 205456.3438
# Epoch : 32  ===> Reconstruction Loss = 204399.0000
# Epoch : 33  ===> Reconstruction Loss = 202585.4375
# Epoch : 34  ===> Reconstruction Loss = 207228.8281
# Epoch : 35  ===> Reconstruction Loss = 201870.6094
# Epoch : 36  ===> Reconstruction Loss = 197836.6719
# Epoch : 37  ===> Reconstruction Loss = 200529.2031
# Epoch : 38  ===> Reconstruction Loss = 201751.6562
# Epoch : 39  ===> Reconstruction Loss = 197510.5312
# Epoch : 40  ===> Reconstruction Loss = 198448.3906
# Epoch : 41  ===> Reconstruction Loss = 199192.3125
# Epoch : 42  ===> Reconstruction Loss = 199766.9688
# Epoch : 43  ===> Reconstruction Loss = 203710.1719
# Epoch : 44  ===> Reconstruction Loss = 202454.8125
# Epoch : 45  ===> Reconstruction Loss = 200763.3125
# Epoch : 46  ===> Reconstruction Loss = 202001.3750
# Epoch : 47  ===> Reconstruction Loss = 200468.5625
# Epoch : 48  ===> Reconstruction Loss = 198952.0000
# Epoch : 49  ===> Reconstruction Loss = 198749.2969
# Epoch : 50  ===> Reconstruction Loss = 200813.1875
#     训练时间: 19.78秒, 内存使用: 53.14MB
#     准确率: 0.7760
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 622741120.0000, Classification Loss = 551.6674
# Epoch : 2  ===> Reconstruction Loss = 17795486.0000, Classification Loss = 284.4610
# Epoch : 3  ===> Reconstruction Loss = 10826117.0000, Classification Loss = 323.1558
# Epoch : 4  ===> Reconstruction Loss = 10493592.0000, Classification Loss = 370.9897
# Epoch : 5  ===> Reconstruction Loss = 5548134.5000, Classification Loss = 406.5944
# Epoch : 6  ===> Reconstruction Loss = 3535739.7500, Classification Loss = 401.5958
# Epoch : 7  ===> Reconstruction Loss = 2070262.1250, Classification Loss = 411.6086
# Epoch : 8  ===> Reconstruction Loss = 1480117.6250, Classification Loss = 400.9946
# Epoch : 9  ===> Reconstruction Loss = 1222892.0000, Classification Loss = 397.0156
# Epoch : 10  ===> Reconstruction Loss = 970804.6875, Classification Loss = 392.3650
# Epoch : 11  ===> Reconstruction Loss = 816351.7500, Classification Loss = 387.1405
# Epoch : 12  ===> Reconstruction Loss = 767391.7500, Classification Loss = 381.5198
# Epoch : 13  ===> Reconstruction Loss = 717359.0000, Classification Loss = 379.2668
# Epoch : 14  ===> Reconstruction Loss = 702567.8750, Classification Loss = 375.4595
# Epoch : 15  ===> Reconstruction Loss = 686196.5625, Classification Loss = 372.6862
# Epoch : 16  ===> Reconstruction Loss = 674825.0625, Classification Loss = 369.7581
# Epoch : 17  ===> Reconstruction Loss = 673458.9375, Classification Loss = 368.6544
# Epoch : 18  ===> Reconstruction Loss = 674604.6250, Classification Loss = 366.7991
# Epoch : 19  ===> Reconstruction Loss = 662529.6875, Classification Loss = 364.4782
# Epoch : 20  ===> Reconstruction Loss = 662906.8750, Classification Loss = 360.8066
# Epoch : 21  ===> Reconstruction Loss = 656098.8750, Classification Loss = 359.6162
# Epoch : 22  ===> Reconstruction Loss = 656426.7500, Classification Loss = 359.2632
# Epoch : 23  ===> Reconstruction Loss = 655366.8750, Classification Loss = 359.0033
# Epoch : 24  ===> Reconstruction Loss = 650177.3750, Classification Loss = 358.7315
# Epoch : 25  ===> Reconstruction Loss = 661163.9375, Classification Loss = 357.4547
# Epoch : 26  ===> Reconstruction Loss = 658242.1875, Classification Loss = 357.1505
# Epoch : 27  ===> Reconstruction Loss = 656648.9375, Classification Loss = 356.8491
# Epoch : 28  ===> Reconstruction Loss = 651814.4375, Classification Loss = 357.5466
# Epoch : 29  ===> Reconstruction Loss = 655673.1250, Classification Loss = 357.2292
# Epoch : 30  ===> Reconstruction Loss = 644074.0625, Classification Loss = 356.8677
# Epoch : 31  ===> Reconstruction Loss = 652540.1250, Classification Loss = 356.5051
# Epoch : 32  ===> Reconstruction Loss = 652716.3750, Classification Loss = 356.1071
# Epoch : 33  ===> Reconstruction Loss = 657580.4375, Classification Loss = 355.7065
# Epoch : 34  ===> Reconstruction Loss = 650253.5000, Classification Loss = 355.2471
# Epoch : 35  ===> Reconstruction Loss = 646368.3125, Classification Loss = 354.7933
# Epoch : 36  ===> Reconstruction Loss = 644139.8125, Classification Loss = 354.3095
# Epoch : 37  ===> Reconstruction Loss = 650613.1250, Classification Loss = 353.7979
# Epoch : 38  ===> Reconstruction Loss = 645398.0000, Classification Loss = 353.2412
# Epoch : 39  ===> Reconstruction Loss = 647323.4375, Classification Loss = 353.6720
# Epoch : 40  ===> Reconstruction Loss = 644433.3125, Classification Loss = 353.0674
# Epoch : 41  ===> Reconstruction Loss = 647120.8125, Classification Loss = 352.4348
# Epoch : 42  ===> Reconstruction Loss = 640359.5625, Classification Loss = 352.7733
# Epoch : 43  ===> Reconstruction Loss = 649026.6250, Classification Loss = 352.1193
# Epoch : 44  ===> Reconstruction Loss = 643023.1875, Classification Loss = 351.4024
# Epoch : 45  ===> Reconstruction Loss = 644979.4375, Classification Loss = 351.7236
# Epoch : 46  ===> Reconstruction Loss = 640430.0625, Classification Loss = 351.9906
# Epoch : 47  ===> Reconstruction Loss = 632843.6875, Classification Loss = 351.2744
# Epoch : 48  ===> Reconstruction Loss = 634669.3750, Classification Loss = 350.5387
# Epoch : 49  ===> Reconstruction Loss = 643060.2500, Classification Loss = 349.8131
# Epoch : 50  ===> Reconstruction Loss = 628012.3750, Classification Loss = 349.1026
# Epoch : 51  ===> Reconstruction Loss = 633374.0000, Classification Loss = 348.3959
# Epoch : 52  ===> Reconstruction Loss = 631944.0625, Classification Loss = 348.7454
# Epoch : 53  ===> Reconstruction Loss = 632466.8750, Classification Loss = 347.0862
# Epoch : 54  ===> Reconstruction Loss = 631171.6875, Classification Loss = 346.5008
# Epoch : 55  ===> Reconstruction Loss = 627982.1875, Classification Loss = 345.9037
# Epoch : 56  ===> Reconstruction Loss = 630989.3125, Classification Loss = 344.3185
# Epoch : 57  ===> Reconstruction Loss = 633092.1875, Classification Loss = 343.8362
# Epoch : 58  ===> Reconstruction Loss = 622269.0000, Classification Loss = 343.3769
# Epoch : 59  ===> Reconstruction Loss = 614535.8750, Classification Loss = 342.9988
# Epoch : 60  ===> Reconstruction Loss = 619969.0000, Classification Loss = 342.6678
# Epoch : 61  ===> Reconstruction Loss = 631484.9375, Classification Loss = 342.3954
# Epoch : 62  ===> Reconstruction Loss = 624593.1875, Classification Loss = 342.1649
# Epoch : 63  ===> Reconstruction Loss = 624135.4375, Classification Loss = 341.9552
# Epoch : 64  ===> Reconstruction Loss = 620164.6875, Classification Loss = 341.7817
# Epoch : 65  ===> Reconstruction Loss = 622978.5000, Classification Loss = 341.6206
# Epoch : 66  ===> Reconstruction Loss = 624352.6250, Classification Loss = 341.4706
# Epoch : 67  ===> Reconstruction Loss = 621753.9375, Classification Loss = 340.3165
# Epoch : 68  ===> Reconstruction Loss = 623658.8750, Classification Loss = 340.1888
# Epoch : 69  ===> Reconstruction Loss = 618264.3125, Classification Loss = 340.0373
# Epoch : 70  ===> Reconstruction Loss = 620796.0000, Classification Loss = 340.9179
# Epoch : 71  ===> Reconstruction Loss = 626278.1250, Classification Loss = 340.7909
# Epoch : 72  ===> Reconstruction Loss = 623209.0000, Classification Loss = 339.6692
# Epoch : 73  ===> Reconstruction Loss = 620057.5000, Classification Loss = 339.5455
# Epoch : 74  ===> Reconstruction Loss = 619794.0625, Classification Loss = 339.4538
# Epoch : 75  ===> Reconstruction Loss = 620995.0000, Classification Loss = 339.3154
# Epoch : 76  ===> Reconstruction Loss = 616145.3125, Classification Loss = 339.2320
# Epoch : 77  ===> Reconstruction Loss = 609766.6250, Classification Loss = 339.1028
# Epoch : 78  ===> Reconstruction Loss = 607071.2500, Classification Loss = 339.0162
# Epoch : 79  ===> Reconstruction Loss = 617883.7500, Classification Loss = 338.8654
# Epoch : 80  ===> Reconstruction Loss = 614825.3750, Classification Loss = 338.7692
# Epoch : 81  ===> Reconstruction Loss = 615874.9375, Classification Loss = 338.6497
# Epoch : 82  ===> Reconstruction Loss = 604321.5625, Classification Loss = 338.5309
# Epoch : 83  ===> Reconstruction Loss = 609401.8125, Classification Loss = 338.4128
# Epoch : 84  ===> Reconstruction Loss = 609392.8125, Classification Loss = 337.2904
# Epoch : 85  ===> Reconstruction Loss = 603143.3750, Classification Loss = 337.1766
# Epoch : 86  ===> Reconstruction Loss = 613164.4375, Classification Loss = 337.0666
# Epoch : 87  ===> Reconstruction Loss = 603094.2500, Classification Loss = 336.9620
# Epoch : 88  ===> Reconstruction Loss = 604361.0625, Classification Loss = 336.8444
# Epoch : 89  ===> Reconstruction Loss = 606581.5000, Classification Loss = 336.7230
# Epoch : 90  ===> Reconstruction Loss = 602936.3125, Classification Loss = 336.6107
# Epoch : 91  ===> Reconstruction Loss = 606702.3750, Classification Loss = 336.5031
# Epoch : 92  ===> Reconstruction Loss = 600926.3125, Classification Loss = 336.3922
# Epoch : 93  ===> Reconstruction Loss = 602194.8125, Classification Loss = 336.2782
# Epoch : 94  ===> Reconstruction Loss = 605997.6250, Classification Loss = 335.1859
# Epoch : 95  ===> Reconstruction Loss = 600985.6250, Classification Loss = 335.0640
# Epoch : 96  ===> Reconstruction Loss = 603957.3125, Classification Loss = 334.9541
# Epoch : 97  ===> Reconstruction Loss = 596863.4375, Classification Loss = 334.8487
# Epoch : 98  ===> Reconstruction Loss = 609901.0625, Classification Loss = 334.7227
# Epoch : 99  ===> Reconstruction Loss = 603184.2500, Classification Loss = 334.6125
# Epoch : 100  ===> Reconstruction Loss = 599120.0625, Classification Loss = 334.4811
# Epoch : 1  ===> Reconstruction Loss = 1846552.3750
# Epoch : 2  ===> Reconstruction Loss = 1043442.3125
# Epoch : 3  ===> Reconstruction Loss = 573828.5000
# Epoch : 4  ===> Reconstruction Loss = 417434.1250
# Epoch : 5  ===> Reconstruction Loss = 351855.0312
# Epoch : 6  ===> Reconstruction Loss = 298600.8125
# Epoch : 7  ===> Reconstruction Loss = 262602.9375
# Epoch : 8  ===> Reconstruction Loss = 236392.6406
# Epoch : 9  ===> Reconstruction Loss = 230369.3906
# Epoch : 10  ===> Reconstruction Loss = 223380.7500
# Epoch : 11  ===> Reconstruction Loss = 222916.5625
# Epoch : 12  ===> Reconstruction Loss = 213193.6719
# Epoch : 13  ===> Reconstruction Loss = 213697.5938
# Epoch : 14  ===> Reconstruction Loss = 211251.8281
# Epoch : 15  ===> Reconstruction Loss = 208385.4688
# Epoch : 16  ===> Reconstruction Loss = 207316.8281
# Epoch : 17  ===> Reconstruction Loss = 211991.2344
# Epoch : 18  ===> Reconstruction Loss = 213665.4219
# Epoch : 19  ===> Reconstruction Loss = 209070.8125
# Epoch : 20  ===> Reconstruction Loss = 207524.2812
# Epoch : 21  ===> Reconstruction Loss = 208528.4688
# Epoch : 22  ===> Reconstruction Loss = 214821.5938
# Epoch : 23  ===> Reconstruction Loss = 212336.0938
# Epoch : 24  ===> Reconstruction Loss = 209122.7812
# Epoch : 25  ===> Reconstruction Loss = 206457.4688
# Epoch : 26  ===> Reconstruction Loss = 203102.9219
# Epoch : 27  ===> Reconstruction Loss = 205595.0156
# Epoch : 28  ===> Reconstruction Loss = 211465.3594
# Epoch : 29  ===> Reconstruction Loss = 204847.8125
# Epoch : 30  ===> Reconstruction Loss = 206813.7188
# Epoch : 31  ===> Reconstruction Loss = 203209.0781
# Epoch : 32  ===> Reconstruction Loss = 204579.9844
# Epoch : 33  ===> Reconstruction Loss = 206697.8750
# Epoch : 34  ===> Reconstruction Loss = 205097.3750
# Epoch : 35  ===> Reconstruction Loss = 208768.2812
# Epoch : 36  ===> Reconstruction Loss = 200122.4688
# Epoch : 37  ===> Reconstruction Loss = 206588.5938
# Epoch : 38  ===> Reconstruction Loss = 208980.4531
# Epoch : 39  ===> Reconstruction Loss = 202190.3906
# Epoch : 40  ===> Reconstruction Loss = 208853.6250
# Epoch : 41  ===> Reconstruction Loss = 205482.9062
# Epoch : 42  ===> Reconstruction Loss = 199379.1719
# Epoch : 43  ===> Reconstruction Loss = 205956.4062
# Epoch : 44  ===> Reconstruction Loss = 208492.3281
# Epoch : 45  ===> Reconstruction Loss = 203918.0156
# Epoch : 46  ===> Reconstruction Loss = 205454.5312
# Epoch : 47  ===> Reconstruction Loss = 204321.4062
# Epoch : 48  ===> Reconstruction Loss = 203329.3125
# Epoch : 49  ===> Reconstruction Loss = 201247.5156
# Epoch : 50  ===> Reconstruction Loss = 200674.7656
#     训练时间: 20.93秒, 内存使用: 55.00MB
#     准确率: 0.6080
#
# === 处理 Batch 2 ===
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 458907712.0000, Classification Loss = 419.9134
# Epoch : 2  ===> Reconstruction Loss = 24061238.0000, Classification Loss = 283.4830
# Epoch : 3  ===> Reconstruction Loss = 15735553.0000, Classification Loss = 351.8476
# Epoch : 4  ===> Reconstruction Loss = 6142085.0000, Classification Loss = 320.6024
# Epoch : 5  ===> Reconstruction Loss = 5238076.5000, Classification Loss = 306.8967
# Epoch : 6  ===> Reconstruction Loss = 2218676.2500, Classification Loss = 291.1167
# Epoch : 7  ===> Reconstruction Loss = 1459792.5000, Classification Loss = 280.1620
# Epoch : 8  ===> Reconstruction Loss = 1219572.5000, Classification Loss = 277.9471
# Epoch : 9  ===> Reconstruction Loss = 1005351.0625, Classification Loss = 272.2833
# Epoch : 10  ===> Reconstruction Loss = 843956.0000, Classification Loss = 267.6785
# Epoch : 11  ===> Reconstruction Loss = 806122.8125, Classification Loss = 259.9742
# Epoch : 12  ===> Reconstruction Loss = 757745.3125, Classification Loss = 264.4892
# Epoch : 13  ===> Reconstruction Loss = 705515.8125, Classification Loss = 261.5266
# Epoch : 14  ===> Reconstruction Loss = 694589.8125, Classification Loss = 260.7742
# Epoch : 15  ===> Reconstruction Loss = 705715.7500, Classification Loss = 261.0501
# Epoch : 16  ===> Reconstruction Loss = 680573.5000, Classification Loss = 262.1155
# Epoch : 17  ===> Reconstruction Loss = 687237.5625, Classification Loss = 262.1579
# Epoch : 18  ===> Reconstruction Loss = 681257.3125, Classification Loss = 261.0147
# Epoch : 19  ===> Reconstruction Loss = 683058.1875, Classification Loss = 260.6525
# Epoch : 20  ===> Reconstruction Loss = 674930.6875, Classification Loss = 260.9094
# Epoch : 21  ===> Reconstruction Loss = 668951.5625, Classification Loss = 260.7476
# Epoch : 22  ===> Reconstruction Loss = 671757.6250, Classification Loss = 259.7759
# Epoch : 23  ===> Reconstruction Loss = 680782.1250, Classification Loss = 258.9805
# Epoch : 24  ===> Reconstruction Loss = 662926.1250, Classification Loss = 259.1162
# Epoch : 25  ===> Reconstruction Loss = 674528.2500, Classification Loss = 259.1586
# Epoch : 26  ===> Reconstruction Loss = 669153.2500, Classification Loss = 260.1966
# Epoch : 27  ===> Reconstruction Loss = 674391.1875, Classification Loss = 259.2379
# Epoch : 28  ===> Reconstruction Loss = 662209.3125, Classification Loss = 260.2843
# Epoch : 29  ===> Reconstruction Loss = 675661.0000, Classification Loss = 260.3243
# Epoch : 30  ===> Reconstruction Loss = 669392.4375, Classification Loss = 260.3073
# Epoch : 31  ===> Reconstruction Loss = 671524.5000, Classification Loss = 260.2507
# Epoch : 32  ===> Reconstruction Loss = 668346.1250, Classification Loss = 259.2028
# Epoch : 33  ===> Reconstruction Loss = 670568.5625, Classification Loss = 258.1693
# Epoch : 34  ===> Reconstruction Loss = 665204.7500, Classification Loss = 256.0762
# Epoch : 35  ===> Reconstruction Loss = 663169.1875, Classification Loss = 255.9312
# Epoch : 36  ===> Reconstruction Loss = 656718.7500, Classification Loss = 253.7748
# Epoch : 37  ===> Reconstruction Loss = 659851.9375, Classification Loss = 252.6128
# Epoch : 38  ===> Reconstruction Loss = 663463.6875, Classification Loss = 251.4287
# Epoch : 39  ===> Reconstruction Loss = 654292.1875, Classification Loss = 248.1538
# Epoch : 40  ===> Reconstruction Loss = 658219.1875, Classification Loss = 244.8797
# Epoch : 41  ===> Reconstruction Loss = 656351.1875, Classification Loss = 243.6172
# Epoch : 42  ===> Reconstruction Loss = 659447.5000, Classification Loss = 244.3277
# Epoch : 43  ===> Reconstruction Loss = 650731.5000, Classification Loss = 238.9814
# Epoch : 44  ===> Reconstruction Loss = 653293.3750, Classification Loss = 237.6456
# Epoch : 45  ===> Reconstruction Loss = 658355.6250, Classification Loss = 234.3049
# Epoch : 46  ===> Reconstruction Loss = 655944.0000, Classification Loss = 230.9453
# ...
# Epoch : 74  ===> Reconstruction Loss = 608493.6250, Classification Loss = 362.0307
# Epoch : 75  ===> Reconstruction Loss = 610413.1250, Classification Loss = 361.8250
# Epoch : 76  ===> Reconstruction Loss = 604545.1875, Classification Loss = 361.6194
# Epoch : 77  ===> Reconstruction Loss = 608093.1875, Classification Loss = 361.4455
# Epoch : 78  ===> Reconstruction Loss = 606463.3125, Classification Loss = 361.2816
# Epoch : 79  ===> Reconstruction Loss = 605487.2500, Classification Loss = 361.1145
# Epoch : 80  ===> Reconstruction Loss = 613987.5000, Classification Loss = 360.9538
# Epoch : 81  ===> Reconstruction Loss = 611631.6875, Classification Loss = 360.8152
# Epoch : 82  ===> Reconstruction Loss = 607952.8750, Classification Loss = 360.6598
# Epoch : 83  ===> Reconstruction Loss = 604882.2500, Classification Loss = 360.5058
# Epoch : 84  ===> Reconstruction Loss = 607718.1250, Classification Loss = 360.3717
# Epoch : 85  ===> Reconstruction Loss = 602462.4375, Classification Loss = 360.2333
# Epoch : 86  ===> Reconstruction Loss = 601717.0625, Classification Loss = 360.1031
# Epoch : 87  ===> Reconstruction Loss = 596461.1875, Classification Loss = 359.9719
# Epoch : 88  ===> Reconstruction Loss = 597449.3125, Classification Loss = 359.8138
# Epoch : 89  ===> Reconstruction Loss = 599795.2500, Classification Loss = 359.6774
# Epoch : 90  ===> Reconstruction Loss = 597144.2500, Classification Loss = 359.5344
# Epoch : 91  ===> Reconstruction Loss = 598790.3750, Classification Loss = 359.4036
# Epoch : 92  ===> Reconstruction Loss = 602101.6875, Classification Loss = 359.2760
# Epoch : 93  ===> Reconstruction Loss = 588393.6875, Classification Loss = 359.1284
# Epoch : 94  ===> Reconstruction Loss = 601781.6250, Classification Loss = 358.9569
# Epoch : 95  ===> Reconstruction Loss = 603030.0000, Classification Loss = 358.7757
# Epoch : 96  ===> Reconstruction Loss = 599868.3125, Classification Loss = 358.6469
# Epoch : 97  ===> Reconstruction Loss = 594919.1250, Classification Loss = 358.5321
# Epoch : 98  ===> Reconstruction Loss = 600405.0000, Classification Loss = 358.4091
# Epoch : 99  ===> Reconstruction Loss = 591575.8125, Classification Loss = 358.2517
# Epoch : 100  ===> Reconstruction Loss = 588729.2500, Classification Loss = 358.0846
# Epoch : 1  ===> Reconstruction Loss = 3001910.0000
# Epoch : 2  ===> Reconstruction Loss = 1637776.2500
# Epoch : 3  ===> Reconstruction Loss = 910640.7500
# Epoch : 4  ===> Reconstruction Loss = 591740.6250
# Epoch : 5  ===> Reconstruction Loss = 414899.8750
# Epoch : 6  ===> Reconstruction Loss = 331234.2500
# Epoch : 7  ===> Reconstruction Loss = 290293.4688
# Epoch : 8  ===> Reconstruction Loss = 268441.9375
# Epoch : 9  ===> Reconstruction Loss = 260236.5312
# Epoch : 10  ===> Reconstruction Loss = 252041.0625
# Epoch : 11  ===> Reconstruction Loss = 241528.2656
# Epoch : 12  ===> Reconstruction Loss = 240519.3750
# Epoch : 13  ===> Reconstruction Loss = 234754.7031
# Epoch : 14  ===> Reconstruction Loss = 237737.5938
# Epoch : 15  ===> Reconstruction Loss = 233229.7969
# Epoch : 16  ===> Reconstruction Loss = 222228.9375
# Epoch : 17  ===> Reconstruction Loss = 225761.1406
# Epoch : 18  ===> Reconstruction Loss = 225819.9062
# Epoch : 19  ===> Reconstruction Loss = 222654.3438
# Epoch : 20  ===> Reconstruction Loss = 225565.7812
# Epoch : 21  ===> Reconstruction Loss = 229643.3125
# Epoch : 22  ===> Reconstruction Loss = 228657.0781
# Epoch : 23  ===> Reconstruction Loss = 226598.7031
# Epoch : 24  ===> Reconstruction Loss = 217870.2812
# Epoch : 25  ===> Reconstruction Loss = 223720.5000
# Epoch : 26  ===> Reconstruction Loss = 216235.0156
# Epoch : 27  ===> Reconstruction Loss = 219529.3594
# Epoch : 28  ===> Reconstruction Loss = 219635.1094
# Epoch : 29  ===> Reconstruction Loss = 217595.1094
# Epoch : 30  ===> Reconstruction Loss = 218618.5312
# Epoch : 31  ===> Reconstruction Loss = 219118.4688
# Epoch : 32  ===> Reconstruction Loss = 218155.0312
# Epoch : 33  ===> Reconstruction Loss = 218823.4219
# Epoch : 34  ===> Reconstruction Loss = 223816.8281
# Epoch : 35  ===> Reconstruction Loss = 215408.6875
# Epoch : 36  ===> Reconstruction Loss = 214456.4531
# Epoch : 37  ===> Reconstruction Loss = 218095.8594
# Epoch : 38  ===> Reconstruction Loss = 219099.3281
# Epoch : 39  ===> Reconstruction Loss = 216960.0781
# Epoch : 40  ===> Reconstruction Loss = 215228.7969
# Epoch : 41  ===> Reconstruction Loss = 216461.5000
# Epoch : 42  ===> Reconstruction Loss = 215665.6250
# Epoch : 43  ===> Reconstruction Loss = 212576.2188
# Epoch : 44  ===> Reconstruction Loss = 221879.3750
# Epoch : 45  ===> Reconstruction Loss = 224150.0000
# Epoch : 46  ===> Reconstruction Loss = 222257.2344
# Epoch : 47  ===> Reconstruction Loss = 216452.5938
# Epoch : 48  ===> Reconstruction Loss = 211630.6406
# Epoch : 49  ===> Reconstruction Loss = 221045.7969
# Epoch : 50  ===> Reconstruction Loss = 217810.2656
#     训练时间: 95.93秒, 内存使用: 89.37MB
#     准确率: 0.6160
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 620940352.0000, Classification Loss = 544.8813
# Epoch : 2  ===> Reconstruction Loss = 24419556.0000, Classification Loss = 291.6590
# Epoch : 3  ===> Reconstruction Loss = 8368676.5000, Classification Loss = 276.6940
# Epoch : 4  ===> Reconstruction Loss = 12648295.0000, Classification Loss = 295.2538
# Epoch : 5  ===> Reconstruction Loss = 5205204.5000, Classification Loss = 305.8504
# Epoch : 6  ===> Reconstruction Loss = 3618222.7500, Classification Loss = 315.9760
# Epoch : 7  ===> Reconstruction Loss = 2039073.2500, Classification Loss = 310.8247
# Epoch : 8  ===> Reconstruction Loss = 1640043.7500, Classification Loss = 302.3383
# Epoch : 9  ===> Reconstruction Loss = 1158153.3750, Classification Loss = 299.2532
# Epoch : 10  ===> Reconstruction Loss = 965672.3125, Classification Loss = 296.1310
# Epoch : 11  ===> Reconstruction Loss = 816347.7500, Classification Loss = 293.3278
# Epoch : 12  ===> Reconstruction Loss = 784955.1250, Classification Loss = 288.9116
# Epoch : 13  ===> Reconstruction Loss = 737181.6875, Classification Loss = 286.1962
# Epoch : 14  ===> Reconstruction Loss = 714526.5000, Classification Loss = 285.6480
# Epoch : 15  ===> Reconstruction Loss = 708317.3750, Classification Loss = 284.0904
# Epoch : 16  ===> Reconstruction Loss = 700953.3125, Classification Loss = 282.8175
# Epoch : 17  ===> Reconstruction Loss = 691432.0625, Classification Loss = 282.2240
# Epoch : 18  ===> Reconstruction Loss = 682952.9375, Classification Loss = 281.1167
# Epoch : 19  ===> Reconstruction Loss = 692059.1875, Classification Loss = 280.3606
# Epoch : 20  ===> Reconstruction Loss = 679561.9375, Classification Loss = 280.3885
# Epoch : 21  ===> Reconstruction Loss = 677757.7500, Classification Loss = 278.0850
# Epoch : 22  ===> Reconstruction Loss = 678671.9375, Classification Loss = 278.9812
# Epoch : 23  ===> Reconstruction Loss = 676802.5625, Classification Loss = 278.8249
# Epoch : 24  ===> Reconstruction Loss = 683939.3750, Classification Loss = 277.7865
# Epoch : 25  ===> Reconstruction Loss = 669492.1250, Classification Loss = 278.6060
# Epoch : 26  ===> Reconstruction Loss = 676831.6250, Classification Loss = 278.6148
# Epoch : 27  ===> Reconstruction Loss = 673186.5000, Classification Loss = 278.5247
# Epoch : 28  ===> Reconstruction Loss = 674537.6250, Classification Loss = 278.4462
# Epoch : 29  ===> Reconstruction Loss = 676966.7500, Classification Loss = 278.3941
# Epoch : 30  ===> Reconstruction Loss = 669736.3125, Classification Loss = 278.2995
# Epoch : 31  ===> Reconstruction Loss = 673434.8750, Classification Loss = 278.1944
# Epoch : 32  ===> Reconstruction Loss = 679261.2500, Classification Loss = 278.0945
# Epoch : 33  ===> Reconstruction Loss = 674324.5000, Classification Loss = 278.0001
# Epoch : 34  ===> Reconstruction Loss = 670018.4375, Classification Loss = 277.8676
# Epoch : 35  ===> Reconstruction Loss = 663568.1250, Classification Loss = 277.7407
# Epoch : 36  ===> Reconstruction Loss = 666698.5625, Classification Loss = 277.6033
# Epoch : 37  ===> Reconstruction Loss = 682128.6250, Classification Loss = 277.4514
# Epoch : 38  ===> Reconstruction Loss = 667848.9375, Classification Loss = 277.2910
# Epoch : 39  ===> Reconstruction Loss = 670969.5000, Classification Loss = 277.1019
# Epoch : 40  ===> Reconstruction Loss = 674954.0000, Classification Loss = 275.9389
# Epoch : 41  ===> Reconstruction Loss = 667511.4375, Classification Loss = 275.7141
# Epoch : 42  ===> Reconstruction Loss = 666806.1250, Classification Loss = 275.5054
# Epoch : 43  ===> Reconstruction Loss = 660105.5625, Classification Loss = 275.2459
# Epoch : 44  ===> Reconstruction Loss = 655237.9375, Classification Loss = 275.0006
# Epoch : 45  ===> Reconstruction Loss = 666791.6250, Classification Loss = 274.7259
# Epoch : 46  ===> Reconstruction Loss = 667150.6250, Classification Loss = 274.4424
# Epoch : 47  ===> Reconstruction Loss = 658495.0625, Classification Loss = 274.1697
# Epoch : 48  ===> Reconstruction Loss = 651426.5625, Classification Loss = 274.8771
# Epoch : 49  ===> Reconstruction Loss = 661485.4375, Classification Loss = 274.5899
# Epoch : 50  ===> Reconstruction Loss = 667724.7500, Classification Loss = 274.3002
# Epoch : 51  ===> Reconstruction Loss = 649177.0625, Classification Loss = 273.9753
# Epoch : 52  ===> Reconstruction Loss = 649967.3750, Classification Loss = 273.7154
# Epoch : 53  ===> Reconstruction Loss = 656749.0625, Classification Loss = 273.4014
# Epoch : 54  ===> Reconstruction Loss = 657787.3750, Classification Loss = 274.1569
# Epoch : 55  ===> Reconstruction Loss = 647614.6875, Classification Loss = 273.8692
# Epoch : 56  ===> Reconstruction Loss = 658922.8125, Classification Loss = 271.6451
# Epoch : 57  ===> Reconstruction Loss = 648633.6875, Classification Loss = 271.4102
# Epoch : 58  ===> Reconstruction Loss = 657638.6875, Classification Loss = 270.2084
# Epoch : 59  ===> Reconstruction Loss = 648096.1250, Classification Loss = 269.9790
# Epoch : 60  ===> Reconstruction Loss = 658116.8750, Classification Loss = 269.8048
# Epoch : 61  ===> Reconstruction Loss = 634907.8125, Classification Loss = 269.6309
# Epoch : 62  ===> Reconstruction Loss = 654752.8125, Classification Loss = 269.4504
# Epoch : 63  ===> Reconstruction Loss = 640757.2500, Classification Loss = 269.3275
# Epoch : 64  ===> Reconstruction Loss = 650838.4375, Classification Loss = 269.1733
# Epoch : 65  ===> Reconstruction Loss = 645706.7500, Classification Loss = 268.0510
# Epoch : 66  ===> Reconstruction Loss = 648930.4375, Classification Loss = 267.8980
# Epoch : 67  ===> Reconstruction Loss = 647111.0625, Classification Loss = 267.8208
# Epoch : 68  ===> Reconstruction Loss = 659379.8125, Classification Loss = 266.6418
# Epoch : 69  ===> Reconstruction Loss = 642939.3125, Classification Loss = 267.5291
# Epoch : 70  ===> Reconstruction Loss = 635311.0000, Classification Loss = 266.4255
# Epoch : 71  ===> Reconstruction Loss = 641349.0000, Classification Loss = 266.3044
# Epoch : 72  ===> Reconstruction Loss = 641405.5000, Classification Loss = 266.1559
# Epoch : 73  ===> Reconstruction Loss = 639281.2500, Classification Loss = 266.0621
# Epoch : 74  ===> Reconstruction Loss = 627723.4375, Classification Loss = 265.9037
# Epoch : 75  ===> Reconstruction Loss = 641633.1250, Classification Loss = 265.7448
# Epoch : 76  ===> Reconstruction Loss = 639771.5625, Classification Loss = 265.6289
# Epoch : 77  ===> Reconstruction Loss = 646070.8750, Classification Loss = 265.4377
# Epoch : 78  ===> Reconstruction Loss = 626431.0000, Classification Loss = 265.3281
# Epoch : 79  ===> Reconstruction Loss = 632336.6250, Classification Loss = 265.1723
# Epoch : 80  ===> Reconstruction Loss = 642443.5625, Classification Loss = 265.0556
# Epoch : 81  ===> Reconstruction Loss = 646708.3125, Classification Loss = 264.9216
# Epoch : 82  ===> Reconstruction Loss = 634037.6250, Classification Loss = 264.8299
# Epoch : 83  ===> Reconstruction Loss = 633601.1875, Classification Loss = 264.6859
# Epoch : 84  ===> Reconstruction Loss = 641944.3125, Classification Loss = 264.5829
# Epoch : 85  ===> Reconstruction Loss = 632217.9375, Classification Loss = 263.4361
# Epoch : 86  ===> Reconstruction Loss = 633522.3125, Classification Loss = 263.3258
# Epoch : 87  ===> Reconstruction Loss = 634313.1875, Classification Loss = 263.2077
# Epoch : 88  ===> Reconstruction Loss = 629227.8125, Classification Loss = 263.0610
# Epoch : 89  ===> Reconstruction Loss = 628352.6875, Classification Loss = 263.9609
# Epoch : 90  ===> Reconstruction Loss = 631870.3125, Classification Loss = 263.8368
# Epoch : 91  ===> Reconstruction Loss = 635181.3750, Classification Loss = 263.7505
# Epoch : 92  ===> Reconstruction Loss = 622286.1875, Classification Loss = 263.6068
# Epoch : 93  ===> Reconstruction Loss = 627269.6250, Classification Loss = 263.5247
# Epoch : 94  ===> Reconstruction Loss = 636419.1250, Classification Loss = 263.3708
# Epoch : 95  ===> Reconstruction Loss = 629363.5000, Classification Loss = 263.2795
# Epoch : 96  ===> Reconstruction Loss = 632957.5625, Classification Loss = 263.1487
# Epoch : 97  ===> Reconstruction Loss = 627040.6875, Classification Loss = 263.0078
# Epoch : 98  ===> Reconstruction Loss = 618451.5625, Classification Loss = 262.8970
# Epoch : 99  ===> Reconstruction Loss = 632143.1250, Classification Loss = 262.7697
# Epoch : 100  ===> Reconstruction Loss = 620866.5000, Classification Loss = 262.6252
# Epoch : 1  ===> Reconstruction Loss = 1309506.2500
# Epoch : 2  ===> Reconstruction Loss = 664875.7500
# Epoch : 3  ===> Reconstruction Loss = 466690.9375
# Epoch : 4  ===> Reconstruction Loss = 332241.0625
# Epoch : 5  ===> Reconstruction Loss = 261947.5625
# Epoch : 6  ===> Reconstruction Loss = 233277.0625
# Epoch : 7  ===> Reconstruction Loss = 213321.5938
# Epoch : 8  ===> Reconstruction Loss = 206928.9219
# Epoch : 9  ===> Reconstruction Loss = 197817.5781
# Epoch : 10  ===> Reconstruction Loss = 188122.7188
# Epoch : 11  ===> Reconstruction Loss = 186272.8281
# Epoch : 12  ===> Reconstruction Loss = 187158.7031
# Epoch : 13  ===> Reconstruction Loss = 191761.5469
# Epoch : 14  ===> Reconstruction Loss = 185769.5156
# Epoch : 15  ===> Reconstruction Loss = 184226.2969
# Epoch : 16  ===> Reconstruction Loss = 180787.0156
# Epoch : 17  ===> Reconstruction Loss = 179845.2188
# Epoch : 18  ===> Reconstruction Loss = 185832.9531
# Epoch : 19  ===> Reconstruction Loss = 177374.0938
# Epoch : 20  ===> Reconstruction Loss = 185299.4219
# Epoch : 21  ===> Reconstruction Loss = 180706.6719
# Epoch : 22  ===> Reconstruction Loss = 181776.5469
# Epoch : 23  ===> Reconstruction Loss = 181039.8750
# Epoch : 24  ===> Reconstruction Loss = 182157.6406
# Epoch : 25  ===> Reconstruction Loss = 184489.3594
# Epoch : 26  ===> Reconstruction Loss = 176382.5156
# Epoch : 27  ===> Reconstruction Loss = 179740.9219
# Epoch : 28  ===> Reconstruction Loss = 175787.8125
# Epoch : 29  ===> Reconstruction Loss = 177466.4688
# Epoch : 30  ===> Reconstruction Loss = 180214.1719
# Epoch : 31  ===> Reconstruction Loss = 180603.5312
# Epoch : 32  ===> Reconstruction Loss = 179765.6094
# Epoch : 33  ===> Reconstruction Loss = 177806.1250
# Epoch : 34  ===> Reconstruction Loss = 175013.0781
# Epoch : 35  ===> Reconstruction Loss = 179065.5469
# Epoch : 36  ===> Reconstruction Loss = 178651.4062
# Epoch : 37  ===> Reconstruction Loss = 173970.2656
# Epoch : 38  ===> Reconstruction Loss = 179036.1875
# Epoch : 39  ===> Reconstruction Loss = 180535.4062
# Epoch : 40  ===> Reconstruction Loss = 182072.0781
# Epoch : 41  ===> Reconstruction Loss = 179305.6250
# Epoch : 42  ===> Reconstruction Loss = 181076.3281
# Epoch : 43  ===> Reconstruction Loss = 178467.3750
# Epoch : 44  ===> Reconstruction Loss = 179331.2969
# Epoch : 45  ===> Reconstruction Loss = 182228.2969
# Epoch : 46  ===> Reconstruction Loss = 180083.5469
# Epoch : 47  ===> Reconstruction Loss = 173903.2812
# Epoch : 48  ===> Reconstruction Loss = 178460.0000
# Epoch : 49  ===> Reconstruction Loss = 174875.8438
# Epoch : 50  ===> Reconstruction Loss = 182847.9531
#     训练时间: 89.61秒, 内存使用: 66.81MB
#     准确率: 0.6880
#
# === 所有批次和折次处理完成 ===
# 结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/cpmnets_cross_validation_results-mid.csv
