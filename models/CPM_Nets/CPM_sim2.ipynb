# %%
import numpy as np
import pandas as pd
from util.util import DataSet
from util.get_sn import get_sn
from util.model import CPMNets
import util.classfiy as classfiy
from sklearn.model_selection import StratifiedKFold
import os
import warnings
import time
import psutil
import math
from util.utils2 import evaluate_model
from numpy.random import shuffle
# Out:
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /public/home/yilab5/miniforge3/envs/tf112/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 禁用警告
warnings.filterwarnings('ignore')

# %%
# 实验配置
scenario = 1
signal_prop = "high"
signal_level = "high"
ratio = 0.75
Normal = 0
n_folds = 4  # 四折交叉验证
num_class = 3  # 假设有3个类别

# 初始化结果记录表
metrics = {
    "Batch": [], "Fold": [], "Accuracy": [], "F1 Macro": [], "F1 Micro": [], "F1 Weighted": [],
    "Precision Macro": [], "Precision Micro": [], "Precision Weighted": [],
    "Recall Macro": [], "Recall Micro": [], "Recall Weighted": [],
    # "AUC Macro": [], "AUC Micro": [], "AUC Weighted": [],
    # "AUPR Macro": [], "AUPR Micro": [], "AUPR Weighted": [], 
    "Cohen Kappa": [], "Training_time": [], "CPU_memory_allocated": []
}
all_predictions_df = pd.DataFrame()

# %%
# 主循环：处理每个batch (1-25)
for batch_num in range(1, 26):
    print(f"\n=== 处理 Batch {batch_num} ===")
    
    # 构建数据路径
    sim_path = f"/public/home/yilab5/Master/methodology/simdata2/scenario1/k-3/prop-high/level-{signal_level}/sim{batch_num}"

    # s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-mrna.csv

    try:
        # 加载omics数据
        omics1 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-mrna.csv", delimiter=',', skiprows=1).T
        omics2 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-meth.csv", delimiter=',', skiprows=1).T
        omics3 = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-prot.csv", delimiter=',', skiprows=1).T

        labels = np.loadtxt(f"{sim_path}/s{scenario}-k3-{signal_prop}-{signal_level}-batch{batch_num}-label.csv",
                             delimiter=',', skiprows=1).reshape(-1, 1).astype(int)
        
        if min(labels)[0] == 0:
            labels = labels + 1
        # omics1 = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata2/scenario1/k-3/prop-high/level-high/sim{batch_num}/s1-k3-high-high-batch{batch_num}-mrna.csv", 
        #            delimiter=',', skiprows=1).T
        # omics2 = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata2/scenario1/k-3/prop-high/level-high/sim{batch_num}/s1-k3-high-high-batch{batch_num}-meth.csv", 
        #            delimiter=',', skiprows=1).T
        # omics3 = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata2/scenario1/k-3/prop-high/level-high/sim{batch_num}/s1-k3-high-high-batch{batch_num}-prot.csv", 
        #            delimiter=',', skiprows=1).T

        # labels = np.loadtxt(f"/public/home/yilab5/Master/methodology/simdata2/scenario1/k-3/prop-high/level-high/sim{batch_num}/s1-k3-high-high-batch{batch_num}-label.csv", 
        #            delimiter=',', skiprows=1).reshape(-1, 1).astype(int)

        # 创建数据字典
        n_views = 3
        X = np.zeros((1, n_views), dtype=object)
        X[0, 0] = omics1.astype(np.float32)
        X[0, 1] = omics2.astype(np.float32)
        X[0, 2] = omics3.astype(np.float32)
        
        data = {'X': X, 'gt': labels}
        
        # 准备交叉验证
        view_number = data['X'].shape[1]
        X_views = np.split(data['X'], view_number, axis=1)
        
        # 提取视图数据
        view_data = []
        for v in range(view_number):
            view_data.append(X_views[v][0][0].transpose())
        
        # 创建分层K折交叉验证
        skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
        
        # 对每一折进行交叉验证
        for fold, (train_index, test_index) in enumerate(skf.split(view_data[0], labels.flatten())):
            print(f"  - 处理第 {fold+1} 折")
            
            # 初始化训练集和测试集
            X_train = []
            X_test = []
            labels_train = labels[train_index]
            labels_test = labels[test_index]
            
            # 处理每个视图的数据
            for v_num in range(view_number):
                # 提取当前视图的训练集和测试集
                X_train_view = view_data[v_num][train_index]
                X_test_view = view_data[v_num][test_index]
                
                # 归一化处理
                if Normal == 1:
                    # 计算训练集的统计量
                    m = np.mean(X_train_view, axis=0)
                    mx = np.max(X_train_view, axis=0)
                    mn = np.min(X_train_view, axis=0)
                    range_val = mx - mn
                    range_val[range_val == 0] = 1  # 避免除零错误
                    
                    # 归一化训练集和测试集
                    X_train_view = (X_train_view - m) / range_val
                    X_test_view = (X_test_view - m) / range_val
                
                X_train.append(X_train_view)
                X_test.append(X_test_view)
            
            # 创建数据集对象
            traindata = DataSet(X_train, view_number, np.array(labels_train))
            testdata = DataSet(X_test, view_number, np.array(labels_test))
            trainData, testData, view_num = traindata, testdata, view_number
            
            # 准备模型参数
            outdim_size = [trainData.data[str(i)].shape[1] for i in range(view_num)]
            layer_size = [[150, outdim_size[i]] for i in range(view_num)]
            
            # 生成Sn（缺失模式矩阵）
            n_total = trainData.num_examples + testData.num_examples
            Sn = get_sn(view_num, n_total, 0)  # 缺失率为0
            Sn_train = Sn[np.arange(trainData.num_examples)]
            Sn_test = Sn[np.arange(testData.num_examples) + trainData.num_examples]
            
            # 模型参数
            lsd_dim = 128
            lamb = 1.
            # epoch = [10, 10]
            epoch = [50, 50]
            learning_rate = [0.01, 0.01]
            
            # 记录训练开始时间和内存
            start_time = time.time()
            # 获取当前进程
            process = psutil.Process(os.getpid())
            # mem_before = psutil.virtual_memory().used
            mem_before = process.memory_info().rss
            # mem_before = 0
            # 创建并训练模型
            model = CPMNets(view_num, trainData.num_examples, testData.num_examples,layer_size, lsd_dim, learning_rate, lamb)
            
            model.train(trainData.data, Sn_train, trainData.labels.reshape(trainData.num_examples), epoch[0])
            H_train = model.get_h_train()
            
            model.test(testData.data, Sn_test, testData.labels.reshape(testData.num_examples), epoch[1])
            H_test = model.get_h_test()
            
            # 记录训练结束时间和内存
            end_time = time.time()
            # mem_after = psutil.virtual_memory().used

            mem_after = process.memory_info().rss
            training_time = end_time - start_time
            cpu_memory_allocated = mem_after - mem_before
            
            # 预测和评估
            label_pred, label_prob = classfiy.ave(H_train, H_test, trainData.labels)
            scores = evaluate_model(testData.labels, label_pred, label_prob, num_class)
            
            # 记录结果
            metrics["Batch"].append(batch_num)
            metrics["Fold"].append(fold+1)
            metrics["Training_time"].append(training_time)
            metrics["CPU_memory_allocated"].append(cpu_memory_allocated)
            
            # 添加评估指标
            for key in scores:
                if key in metrics:
                    metrics[key].append(scores[key])
                    # 创建当前批次和折次的预测结果 DataFrame
            fold_predictions = pd.DataFrame({
                "Batch": [batch_num] * len(test_index),
                "Fold": [fold+1] * len(test_index),
                "True_Label": testData.labels.flatten(),
                "Pred_Label": label_pred,
            })
            
            # 添加每个类别的概率列
            for i in range(label_prob.shape[1]):
                fold_predictions[f"Prob_Class_{i}"] = np.round(label_prob[:, i], 4)
            
            # 将当前折次的预测结果添加到总 DataFrame
            all_predictions_df = pd.concat([all_predictions_df, fold_predictions], ignore_index=True)

            print(f"    训练时间: {training_time:.2f}秒, 内存使用: {cpu_memory_allocated/1024/1024:.2f}MB")
            print(f"    准确率: {scores['Accuracy']:.4f}")
        
    except Exception as e:
        print(f"处理 Batch {batch_num} 时出错: {str(e)}")
        continue

# 保存结果到DataFrame
metrics_df = pd.DataFrame(metrics)

# 保存到CSV文件
output_dir = "/public/home/yilab5/Master/methodology/result/result_CPM/res-simdata2"
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, "cpmnets_cross_validation_results-high.csv")
metrics_df.to_csv(output_path, index=False)
# 保存所有预测结果到另一个 CSV

predictions_path = os.path.join(output_dir, "cpmnets_all_predictions-high.csv")
all_predictions_df.to_csv(predictions_path, index=False)

print("\n=== 所有批次和折次处理完成 ===")
print(f"结果已保存至: {output_path}")
# Out:
# === 处理 Batch 1 ===
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 89195.2031, Classification Loss = 279.6752
# Epoch : 2  ===> Reconstruction Loss = 62954.1055, Classification Loss = 236.8226
# Epoch : 3  ===> Reconstruction Loss = 53773.5234, Classification Loss = 211.4652
# Epoch : 4  ===> Reconstruction Loss = 46523.4609, Classification Loss = 189.3281
# Epoch : 5  ===> Reconstruction Loss = 41392.4492, Classification Loss = 155.1659
# Epoch : 6  ===> Reconstruction Loss = 36990.0547, Classification Loss = 118.1374
# Epoch : 7  ===> Reconstruction Loss = 33788.6328, Classification Loss = 81.2089
# Epoch : 8  ===> Reconstruction Loss = 30564.5078, Classification Loss = 52.5948
# Epoch : 9  ===> Reconstruction Loss = 27829.3535, Classification Loss = 40.1152
# Epoch : 10  ===> Reconstruction Loss = 26629.7969, Classification Loss = 35.7648
# Epoch : 11  ===> Reconstruction Loss = 24864.7344, Classification Loss = 28.5873
# Epoch : 12  ===> Reconstruction Loss = 24129.7266, Classification Loss = 24.4259
# Epoch : 13  ===> Reconstruction Loss = 22896.3398, Classification Loss = 14.3058
# Epoch : 14  ===> Reconstruction Loss = 22170.8555, Classification Loss = 13.2343
# Epoch : 15  ===> Reconstruction Loss = 22199.7227, Classification Loss = 13.1918
# Epoch : 16  ===> Reconstruction Loss = 20839.5820, Classification Loss = 14.1585
# Epoch : 17  ===> Reconstruction Loss = 20847.6465, Classification Loss = 12.1243
# Epoch : 18  ===> Reconstruction Loss = 20284.1914, Classification Loss = 10.1021
# Epoch : 19  ===> Reconstruction Loss = 19709.2695, Classification Loss = 7.0856
# Epoch : 20  ===> Reconstruction Loss = 19718.8320, Classification Loss = 7.0748
# Epoch : 21  ===> Reconstruction Loss = 19179.0117, Classification Loss = 7.0669
# Epoch : 22  ===> Reconstruction Loss = 19639.5781, Classification Loss = 6.0569
# Epoch : 23  ===> Reconstruction Loss = 18541.9121, Classification Loss = 5.0503
# Epoch : 24  ===> Reconstruction Loss = 18672.1582, Classification Loss = 5.0423
# Epoch : 25  ===> Reconstruction Loss = 19109.3945, Classification Loss = 4.0333
# Epoch : 26  ===> Reconstruction Loss = 18936.4297, Classification Loss = 5.0321
# Epoch : 27  ===> Reconstruction Loss = 18660.1094, Classification Loss = 4.0316
# Epoch : 28  ===> Reconstruction Loss = 19091.5762, Classification Loss = 4.0307
# Epoch : 29  ===> Reconstruction Loss = 18541.3086, Classification Loss = 3.0258
# Epoch : 30  ===> Reconstruction Loss = 18419.7148, Classification Loss = 3.0255
# Epoch : 31  ===> Reconstruction Loss = 18211.7480, Classification Loss = 4.0282
# Epoch : 32  ===> Reconstruction Loss = 18404.8730, Classification Loss = 2.0241
# Epoch : 33  ===> Reconstruction Loss = 18522.4785, Classification Loss = 2.0218
# Epoch : 34  ===> Reconstruction Loss = 17511.3730, Classification Loss = 2.0217
# Epoch : 35  ===> Reconstruction Loss = 18142.4023, Classification Loss = 2.0205
# Epoch : 36  ===> Reconstruction Loss = 18173.3730, Classification Loss = 3.0184
# Epoch : 37  ===> Reconstruction Loss = 17918.7617, Classification Loss = 2.0148
# Epoch : 38  ===> Reconstruction Loss = 18106.3574, Classification Loss = 2.0132
# Epoch : 39  ===> Reconstruction Loss = 17880.6270, Classification Loss = 1.0125
# Epoch : 40  ===> Reconstruction Loss = 18030.9863, Classification Loss = 2.0098
# Epoch : 41  ===> Reconstruction Loss = 17883.7266, Classification Loss = 3.0063
# Epoch : 42  ===> Reconstruction Loss = 17803.3867, Classification Loss = 1.0048
# Epoch : 43  ===> Reconstruction Loss = 17247.3652, Classification Loss = 2.0046
# Epoch : 44  ===> Reconstruction Loss = 18305.2695, Classification Loss = 1.0034
# Epoch : 45  ===> Reconstruction Loss = 18174.4258, Classification Loss = 1.0018
# Epoch : 46  ===> Reconstruction Loss = 17391.8691, Classification Loss = 0.0000
# Epoch : 47  ===> Reconstruction Loss = 17835.5078, Classification Loss = 0.0000
# Epoch : 48  ===> Reconstruction Loss = 17568.5312, Classification Loss = 0.0000
# Epoch : 49  ===> Reconstruction Loss = 18159.5430, Classification Loss = 1.0010
# Epoch : 50  ===> Reconstruction Loss = 17523.7148, Classification Loss = 0.0000
# Epoch : 51  ===> Reconstruction Loss = 17468.0488, Classification Loss = 0.0000
# Epoch : 52  ===> Reconstruction Loss = 17898.4805, Classification Loss = 3.0032
# Epoch : 53  ===> Reconstruction Loss = 18536.1523, Classification Loss = 2.0005
# Epoch : 54  ===> Reconstruction Loss = 17948.2051, Classification Loss = 1.0007
# Epoch : 55  ===> Reconstruction Loss = 17822.0352, Classification Loss = 2.0029
# Epoch : 56  ===> Reconstruction Loss = 17353.9102, Classification Loss = 3.0018
# Epoch : 57  ===> Reconstruction Loss = 17260.7910, Classification Loss = 0.0000
# Epoch : 58  ===> Reconstruction Loss = 17666.0039, Classification Loss = 0.0000
# Epoch : 59  ===> Reconstruction Loss = 17859.1562, Classification Loss = 1.0009
# Epoch : 60  ===> Reconstruction Loss = 17788.3750, Classification Loss = 1.0001
# Epoch : 61  ===> Reconstruction Loss = 17943.2520, Classification Loss = 1.0028
# Epoch : 62  ===> Reconstruction Loss = 18069.9863, Classification Loss = 1.0016
# Epoch : 63  ===> Reconstruction Loss = 18125.1758, Classification Loss = 2.0016
# Epoch : 64  ===> Reconstruction Loss = 17967.6289, Classification Loss = 2.0014
# Epoch : 65  ===> Reconstruction Loss = 17897.5469, Classification Loss = 3.0008
# Epoch : 66  ===> Reconstruction Loss = 17918.5605, Classification Loss = 0.0000
# Epoch : 67  ===> Reconstruction Loss = 17991.2031, Classification Loss = 1.0001
# Epoch : 68  ===> Reconstruction Loss = 17599.3164, Classification Loss = 0.0000
# Epoch : 69  ===> Reconstruction Loss = 17643.9648, Classification Loss = 0.0000
# Epoch : 70  ===> Reconstruction Loss = 17543.6738, Classification Loss = 0.0000
# Epoch : 71  ===> Reconstruction Loss = 17634.5664, Classification Loss = 0.0000
# Epoch : 72  ===> Reconstruction Loss = 17854.1328, Classification Loss = 0.0000
# Epoch : 73  ===> Reconstruction Loss = 17615.0098, Classification Loss = 1.0003
# Epoch : 74  ===> Reconstruction Loss = 17219.8672, Classification Loss = 1.0002
# Epoch : 75  ===> Reconstruction Loss = 17624.2910, Classification Loss = 1.0016
# Epoch : 76  ===> Reconstruction Loss = 17948.9492, Classification Loss = 1.0015
# Epoch : 77  ===> Reconstruction Loss = 17875.1719, Classification Loss = 2.0027
# Epoch : 78  ===> Reconstruction Loss = 18043.7734, Classification Loss = 5.0075
# Epoch : 79  ===> Reconstruction Loss = 18347.1094, Classification Loss = 4.0101
# Epoch : 80  ===> Reconstruction Loss = 17596.8926, Classification Loss = 3.0056
# Epoch : 81  ===> Reconstruction Loss = 17974.0801, Classification Loss = 2.0037
# Epoch : 82  ===> Reconstruction Loss = 18494.2891, Classification Loss = 0.0000
# Epoch : 83  ===> Reconstruction Loss = 17997.7891, Classification Loss = 1.0019
# Epoch : 84  ===> Reconstruction Loss = 18105.4219, Classification Loss = 2.0016
# Epoch : 85  ===> Reconstruction Loss = 17157.2852, Classification Loss = 0.0000
# Epoch : 86  ===> Reconstruction Loss = 17704.1328, Classification Loss = 1.0006
# Epoch : 87  ===> Reconstruction Loss = 18031.9590, Classification Loss = 3.0022
# Epoch : 88  ===> Reconstruction Loss = 18081.8555, Classification Loss = 0.0000
# Epoch : 89  ===> Reconstruction Loss = 18003.0625, Classification Loss = 1.0028
# Epoch : 90  ===> Reconstruction Loss = 18379.9258, Classification Loss = 1.0032
# Epoch : 91  ===> Reconstruction Loss = 18054.1582, Classification Loss = 1.0002
# Epoch : 92  ===> Reconstruction Loss = 18008.4844, Classification Loss = 1.0001
# Epoch : 93  ===> Reconstruction Loss = 17513.6797, Classification Loss = 1.0016
# Epoch : 94  ===> Reconstruction Loss = 18041.9531, Classification Loss = 0.0000
# Epoch : 95  ===> Reconstruction Loss = 17790.4004, Classification Loss = 0.0000
# Epoch : 96  ===> Reconstruction Loss = 17930.2207, Classification Loss = 1.0003
# Epoch : 97  ===> Reconstruction Loss = 17896.0273, Classification Loss = 0.0000
# Epoch : 98  ===> Reconstruction Loss = 17167.4414, Classification Loss = 0.0000
# Epoch : 99  ===> Reconstruction Loss = 17470.7227, Classification Loss = 1.0011
# Epoch : 100  ===> Reconstruction Loss = 18566.6113, Classification Loss = 1.0012
# Epoch : 1  ===> Reconstruction Loss = 19546.1836
# Epoch : 2  ===> Reconstruction Loss = 14359.9824
# Epoch : 3  ===> Reconstruction Loss = 11638.1475
# Epoch : 4  ===> Reconstruction Loss = 9853.4023
# Epoch : 5  ===> Reconstruction Loss = 9015.5068
# Epoch : 6  ===> Reconstruction Loss = 8360.7773
# Epoch : 7  ===> Reconstruction Loss = 7809.4868
# Epoch : 8  ===> Reconstruction Loss = 7440.9102
# Epoch : 9  ===> Reconstruction Loss = 7592.2012
# Epoch : 10  ===> Reconstruction Loss = 7691.7935
# Epoch : 11  ===> Reconstruction Loss = 7126.0049
# Epoch : 12  ===> Reconstruction Loss = 6892.0942
# Epoch : 13  ===> Reconstruction Loss = 7163.7812
# Epoch : 14  ===> Reconstruction Loss = 7093.3755
# Epoch : 15  ===> Reconstruction Loss = 7025.7329
# Epoch : 16  ===> Reconstruction Loss = 7128.1279
# Epoch : 17  ===> Reconstruction Loss = 7105.3228
# Epoch : 18  ===> Reconstruction Loss = 6933.4102
# Epoch : 19  ===> Reconstruction Loss = 6901.6982
# Epoch : 20  ===> Reconstruction Loss = 7039.3203
# Epoch : 21  ===> Reconstruction Loss = 7052.4424
# Epoch : 22  ===> Reconstruction Loss = 6900.0591
# Epoch : 23  ===> Reconstruction Loss = 7132.4858
# Epoch : 24  ===> Reconstruction Loss = 7066.7964
# Epoch : 25  ===> Reconstruction Loss = 7165.7334
# Epoch : 26  ===> Reconstruction Loss = 6708.5498
# Epoch : 27  ===> Reconstruction Loss = 7043.2363
# Epoch : 28  ===> Reconstruction Loss = 6883.1226
# Epoch : 29  ===> Reconstruction Loss = 7566.7729
# Epoch : 30  ===> Reconstruction Loss = 7327.9521
# Epoch : 31  ===> Reconstruction Loss = 6961.6807
# Epoch : 32  ===> Reconstruction Loss = 6966.5156
# Epoch : 33  ===> Reconstruction Loss = 7005.1152
# Epoch : 34  ===> Reconstruction Loss = 6921.9707
# Epoch : 35  ===> Reconstruction Loss = 7309.1562
# Epoch : 36  ===> Reconstruction Loss = 6843.7188
# Epoch : 37  ===> Reconstruction Loss = 7466.2065
# Epoch : 38  ===> Reconstruction Loss = 7184.6533
# Epoch : 39  ===> Reconstruction Loss = 6721.7021
# Epoch : 40  ===> Reconstruction Loss = 7457.8486
# Epoch : 41  ===> Reconstruction Loss = 7416.8086
# Epoch : 42  ===> Reconstruction Loss = 6962.3789
# Epoch : 43  ===> Reconstruction Loss = 6728.3359
# Epoch : 44  ===> Reconstruction Loss = 6912.1421
# Epoch : 45  ===> Reconstruction Loss = 7116.4600
# Epoch : 46  ===> Reconstruction Loss = 6894.4541
# Epoch : 47  ===> Reconstruction Loss = 7157.2944
# Epoch : 48  ===> Reconstruction Loss = 7125.2769
# Epoch : 49  ===> Reconstruction Loss = 6843.8423
# Epoch : 50  ===> Reconstruction Loss = 7227.7461
#     训练时间: 14.76秒, 内存使用: 38.95MB
#     准确率: 0.9920
#   - 处理第 2 折
# Epoch : 1  ===> Reconstruction Loss = 89521.4844, Classification Loss = 255.2832
# Epoch : 2  ===> Reconstruction Loss = 62785.3516, Classification Loss = 235.8884
# Epoch : 3  ===> Reconstruction Loss = 53151.0117, Classification Loss = 178.7072
# Epoch : 4  ===> Reconstruction Loss = 46403.8672, Classification Loss = 133.9118
# Epoch : 5  ===> Reconstruction Loss = 40622.3984, Classification Loss = 109.6873
# Epoch : 6  ===> Reconstruction Loss = 35291.3203, Classification Loss = 85.1784
# Epoch : 7  ===> Reconstruction Loss = 32841.1445, Classification Loss = 70.7262
# Epoch : 8  ===> Reconstruction Loss = 29321.1055, Classification Loss = 56.2882
# Epoch : 9  ===> Reconstruction Loss = 27768.0098, Classification Loss = 41.9898
# Epoch : 10  ===> Reconstruction Loss = 26345.0254, Classification Loss = 32.8154
# Epoch : 11  ===> Reconstruction Loss = 24576.5586, Classification Loss = 32.6560
# Epoch : 12  ===> Reconstruction Loss = 23388.0469, Classification Loss = 28.5362
# Epoch : 13  ===> Reconstruction Loss = 22950.6797, Classification Loss = 27.4380
# Epoch : 14  ===> Reconstruction Loss = 22104.2109, Classification Loss = 25.3431
# Epoch : 15  ===> Reconstruction Loss = 20754.1855, Classification Loss = 21.2470
# Epoch : 16  ===> Reconstruction Loss = 20543.0898, Classification Loss = 15.1856
# Epoch : 17  ===> Reconstruction Loss = 20730.8594, Classification Loss = 14.1372
# Epoch : 18  ===> Reconstruction Loss = 20580.7773, Classification Loss = 10.0970
# Epoch : 19  ===> Reconstruction Loss = 19918.9590, Classification Loss = 7.0678
# Epoch : 20  ===> Reconstruction Loss = 19738.8242, Classification Loss = 5.0545
# Epoch : 21  ===> Reconstruction Loss = 19729.9668, Classification Loss = 6.0463
# Epoch : 22  ===> Reconstruction Loss = 19013.2617, Classification Loss = 5.0420
# Epoch : 23  ===> Reconstruction Loss = 18796.5625, Classification Loss = 7.0472
# Epoch : 24  ===> Reconstruction Loss = 18765.7969, Classification Loss = 7.0514
# Epoch : 25  ===> Reconstruction Loss = 18844.1836, Classification Loss = 7.0512
# Epoch : 26  ===> Reconstruction Loss = 18692.8359, Classification Loss = 7.0439
# Epoch : 27  ===> Reconstruction Loss = 17870.4531, Classification Loss = 4.0344
# Epoch : 28  ===> Reconstruction Loss = 18545.0742, Classification Loss = 4.0262
# Epoch : 29  ===> Reconstruction Loss = 17641.4258, Classification Loss = 2.0267
# Epoch : 30  ===> Reconstruction Loss = 18160.1055, Classification Loss = 5.0313
# Epoch : 31  ===> Reconstruction Loss = 17730.1836, Classification Loss = 3.0287
# Epoch : 32  ===> Reconstruction Loss = 18519.1875, Classification Loss = 4.0262
# Epoch : 33  ===> Reconstruction Loss = 18421.3652, Classification Loss = 2.0229
# Epoch : 34  ===> Reconstruction Loss = 18240.0664, Classification Loss = 3.0201
# Epoch : 35  ===> Reconstruction Loss = 17656.7305, Classification Loss = 3.0188
# Epoch : 36  ===> Reconstruction Loss = 18039.0410, Classification Loss = 3.0170
# Epoch : 37  ===> Reconstruction Loss = 18123.9688, Classification Loss = 4.0151
# Epoch : 38  ===> Reconstruction Loss = 17952.1309, Classification Loss = 2.0121
# Epoch : 39  ===> Reconstruction Loss = 17863.6562, Classification Loss = 4.0137
# Epoch : 40  ===> Reconstruction Loss = 18096.7363, Classification Loss = 4.0124
# Epoch : 41  ===> Reconstruction Loss = 17469.1543, Classification Loss = 1.0080
# Epoch : 42  ===> Reconstruction Loss = 17702.2695, Classification Loss = 3.0057
# Epoch : 43  ===> Reconstruction Loss = 17737.2246, Classification Loss = 4.0033
# Epoch : 44  ===> Reconstruction Loss = 17041.3887, Classification Loss = 4.0026
# Epoch : 45  ===> Reconstruction Loss = 17634.8711, Classification Loss = 1.0009
# Epoch : 46  ===> Reconstruction Loss = 17523.0195, Classification Loss = 0.0000
# Epoch : 47  ===> Reconstruction Loss = 17941.9902, Classification Loss = 0.0000
# Epoch : 48  ===> Reconstruction Loss = 17701.3203, Classification Loss = 0.0000
# Epoch : 49  ===> Reconstruction Loss = 17800.4590, Classification Loss = 0.0000
# Epoch : 50  ===> Reconstruction Loss = 17666.5820, Classification Loss = 0.0000
# Epoch : 51  ===> Reconstruction Loss = 18002.1660, Classification Loss = 0.0000
# Epoch : 52  ===> Reconstruction Loss = 18071.8379, Classification Loss = 1.0009
# Epoch : 53  ===> Reconstruction Loss = 17543.3750, Classification Loss = 1.0004
# Epoch : 54  ===> Reconstruction Loss = 17903.1797, Classification Loss = 2.0021
# Epoch : 55  ===> Reconstruction Loss = 17873.1582, Classification Loss = 3.0026
# Epoch : 56  ===> Reconstruction Loss = 18133.1699, Classification Loss = 8.0085
# Epoch : 57  ===> Reconstruction Loss = 18531.6562, Classification Loss = 9.0397
# Epoch : 58  ===> Reconstruction Loss = 18564.3594, Classification Loss = 19.0969
# Epoch : 59  ===> Reconstruction Loss = 17529.5117, Classification Loss = 26.1938
# Epoch : 60  ===> Reconstruction Loss = 18200.9414, Classification Loss = 30.2338
# Epoch : 61  ===> Reconstruction Loss = 17586.8652, Classification Loss = 26.1978
# Epoch : 62  ===> Reconstruction Loss = 17872.6289, Classification Loss = 21.1618
# Epoch : 63  ===> Reconstruction Loss = 17567.9453, Classification Loss = 14.1083
# Epoch : 64  ===> Reconstruction Loss = 18294.2227, Classification Loss = 12.0739
# Epoch : 65  ===> Reconstruction Loss = 17543.3535, Classification Loss = 12.0603
# Epoch : 66  ===> Reconstruction Loss = 17705.6777, Classification Loss = 8.0438
# Epoch : 67  ===> Reconstruction Loss = 17644.5137, Classification Loss = 5.0251
# Epoch : 68  ===> Reconstruction Loss = 18287.8164, Classification Loss = 5.0129
# Epoch : 69  ===> Reconstruction Loss = 17838.8184, Classification Loss = 3.0014
# Epoch : 70  ===> Reconstruction Loss = 17710.1309, Classification Loss = 1.0004
# Epoch : 71  ===> Reconstruction Loss = 17164.9277, Classification Loss = 1.0004
# Epoch : 72  ===> Reconstruction Loss = 17848.1953, Classification Loss = 0.0000
# Epoch : 73  ===> Reconstruction Loss = 18115.1758, Classification Loss = 0.0000
# Epoch : 74  ===> Reconstruction Loss = 17656.5156, Classification Loss = 1.0002
# Epoch : 75  ===> Reconstruction Loss = 17760.3516, Classification Loss = 0.0000
# Epoch : 76  ===> Reconstruction Loss = 17354.6289, Classification Loss = 0.0000
# Epoch : 77  ===> Reconstruction Loss = 17429.3320, Classification Loss = 2.0009
# Epoch : 78  ===> Reconstruction Loss = 17848.1992, Classification Loss = 1.0006
# Epoch : 79  ===> Reconstruction Loss = 18361.6816, Classification Loss = 2.0001
# Epoch : 80  ===> Reconstruction Loss = 17510.4180, Classification Loss = 2.0003
# Epoch : 81  ===> Reconstruction Loss = 17775.4961, Classification Loss = 3.0030
# Epoch : 82  ===> Reconstruction Loss = 17602.0664, Classification Loss = 2.0038
# Epoch : 83  ===> Reconstruction Loss = 18261.8574, Classification Loss = 0.0000
# Epoch : 84  ===> Reconstruction Loss = 17524.1836, Classification Loss = 2.0020
# Epoch : 85  ===> Reconstruction Loss = 17316.4883, Classification Loss = 2.0011
# Epoch : 86  ===> Reconstruction Loss = 18097.3906, Classification Loss = 2.0016
# Epoch : 87  ===> Reconstruction Loss = 18045.1172, Classification Loss = 0.0000
# Epoch : 88  ===> Reconstruction Loss = 17383.6992, Classification Loss = 2.0002
# Epoch : 89  ===> Reconstruction Loss = 17978.7207, Classification Loss = 1.0002
# Epoch : 90  ===> Reconstruction Loss = 18063.8984, Classification Loss = 0.0000
# Epoch : 91  ===> Reconstruction Loss = 17905.4121, Classification Loss = 2.0026
# Epoch : 92  ===> Reconstruction Loss = 17459.0566, Classification Loss = 2.0025
# Epoch : 93  ===> Reconstruction Loss = 18019.1289, Classification Loss = 0.0000
# Epoch : 94  ===> Reconstruction Loss = 17457.4844, Classification Loss = 1.0001
# Epoch : 95  ===> Reconstruction Loss = 17778.3594, Classification Loss = 3.0020
# Epoch : 96  ===> Reconstruction Loss = 18266.2891, Classification Loss = 3.0035
# Epoch : 97  ===> Reconstruction Loss = 17994.4219, Classification Loss = 1.0001
# Epoch : 98  ===> Reconstruction Loss = 18065.0234, Classification Loss = 0.0000
# Epoch : 99  ===> Reconstruction Loss = 18073.4258, Classification Loss = 1.0003
# Epoch : 100  ===> Reconstruction Loss = 18088.6523, Classification Loss = 1.0024
# Epoch : 1  ===> Reconstruction Loss = 22285.7852
# Epoch : 2  ===> Reconstruction Loss = 16306.3223
# Epoch : 3  ===> Reconstruction Loss = 12781.5723
# Epoch : 4  ===> Reconstruction Loss = 10839.7695
# Epoch : 5  ===> Reconstruction Loss = 9811.5752
# Epoch : 6  ===> Reconstruction Loss = 8943.9453
# Epoch : 7  ===> Reconstruction Loss = 8045.8384
# Epoch : 8  ===> Reconstruction Loss = 7780.8398
# Epoch : 9  ===> Reconstruction Loss = 8172.5762
# Epoch : 10  ===> Reconstruction Loss = 7500.1553
# Epoch : 11  ===> Reconstruction Loss = 7506.6235
# Epoch : 12  ===> Reconstruction Loss = 7496.3369
# Epoch : 13  ===> Reconstruction Loss = 7165.6250
# Epoch : 14  ===> Reconstruction Loss = 7229.8159
# Epoch : 15  ===> Reconstruction Loss = 7060.7520
# Epoch : 16  ===> Reconstruction Loss = 7109.5127
# Epoch : 17  ===> Reconstruction Loss = 7090.5127
# Epoch : 18  ===> Reconstruction Loss = 7054.4722
# Epoch : 19  ===> Reconstruction Loss = 6957.7520
# Epoch : 20  ===> Reconstruction Loss = 7397.5264
# Epoch : 21  ===> Reconstruction Loss = 7047.6260
# Epoch : 22  ===> Reconstruction Loss = 7477.0137
# Epoch : 23  ===> Reconstruction Loss = 6962.8066
# Epoch : 24  ===> Reconstruction Loss = 7093.7148
# Epoch : 25  ===> Reconstruction Loss = 7010.2305
# Epoch : 26  ===> Reconstruction Loss = 7095.5186
# Epoch : 27  ===> Reconstruction Loss = 6972.8472
# Epoch : 28  ===> Reconstruction Loss = 7146.1289
# Epoch : 29  ===> Reconstruction Loss = 7057.2012
# Epoch : 30  ===> Reconstruction Loss = 7363.1074
# Epoch : 31  ===> Reconstruction Loss = 6999.0928
# Epoch : 32  ===> Reconstruction Loss = 6998.6436
# Epoch : 33  ===> Reconstruction Loss = 6949.4219
# Epoch : 34  ===> Reconstruction Loss = 7146.0430
# Epoch : 35  ===> Reconstruction Loss = 6840.8550
# Epoch : 36  ===> Reconstruction Loss = 7121.2197
# Epoch : 37  ===> Reconstruction Loss = 6846.3896
# Epoch : 38  ===> Reconstruction Loss = 7050.5576
# Epoch : 39  ===> Reconstruction Loss = 6828.6362
# Epoch : 40  ===> Reconstruction Loss = 7231.0625
# Epoch : 41  ===> Reconstruction Loss = 7104.9697
# Epoch : 42  ===> Reconstruction Loss = 6890.6475
# Epoch : 43  ===> Reconstruction Loss = 7221.2002
# Epoch : 44  ===> Reconstruction Loss = 7019.4170
# Epoch : 45  ===> Reconstruction Loss = 7037.4946
# Epoch : 46  ===> Reconstruction Loss = 7121.3931
# Epoch : 47  ===> Reconstruction Loss = 6820.9277
# Epoch : 48  ===> Reconstruction Loss = 7093.6279
# Epoch : 49  ===> Reconstruction Loss = 6998.9121
# Epoch : 50  ===> Reconstruction Loss = 7038.8872
#     训练时间: 16.26秒, 内存使用: 32.90MB
#     准确率: 0.9760
#   - 处理第 3 折
# Epoch : 1  ===> Reconstruction Loss = 90234.5938, Classification Loss = 300.0763
# Epoch : 2  ===> Reconstruction Loss = 62475.7344, Classification Loss = 263.6027
# Epoch : 3  ===> Reconstruction Loss = 53885.9375, Classification Loss = 213.2981
# Epoch : 4  ===> Reconstruction Loss = 47024.3633, Classification Loss = 180.1308
# Epoch : 5  ===> Reconstruction Loss = 41702.0156, Classification Loss = 138.5968
# Epoch : 6  ===> Reconstruction Loss = 36902.1602, Classification Loss = 100.1679
# Epoch : 7  ===> Reconstruction Loss = 33309.8086, Classification Loss = 83.5591
# Epoch : 8  ===> Reconstruction Loss = 30347.8340, Classification Loss = 66.7869
# Epoch : 9  ===> Reconstruction Loss = 28030.0898, Classification Loss = 47.2407
# Epoch : 10  ===> Reconstruction Loss = 26721.6836, Classification Loss = 34.9332
# Epoch : 11  ===> Reconstruction Loss = 25300.0645, Classification Loss = 35.7563
# Epoch : 12  ===> Reconstruction Loss = 23974.3223, Classification Loss = 31.6398
# Epoch : 13  ===> Reconstruction Loss = 23357.5605, Classification Loss = 30.5373
# Epoch : 14  ===> Reconstruction Loss = 22103.4121, Classification Loss = 27.4444
# Epoch : 15  ===> Reconstruction Loss = 21391.5430, Classification Loss = 20.3606
# Epoch : 16  ===> Reconstruction Loss = 21544.2656, Classification Loss = 16.3192
# Epoch : 17  ===> Reconstruction Loss = 20917.3594, Classification Loss = 12.3015
# Epoch : 18  ===> Reconstruction Loss = 19853.1621, Classification Loss = 12.3061
# Epoch : 19  ===> Reconstruction Loss = 19715.2773, Classification Loss = 12.3109
# Epoch : 20  ===> Reconstruction Loss = 19688.0176, Classification Loss = 12.3061
# Epoch : 21  ===> Reconstruction Loss = 18886.0000, Classification Loss = 11.2883
# Epoch : 22  ===> Reconstruction Loss = 19443.7773, Classification Loss = 12.2740
# Epoch : 23  ===> Reconstruction Loss = 19058.5625, Classification Loss = 14.2670
# Epoch : 24  ===> Reconstruction Loss = 18999.7305, Classification Loss = 14.2567
# Epoch : 25  ===> Reconstruction Loss = 18757.0391, Classification Loss = 12.2383
# Epoch : 26  ===> Reconstruction Loss = 18578.7988, Classification Loss = 11.2171
# Epoch : 27  ===> Reconstruction Loss = 18571.1133, Classification Loss = 11.2012
# Epoch : 28  ===> Reconstruction Loss = 18429.1113, Classification Loss = 11.1845
# Epoch : 29  ===> Reconstruction Loss = 18547.3848, Classification Loss = 9.1627
# Epoch : 30  ===> Reconstruction Loss = 18706.8789, Classification Loss = 9.1545
# Epoch : 31  ===> Reconstruction Loss = 18848.1523, Classification Loss = 10.1452
# Epoch : 32  ===> Reconstruction Loss = 18004.2715, Classification Loss = 9.1351
# Epoch : 33  ===> Reconstruction Loss = 18564.8555, Classification Loss = 8.1297
# Epoch : 34  ===> Reconstruction Loss = 18178.5156, Classification Loss = 8.1203
# Epoch : 35  ===> Reconstruction Loss = 18038.0195, Classification Loss = 6.1046
# Epoch : 36  ===> Reconstruction Loss = 17490.5273, Classification Loss = 8.0995
# Epoch : 37  ===> Reconstruction Loss = 18184.2617, Classification Loss = 8.0961
# Epoch : 38  ===> Reconstruction Loss = 18333.3086, Classification Loss = 7.0873
# Epoch : 39  ===> Reconstruction Loss = 18145.8633, Classification Loss = 7.0769
# Epoch : 40  ===> Reconstruction Loss = 17547.7051, Classification Loss = 5.0656
# Epoch : 41  ===> Reconstruction Loss = 17719.8008, Classification Loss = 4.0597
# Epoch : 42  ===> Reconstruction Loss = 18009.3750, Classification Loss = 5.0566
# Epoch : 43  ===> Reconstruction Loss = 18101.1543, Classification Loss = 3.0531
# Epoch : 44  ===> Reconstruction Loss = 17572.3281, Classification Loss = 3.0523
# Epoch : 45  ===> Reconstruction Loss = 17486.7266, Classification Loss = 3.0489
# Epoch : 46  ===> Reconstruction Loss = 17440.5547, Classification Loss = 4.0429
# Epoch : 47  ===> Reconstruction Loss = 17317.6641, Classification Loss = 2.0391
# Epoch : 48  ===> Reconstruction Loss = 18047.7988, Classification Loss = 2.0360
# Epoch : 49  ===> Reconstruction Loss = 17995.3477, Classification Loss = 5.0344
# Epoch : 50  ===> Reconstruction Loss = 17861.1797, Classification Loss = 4.0327
# Epoch : 51  ===> Reconstruction Loss = 17768.7344, Classification Loss = 5.0291
# Epoch : 52  ===> Reconstruction Loss = 17965.4336, Classification Loss = 1.0230
# Epoch : 53  ===> Reconstruction Loss = 17409.9180, Classification Loss = 1.0189
# Epoch : 54  ===> Reconstruction Loss = 17580.2988, Classification Loss = 2.0172
# Epoch : 55  ===> Reconstruction Loss = 18109.3633, Classification Loss = 1.0152
# Epoch : 56  ===> Reconstruction Loss = 17430.8438, Classification Loss = 3.0137
# Epoch : 57  ===> Reconstruction Loss = 17810.6270, Classification Loss = 1.0109
# Epoch : 58  ===> Reconstruction Loss = 17935.0898, Classification Loss = 2.0103
# Epoch : 59  ===> Reconstruction Loss = 17776.3477, Classification Loss = 2.0098
# Epoch : 60  ===> Reconstruction Loss = 17861.9570, Classification Loss = 1.0077
# Epoch : 61  ===> Reconstruction Loss = 17579.3984, Classification Loss = 2.0071
# Epoch : 62  ===> Reconstruction Loss = 17548.7383, Classification Loss = 2.0023
# Epoch : 63  ===> Reconstruction Loss = 17562.4883, Classification Loss = 1.0006
# Epoch : 64  ===> Reconstruction Loss = 18012.4688, Classification Loss = 1.0003
# Epoch : 65  ===> Reconstruction Loss = 17292.5195, Classification Loss = 1.0007
# Epoch : 66  ===> Reconstruction Loss = 17246.8672, Classification Loss = 0.0000
# Epoch : 67  ===> Reconstruction Loss = 17847.7363, Classification Loss = 0.0000
# Epoch : 68  ===> Reconstruction Loss = 17545.6641, Classification Loss = 0.0000
# Epoch : 69  ===> Reconstruction Loss = 17787.9473, Classification Loss = 1.0018
# Epoch : 70  ===> Reconstruction Loss = 17485.6699, Classification Loss = 1.0015
# Epoch : 71  ===> Reconstruction Loss = 17373.9844, Classification Loss = 0.0000
# Epoch : 72  ===> Reconstruction Loss = 17630.1992, Classification Loss = 0.0000
# Epoch : 73  ===> Reconstruction Loss = 17564.1973, Classification Loss = 1.0005
# Epoch : 74  ===> Reconstruction Loss = 17794.1387, Classification Loss = 1.0001
# Epoch : 75  ===> Reconstruction Loss = 17692.3672, Classification Loss = 0.0000
# Epoch : 76  ===> Reconstruction Loss = 17508.0859, Classification Loss = 0.0000
# Epoch : 77  ===> Reconstruction Loss = 18045.2207, Classification Loss = 1.0002
# Epoch : 78  ===> Reconstruction Loss = 17911.1680, Classification Loss = 0.0000
# Epoch : 79  ===> Reconstruction Loss = 17710.3672, Classification Loss = 0.0000
# Epoch : 80  ===> Reconstruction Loss = 17418.6309, Classification Loss = 1.0026
# Epoch : 81  ===> Reconstruction Loss = 17466.1055, Classification Loss = 2.0036
# Epoch : 82  ===> Reconstruction Loss = 18052.7383, Classification Loss = 2.0015
# Epoch : 83  ===> Reconstruction Loss = 17861.6016, Classification Loss = 1.0018
# Epoch : 84  ===> Reconstruction Loss = 17511.1289, Classification Loss = 3.0023
# Epoch : 85  ===> Reconstruction Loss = 17677.6211, Classification Loss = 2.0008
# Epoch : 86  ===> Reconstruction Loss = 17762.2168, Classification Loss = 0.0000
# Epoch : 87  ===> Reconstruction Loss = 17423.0273, Classification Loss = 1.0000
# Epoch : 88  ===> Reconstruction Loss = 18121.3516, Classification Loss = 1.0005
# Epoch : 89  ===> Reconstruction Loss = 17155.5352, Classification Loss = 0.0000
# Epoch : 90  ===> Reconstruction Loss = 17813.0508, Classification Loss = 1.0009
# Epoch : 91  ===> Reconstruction Loss = 18331.0996, Classification Loss = 2.0008
# Epoch : 92  ===> Reconstruction Loss = 17101.6543, Classification Loss = 0.0000
# Epoch : 93  ===> Reconstruction Loss = 18025.4180, Classification Loss = 1.0008
# Epoch : 94  ===> Reconstruction Loss = 17804.8496, Classification Loss = 1.0014
# Epoch : 95  ===> Reconstruction Loss = 17699.3574, Classification Loss = 0.0000
# Epoch : 96  ===> Reconstruction Loss = 17604.3965, Classification Loss = 0.0000
# Epoch : 97  ===> Reconstruction Loss = 18238.9434, Classification Loss = 1.0012
# Epoch : 98  ===> Reconstruction Loss = 18010.9316, Classification Loss = 1.0011
# Epoch : 99  ===> Reconstruction Loss = 18146.6445, Classification Loss = 0.0000
# Epoch : 100  ===> Reconstruction Loss = 18013.3555, Classification Loss = 1.0014
# Epoch : 1  ===> Reconstruction Loss = 19802.3965
# Epoch : 2  ===> Reconstruction Loss = 14544.5840
# Epoch : 3  ===> Reconstruction Loss = 11681.1465
# Epoch : 4  ===> Reconstruction Loss = 10037.1543
# Epoch : 5  ===> Reconstruction Loss = 9222.0996
# Epoch : 6  ===> Reconstruction Loss = 8599.8506
# Epoch : 7  ===> Reconstruction Loss = 8130.0811
# Epoch : 8  ===> Reconstruction Loss = 7696.1279
# Epoch : 9  ===> Reconstruction Loss = 7202.9434
# Epoch : 10  ===> Reconstruction Loss = 7293.7734
# Epoch : 11  ===> Reconstruction Loss = 7330.3955
# Epoch : 12  ===> Reconstruction Loss = 7184.3442
# Epoch : 13  ===> Reconstruction Loss = 6981.5044
# Epoch : 14  ===> Reconstruction Loss = 7514.2183
# Epoch : 15  ===> Reconstruction Loss = 7067.3960
# Epoch : 16  ===> Reconstruction Loss = 7157.0845
# Epoch : 17  ===> Reconstruction Loss = 7266.0166
# Epoch : 18  ===> Reconstruction Loss = 7222.3623
# Epoch : 19  ===> Reconstruction Loss = 7150.4854
# Epoch : 20  ===> Reconstruction Loss = 7264.3159
# Epoch : 21  ===> Reconstruction Loss = 6929.1934
# Epoch : 22  ===> Reconstruction Loss = 7257.0693
# Epoch : 23  ===> Reconstruction Loss = 7037.6475
# Epoch : 24  ===> Reconstruction Loss = 7016.3359
# Epoch : 25  ===> Reconstruction Loss = 7027.6138
# Epoch : 26  ===> Reconstruction Loss = 7200.9897
# Epoch : 27  ===> Reconstruction Loss = 6888.8301
# Epoch : 28  ===> Reconstruction Loss = 7286.4648
# Epoch : 29  ===> Reconstruction Loss = 7070.8232
# Epoch : 30  ===> Reconstruction Loss = 7403.0049
# Epoch : 31  ===> Reconstruction Loss = 6842.4766
# Epoch : 32  ===> Reconstruction Loss = 7270.1836
# Epoch : 33  ===> Reconstruction Loss = 7070.6602
# Epoch : 34  ===> Reconstruction Loss = 6868.7842
# Epoch : 35  ===> Reconstruction Loss = 7356.0947
# Epoch : 36  ===> Reconstruction Loss = 7360.8770
# Epoch : 37  ===> Reconstruction Loss = 6877.0293
# Epoch : 38  ===> Reconstruction Loss = 7012.6309
# Epoch : 39  ===> Reconstruction Loss = 6865.6792
# Epoch : 40  ===> Reconstruction Loss = 7242.1577
# Epoch : 41  ===> Reconstruction Loss = 7132.3613
# Epoch : 42  ===> Reconstruction Loss = 7100.9497
# Epoch : 43  ===> Reconstruction Loss = 7119.6577
# Epoch : 44  ===> Reconstruction Loss = 7086.1387
# Epoch : 45  ===> Reconstruction Loss = 6844.8457
# Epoch : 46  ===> Reconstruction Loss = 7134.1064
# Epoch : 47  ===> Reconstruction Loss = 6942.2266
# Epoch : 48  ===> Reconstruction Loss = 7331.3340
# Epoch : 49  ===> Reconstruction Loss = 6964.4126
# Epoch : 50  ===> Reconstruction Loss = 6942.2212
#     训练时间: 15.85秒, 内存使用: 36.76MB
#     准确率: 0.9760
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 88137.2969, Classification Loss = 299.8810
# Epoch : 2  ===> Reconstruction Loss = 61803.0000, Classification Loss = 291.6483
# Epoch : 3  ===> Reconstruction Loss = 53245.1719, Classification Loss = 239.5193
# Epoch : 4  ===> Reconstruction Loss = 46723.8594, Classification Loss = 189.9614
# Epoch : 5  ===> Reconstruction Loss = 40549.4805, Classification Loss = 153.5883
# Epoch : 6  ===> Reconstruction Loss = 36740.0508, Classification Loss = 120.9383
# Epoch : 7  ===> Reconstruction Loss = 33165.2266, Classification Loss = 97.0745
# Epoch : 8  ===> Reconstruction Loss = 30350.3398, Classification Loss = 71.3473
# Epoch : 9  ===> Reconstruction Loss = 28134.3984, Classification Loss = 61.6688
# Epoch : 10  ===> Reconstruction Loss = 26480.9023, Classification Loss = 47.0740
# Epoch : 11  ===> Reconstruction Loss = 24792.9746, Classification Loss = 34.7816
# Epoch : 12  ===> Reconstruction Loss = 24197.1719, Classification Loss = 28.5813
# Epoch : 13  ===> Reconstruction Loss = 22948.0586, Classification Loss = 25.4343
# Epoch : 14  ===> Reconstruction Loss = 22052.7949, Classification Loss = 20.3125
# Epoch : 15  ===> Reconstruction Loss = 21542.7305, Classification Loss = 17.2352
# Epoch : 16  ===> Reconstruction Loss = 21366.2930, Classification Loss = 14.1945
# Epoch : 17  ===> Reconstruction Loss = 20507.1660, Classification Loss = 18.1666
# Epoch : 18  ===> Reconstruction Loss = 20018.6914, Classification Loss = 16.1598
# Epoch : 19  ===> Reconstruction Loss = 20049.2617, Classification Loss = 15.1337
# Epoch : 20  ===> Reconstruction Loss = 19507.6230, Classification Loss = 13.0992
# Epoch : 21  ===> Reconstruction Loss = 19169.7227, Classification Loss = 7.0656
# Epoch : 22  ===> Reconstruction Loss = 19099.4922, Classification Loss = 7.0524
# Epoch : 23  ===> Reconstruction Loss = 19001.2852, Classification Loss = 5.0459
# Epoch : 24  ===> Reconstruction Loss = 18978.5156, Classification Loss = 6.0419
# Epoch : 25  ===> Reconstruction Loss = 18514.2207, Classification Loss = 5.0377
# Epoch : 26  ===> Reconstruction Loss = 18566.5137, Classification Loss = 5.0330
# Epoch : 27  ===> Reconstruction Loss = 18159.0332, Classification Loss = 5.0246
# Epoch : 28  ===> Reconstruction Loss = 18390.9902, Classification Loss = 4.0167
# Epoch : 29  ===> Reconstruction Loss = 17959.3320, Classification Loss = 2.0100
# Epoch : 30  ===> Reconstruction Loss = 18240.5508, Classification Loss = 2.0098
# Epoch : 31  ===> Reconstruction Loss = 18120.5234, Classification Loss = 2.0084
# Epoch : 32  ===> Reconstruction Loss = 17859.8867, Classification Loss = 2.0103
# Epoch : 33  ===> Reconstruction Loss = 18663.3594, Classification Loss = 2.0107
# Epoch : 34  ===> Reconstruction Loss = 18463.8828, Classification Loss = 2.0097
# Epoch : 35  ===> Reconstruction Loss = 17668.9688, Classification Loss = 2.0101
# Epoch : 36  ===> Reconstruction Loss = 17806.3164, Classification Loss = 3.0099
# Epoch : 37  ===> Reconstruction Loss = 17865.1621, Classification Loss = 1.0081
# Epoch : 38  ===> Reconstruction Loss = 17545.4531, Classification Loss = 1.0076
# Epoch : 39  ===> Reconstruction Loss = 17894.6172, Classification Loss = 3.0070
# Epoch : 40  ===> Reconstruction Loss = 17982.4707, Classification Loss = 2.0042
# Epoch : 41  ===> Reconstruction Loss = 18019.9043, Classification Loss = 1.0039
# Epoch : 42  ===> Reconstruction Loss = 18439.5156, Classification Loss = 1.0029
# Epoch : 43  ===> Reconstruction Loss = 17704.2051, Classification Loss = 1.0014
# Epoch : 44  ===> Reconstruction Loss = 17701.6074, Classification Loss = 0.0000
# Epoch : 45  ===> Reconstruction Loss = 17557.1836, Classification Loss = 0.0000
# Epoch : 46  ===> Reconstruction Loss = 17751.4375, Classification Loss = 0.0000
# Epoch : 47  ===> Reconstruction Loss = 17820.4219, Classification Loss = 2.0033
# Epoch : 48  ===> Reconstruction Loss = 18265.1914, Classification Loss = 1.0101
# Epoch : 49  ===> Reconstruction Loss = 17532.0508, Classification Loss = 3.0297
# Epoch : 50  ===> Reconstruction Loss = 18227.3301, Classification Loss = 5.0470
# Epoch : 51  ===> Reconstruction Loss = 18043.7676, Classification Loss = 4.0456
# Epoch : 52  ===> Reconstruction Loss = 18421.1914, Classification Loss = 4.0443
# Epoch : 53  ===> Reconstruction Loss = 17626.9023, Classification Loss = 3.0476
# Epoch : 54  ===> Reconstruction Loss = 17672.9355, Classification Loss = 3.0399
# Epoch : 55  ===> Reconstruction Loss = 17662.1484, Classification Loss = 4.0358
# Epoch : 56  ===> Reconstruction Loss = 17856.1523, Classification Loss = 4.0374
# Epoch : 57  ===> Reconstruction Loss = 17596.2109, Classification Loss = 2.0292
# Epoch : 58  ===> Reconstruction Loss = 18298.2148, Classification Loss = 2.0200
# Epoch : 59  ===> Reconstruction Loss = 17475.2734, Classification Loss = 3.0186
# Epoch : 60  ===> Reconstruction Loss = 17969.9805, Classification Loss = 2.0167
# Epoch : 61  ===> Reconstruction Loss = 17503.4258, Classification Loss = 3.0114
# Epoch : 62  ===> Reconstruction Loss = 17591.3301, Classification Loss = 4.0021
# Epoch : 63  ===> Reconstruction Loss = 17963.1816, Classification Loss = 1.0001
# Epoch : 64  ===> Reconstruction Loss = 17552.3848, Classification Loss = 0.0000
# Epoch : 65  ===> Reconstruction Loss = 18348.0801, Classification Loss = 2.0007
# Epoch : 66  ===> Reconstruction Loss = 17895.1367, Classification Loss = 0.0000
# Epoch : 67  ===> Reconstruction Loss = 17260.2363, Classification Loss = 3.0025
# Epoch : 68  ===> Reconstruction Loss = 17497.7012, Classification Loss = 1.0007
# Epoch : 69  ===> Reconstruction Loss = 17654.9785, Classification Loss = 2.0021
# Epoch : 70  ===> Reconstruction Loss = 18266.2031, Classification Loss = 2.0015
# Epoch : 71  ===> Reconstruction Loss = 17848.6426, Classification Loss = 2.0025
# Epoch : 72  ===> Reconstruction Loss = 17843.8965, Classification Loss = 0.0000
# Epoch : 73  ===> Reconstruction Loss = 17652.6641, Classification Loss = 1.0011
# Epoch : 74  ===> Reconstruction Loss = 17304.2051, Classification Loss = 0.0000
# Epoch : 75  ===> Reconstruction Loss = 18353.7441, Classification Loss = 0.0000
# Epoch : 76  ===> Reconstruction Loss = 17465.5859, Classification Loss = 0.0000
# Epoch : 77  ===> Reconstruction Loss = 18387.1719, Classification Loss = 1.0010
# Epoch : 78  ===> Reconstruction Loss = 17583.7070, Classification Loss = 1.0001
# Epoch : 79  ===> Reconstruction Loss = 17191.9043, Classification Loss = 1.0006
# Epoch : 80  ===> Reconstruction Loss = 17179.1758, Classification Loss = 1.0017
# Epoch : 81  ===> Reconstruction Loss = 18018.0742, Classification Loss = 0.0000
# Epoch : 82  ===> Reconstruction Loss = 17877.0273, Classification Loss = 0.0000
# Epoch : 83  ===> Reconstruction Loss = 18360.4512, Classification Loss = 0.0000
# Epoch : 84  ===> Reconstruction Loss = 17996.7188, Classification Loss = 0.0000
# Epoch : 85  ===> Reconstruction Loss = 17448.7461, Classification Loss = 0.0000
# Epoch : 86  ===> Reconstruction Loss = 17913.9883, Classification Loss = 1.0014
# Epoch : 87  ===> Reconstruction Loss = 17754.4688, Classification Loss = 1.0013
# Epoch : 88  ===> Reconstruction Loss = 17208.0469, Classification Loss = 1.0012
# Epoch : 89  ===> Reconstruction Loss = 17342.4727, Classification Loss = 4.0042
# Epoch : 90  ===> Reconstruction Loss = 18090.8633, Classification Loss = 2.0009
# Epoch : 91  ===> Reconstruction Loss = 18326.4434, Classification Loss = 3.0029
# Epoch : 92  ===> Reconstruction Loss = 18315.4316, Classification Loss = 2.0012
# Epoch : 93  ===> Reconstruction Loss = 17434.8398, Classification Loss = 0.0000
# Epoch : 94  ===> Reconstruction Loss = 18005.6504, Classification Loss = 1.0018
# Epoch : 95  ===> Reconstruction Loss = 17655.4766, Classification Loss = 1.0004
# Epoch : 96  ===> Reconstruction Loss = 17855.4668, Classification Loss = 1.0002
# Epoch : 97  ===> Reconstruction Loss = 17979.3730, Classification Loss = 0.0000
# Epoch : 98  ===> Reconstruction Loss = 17838.5781, Classification Loss = 1.0001
# Epoch : 99  ===> Reconstruction Loss = 17646.7422, Classification Loss = 0.0000
# Epoch : 100  ===> Reconstruction Loss = 18288.6270, Classification Loss = 1.0005
# Epoch : 1  ===> Reconstruction Loss = 20051.1992
# Epoch : 2  ===> Reconstruction Loss = 14644.5127
# Epoch : 3  ===> Reconstruction Loss = 11660.4375
# Epoch : 4  ===> Reconstruction Loss = 9998.5049
# Epoch : 5  ===> Reconstruction Loss = 8897.0732
# Epoch : 6  ===> Reconstruction Loss = 8303.2236
# Epoch : 7  ===> Reconstruction Loss = 8163.6748
# Epoch : 8  ===> Reconstruction Loss = 7496.8491
# Epoch : 9  ===> Reconstruction Loss = 7331.9937
# Epoch : 10  ===> Reconstruction Loss = 7346.4199
# Epoch : 11  ===> Reconstruction Loss = 6987.0742
# Epoch : 12  ===> Reconstruction Loss = 6859.0615
# Epoch : 13  ===> Reconstruction Loss = 6853.5132
# Epoch : 14  ===> Reconstruction Loss = 7268.9922
# Epoch : 15  ===> Reconstruction Loss = 7143.0718
# Epoch : 16  ===> Reconstruction Loss = 7080.6133
# Epoch : 17  ===> Reconstruction Loss = 7216.3794
# Epoch : 18  ===> Reconstruction Loss = 7166.8916
# Epoch : 19  ===> Reconstruction Loss = 6838.6748
# Epoch : 20  ===> Reconstruction Loss = 7126.8730
# Epoch : 21  ===> Reconstruction Loss = 6772.8896
# Epoch : 22  ===> Reconstruction Loss = 7320.7832
# Epoch : 23  ===> Reconstruction Loss = 6986.1880
# Epoch : 24  ===> Reconstruction Loss = 7091.4312
# Epoch : 25  ===> Reconstruction Loss = 7136.9902
# Epoch : 26  ===> Reconstruction Loss = 6876.0747
# Epoch : 27  ===> Reconstruction Loss = 6833.6221
# Epoch : 28  ===> Reconstruction Loss = 7081.4243
# Epoch : 29  ===> Reconstruction Loss = 7173.7471
# Epoch : 30  ===> Reconstruction Loss = 6588.0176
# Epoch : 31  ===> Reconstruction Loss = 7096.2280
# Epoch : 32  ===> Reconstruction Loss = 7130.4727
# Epoch : 33  ===> Reconstruction Loss = 7119.1782
# Epoch : 34  ===> Reconstruction Loss = 6822.8472
# Epoch : 35  ===> Reconstruction Loss = 6880.2632
# Epoch : 36  ===> Reconstruction Loss = 7114.5029
# Epoch : 37  ===> Reconstruction Loss = 7117.3315
# Epoch : 38  ===> Reconstruction Loss = 7022.6553
# Epoch : 39  ===> Reconstruction Loss = 7039.6562
# Epoch : 40  ===> Reconstruction Loss = 7260.3320
# Epoch : 41  ===> Reconstruction Loss = 6950.3350
# Epoch : 42  ===> Reconstruction Loss = 7034.8540
# Epoch : 43  ===> Reconstruction Loss = 7033.5947
# Epoch : 44  ===> Reconstruction Loss = 6920.3496
# Epoch : 45  ===> Reconstruction Loss = 7056.6333
# Epoch : 46  ===> Reconstruction Loss = 6894.0273
# Epoch : 47  ===> Reconstruction Loss = 7127.2593
# Epoch : 48  ===> Reconstruction Loss = 6624.8975
# Epoch : 49  ===> Reconstruction Loss = 7086.7578
# Epoch : 50  ===> Reconstruction Loss = 6939.3203
#     训练时间: 15.66秒, 内存使用: 38.22MB
#     准确率: 0.9920
#
# === 处理 Batch 2 ===
#   - 处理第 1 折
# Epoch : 1  ===> Reconstruction Loss = 90425.8750, Classification Loss = 300.8621
# Epoch : 2  ===> Reconstruction Loss = 63360.6406, Classification Loss = 272.6775
# Epoch : 3  ===> Reconstruction Loss = 54509.6016, Classification Loss = 197.8453
# Epoch : 4  ===> Reconstruction Loss = 47491.3672, Classification Loss = 144.3574
# Epoch : 5  ===> Reconstruction Loss = 41624.9453, Classification Loss = 99.9071
# Epoch : 6  ===> Reconstruction Loss = 36763.3164, Classification Loss = 66.1878
# Epoch : 7  ===> Reconstruction Loss = 32908.7969, Classification Loss = 42.7344
# Epoch : 8  ===> Reconstruction Loss = 30443.6602, Classification Loss = 24.5123
# Epoch : 9  ===> Reconstruction Loss = 28443.0469, Classification Loss = 21.3869
# Epoch : 10  ===> Reconstruction Loss = 26893.9336, Classification Loss = 15.2517
# Epoch : 11  ===> Reconstruction Loss = 25183.9570, Classification Loss = 13.1420
# Epoch : 12  ===> Reconstruction Loss = 23766.1816, Classification Loss = 9.0618
# Epoch : 13  ===> Reconstruction Loss = 22758.4648, Classification Loss = 5.0282
# Epoch : 14  ===> Reconstruction Loss = 22309.5547, Classification Loss = 5.0296
# Epoch : 15  ===> Reconstruction Loss = 21505.5566, Classification Loss = 4.0211
# Epoch : 16  ===> Reconstruction Loss = 21001.9062, Classification Loss = 2.0057
# Epoch : 17  ===> Reconstruction Loss = 20170.6758, Classification Loss = 1.0042
# Epoch : 18  ===> Reconstruction Loss = 19860.3555, Classification Loss = 3.0071
# Epoch : 19  ===> Reconstruction Loss = 19668.5996, Classification Loss = 4.0139
# Epoch : 20  ===> Reconstruction Loss = 20146.3652, Classification Loss = 4.0193
# Epoch : 21  ===> Reconstruction Loss = 18894.4277, Classification Loss = 4.0189
# Epoch : 22  ===> Reconstruction Loss = 18882.2168, Classification Loss = 3.0158
# Epoch : 23  ===> Reconstruction Loss = 18129.1953, Classification Loss = 4.0122
# Epoch : 24  ===> Reconstruction Loss = 18654.2480, Classification Loss = 1.0089
# Epoch : 25  ===> Reconstruction Loss = 18430.2969, Classification Loss = 2.0091
# Epoch : 26  ===> Reconstruction Loss = 18418.5840, Classification Loss = 1.0083
# Epoch : 27  ===> Reconstruction Loss = 18759.6816, Classification Loss = 1.0053
# Epoch : 28  ===> Reconstruction Loss = 18189.0098, Classification Loss = 2.0026
# Epoch : 29  ===> Reconstruction Loss = 17746.6367, Classification Loss = 1.0000
# Epoch : 30  ===> Reconstruction Loss = 18006.7559, Classification Loss = 0.0000
# Epoch : 31  ===> Reconstruction Loss = 18078.3438, Classification Loss = 0.0000
# Epoch : 32  ===> Reconstruction Loss = 18372.5020, Classification Loss = 1.0026
# Epoch : 33  ===> Reconstruction Loss = 18288.3125, Classification Loss = 1.0009
# Epoch : 34  ===> Reconstruction Loss = 17817.3398, Classification Loss = 1.0006
# Epoch : 35  ===> Reconstruction Loss = 17920.3281, Classification Loss = 1.0004
# Epoch : 36  ===> Reconstruction Loss = 17909.1680, Classification Loss = 0.0000
# Epoch : 37  ===> Reconstruction Loss = 17753.7285, Classification Loss = 0.0000
# Epoch : 38  ===> Reconstruction Loss = 17858.5039, Classification Loss = 0.0000
# Epoch : 39  ===> Reconstruction Loss = 17656.0527, Classification Loss = 1.0003
# Epoch : 40  ===> Reconstruction Loss = 17145.5078, Classification Loss = 0.0000
# Epoch : 41  ===> Reconstruction Loss = 18029.3750, Classification Loss = 0.0000
# Epoch : 42  ===> Reconstruction Loss = 17490.4004, Classification Loss = 0.0000
# Epoch : 43  ===> Reconstruction Loss = 17627.0117, Classification Loss = 0.0000
# Epoch : 44  ===> Reconstruction Loss = 18074.9414, Classification Loss = 0.0000
# Epoch : 45  ===> Reconstruction Loss = 17372.9316, Classification Loss = 1.0004
# Epoch : 46  ===> Reconstruction Loss = 17460.5273, Classification Loss = 1.0002
# Epoch : 47  ===> Reconstruction Loss = 17458.2031, Classification Loss = 1.0004
# Epoch : 48  ===> Reconstruction Loss = 17820.3164, Classification Loss = 1.0009
# Epoch : 49  ===> Reconstruction Loss = 18027.3281, Classification Loss = 1.0016
# Epoch : 50  ===> Reconstruction Loss = 17579.3945, Classification Loss = 1.0002
# Epoch : 51  ===> Reconstruction Loss = 17762.9141, Classification Loss = 1.0005
# Epoch : 52  ===> Reconstruction Loss = 17025.4531, Classification Loss = 1.0006
# Epoch : 53  ===> Reconstruction Loss = 17966.9492, Classification Loss = 1.0014
# Epoch : 54  ===> Reconstruction Loss = 17967.5898, Classification Loss = 2.0013
# Epoch : 55  ===> Reconstruction Loss = 17902.3457, Classification Loss = 2.0030
# Epoch : 56  ===> Reconstruction Loss = 17809.5918, Classification Loss = 1.0009
# Epoch : 57  ===> Reconstruction Loss = 17154.1387, Classification Loss = 1.0007
# Epoch : 58  ===> Reconstruction Loss = 17497.8477, Classification Loss = 0.0000
# Epoch : 59  ===> Reconstruction Loss = 17526.0000, Classification Loss = 2.0027
# Epoch : 60  ===> Reconstruction Loss = 18382.1738, Classification Loss = 3.0021
# Epoch : 61  ===> Reconstruction Loss = 17947.0918, Classification Loss = 2.0003
# Epoch : 62  ===> Reconstruction Loss = 18056.2852, Classification Loss = 2.0010
# Epoch : 63  ===> Reconstruction Loss = 17483.0547, Classification Loss = 4.0018
# Epoch : 64  ===> Reconstruction Loss = 17707.5391, Classification Loss = 2.0013
# Epoch : 65  ===> Reconstruction Loss = 17288.2188, Classification Loss = 1.0002
# Epoch : 66  ===> Reconstruction Loss = 17679.2344, Classification Loss = 3.0009
# Epoch : 67  ===> Reconstruction Loss = 17565.2656, Classification Loss = 1.0023
# ...
# Epoch : 68  ===> Reconstruction Loss = 17641.8535, Classification Loss = 2.0012
# Epoch : 69  ===> Reconstruction Loss = 18022.0215, Classification Loss = 0.0000
# Epoch : 70  ===> Reconstruction Loss = 18124.9102, Classification Loss = 1.0015
# Epoch : 71  ===> Reconstruction Loss = 17938.8750, Classification Loss = 0.0000
# Epoch : 72  ===> Reconstruction Loss = 17873.7148, Classification Loss = 0.0000
# Epoch : 73  ===> Reconstruction Loss = 18158.6992, Classification Loss = 0.0000
# Epoch : 74  ===> Reconstruction Loss = 17975.4727, Classification Loss = 0.0000
# Epoch : 75  ===> Reconstruction Loss = 17804.9492, Classification Loss = 0.0000
# Epoch : 76  ===> Reconstruction Loss = 17632.0488, Classification Loss = 0.0000
# Epoch : 77  ===> Reconstruction Loss = 17737.3828, Classification Loss = 0.0000
# Epoch : 78  ===> Reconstruction Loss = 17706.7617, Classification Loss = 0.0000
# Epoch : 79  ===> Reconstruction Loss = 18102.0703, Classification Loss = 0.0000
# Epoch : 80  ===> Reconstruction Loss = 17732.8145, Classification Loss = 0.0000
# Epoch : 81  ===> Reconstruction Loss = 18221.7266, Classification Loss = 0.0000
# Epoch : 82  ===> Reconstruction Loss = 17677.5254, Classification Loss = 0.0000
# Epoch : 83  ===> Reconstruction Loss = 17898.3145, Classification Loss = 0.0000
# Epoch : 84  ===> Reconstruction Loss = 17979.7402, Classification Loss = 2.0036
# Epoch : 85  ===> Reconstruction Loss = 17776.7930, Classification Loss = 1.0008
# Epoch : 86  ===> Reconstruction Loss = 17481.6738, Classification Loss = 0.0000
# Epoch : 87  ===> Reconstruction Loss = 17898.4355, Classification Loss = 1.0006
# Epoch : 88  ===> Reconstruction Loss = 17618.5645, Classification Loss = 0.0000
# Epoch : 89  ===> Reconstruction Loss = 17603.1328, Classification Loss = 0.0000
# Epoch : 90  ===> Reconstruction Loss = 18052.9922, Classification Loss = 0.0000
# Epoch : 91  ===> Reconstruction Loss = 17910.3418, Classification Loss = 1.0019
# Epoch : 92  ===> Reconstruction Loss = 18047.5312, Classification Loss = 0.0000
# Epoch : 93  ===> Reconstruction Loss = 17549.9629, Classification Loss = 0.0000
# Epoch : 94  ===> Reconstruction Loss = 17796.9160, Classification Loss = 1.0011
# Epoch : 95  ===> Reconstruction Loss = 18192.1133, Classification Loss = 0.0000
# Epoch : 96  ===> Reconstruction Loss = 17574.3672, Classification Loss = 0.0000
# Epoch : 97  ===> Reconstruction Loss = 18043.1523, Classification Loss = 0.0000
# Epoch : 98  ===> Reconstruction Loss = 17673.2695, Classification Loss = 0.0000
# Epoch : 99  ===> Reconstruction Loss = 18065.5547, Classification Loss = 0.0000
# Epoch : 100  ===> Reconstruction Loss = 18269.9473, Classification Loss = 0.0000
# Epoch : 1  ===> Reconstruction Loss = 19947.6816
# Epoch : 2  ===> Reconstruction Loss = 14910.3926
# Epoch : 3  ===> Reconstruction Loss = 12013.1885
# Epoch : 4  ===> Reconstruction Loss = 10304.7988
# Epoch : 5  ===> Reconstruction Loss = 9069.1787
# Epoch : 6  ===> Reconstruction Loss = 8875.2324
# Epoch : 7  ===> Reconstruction Loss = 8075.5474
# Epoch : 8  ===> Reconstruction Loss = 7667.5317
# Epoch : 9  ===> Reconstruction Loss = 7636.4990
# Epoch : 10  ===> Reconstruction Loss = 7338.6162
# Epoch : 11  ===> Reconstruction Loss = 7211.1895
# Epoch : 12  ===> Reconstruction Loss = 7270.8008
# Epoch : 13  ===> Reconstruction Loss = 7158.7930
# Epoch : 14  ===> Reconstruction Loss = 7007.7476
# Epoch : 15  ===> Reconstruction Loss = 7140.3564
# Epoch : 16  ===> Reconstruction Loss = 6982.9316
# Epoch : 17  ===> Reconstruction Loss = 7042.3574
# Epoch : 18  ===> Reconstruction Loss = 6840.8018
# Epoch : 19  ===> Reconstruction Loss = 7122.3140
# Epoch : 20  ===> Reconstruction Loss = 7067.4082
# Epoch : 21  ===> Reconstruction Loss = 7182.2583
# Epoch : 22  ===> Reconstruction Loss = 6622.4624
# Epoch : 23  ===> Reconstruction Loss = 6690.2261
# Epoch : 24  ===> Reconstruction Loss = 7151.9653
# Epoch : 25  ===> Reconstruction Loss = 7015.7095
# Epoch : 26  ===> Reconstruction Loss = 6913.6069
# Epoch : 27  ===> Reconstruction Loss = 7117.7627
# Epoch : 28  ===> Reconstruction Loss = 7303.1543
# Epoch : 29  ===> Reconstruction Loss = 7005.4170
# Epoch : 30  ===> Reconstruction Loss = 6938.1157
# Epoch : 31  ===> Reconstruction Loss = 7269.9180
# Epoch : 32  ===> Reconstruction Loss = 6740.8364
# Epoch : 33  ===> Reconstruction Loss = 7562.2915
# Epoch : 34  ===> Reconstruction Loss = 7180.4717
# Epoch : 35  ===> Reconstruction Loss = 7132.6768
# Epoch : 36  ===> Reconstruction Loss = 7196.2461
# Epoch : 37  ===> Reconstruction Loss = 7272.0396
# Epoch : 38  ===> Reconstruction Loss = 7020.9648
# Epoch : 39  ===> Reconstruction Loss = 7129.1274
# Epoch : 40  ===> Reconstruction Loss = 6830.2822
# Epoch : 41  ===> Reconstruction Loss = 6971.9893
# Epoch : 42  ===> Reconstruction Loss = 6903.9072
# Epoch : 43  ===> Reconstruction Loss = 6718.4102
# Epoch : 44  ===> Reconstruction Loss = 7125.4482
# Epoch : 45  ===> Reconstruction Loss = 7183.0654
# Epoch : 46  ===> Reconstruction Loss = 6998.5083
# Epoch : 47  ===> Reconstruction Loss = 7210.2393
# Epoch : 48  ===> Reconstruction Loss = 6825.7705
# Epoch : 49  ===> Reconstruction Loss = 6884.2705
# Epoch : 50  ===> Reconstruction Loss = 6875.6094
#     训练时间: 148.53秒, 内存使用: 113.78MB
#     准确率: 0.9920
#   - 处理第 4 折
# Epoch : 1  ===> Reconstruction Loss = 90983.9141, Classification Loss = 246.0022
# Epoch : 2  ===> Reconstruction Loss = 64422.9805, Classification Loss = 180.8804
# Epoch : 3  ===> Reconstruction Loss = 55886.8438, Classification Loss = 130.7621
# Epoch : 4  ===> Reconstruction Loss = 48058.7656, Classification Loss = 90.8086
# Epoch : 5  ===> Reconstruction Loss = 42540.3086, Classification Loss = 72.7369
# Epoch : 6  ===> Reconstruction Loss = 37555.4883, Classification Loss = 52.4054
# Epoch : 7  ===> Reconstruction Loss = 33935.0000, Classification Loss = 39.0317
# Epoch : 8  ===> Reconstruction Loss = 31253.5703, Classification Loss = 25.7097
# Epoch : 9  ===> Reconstruction Loss = 29086.3203, Classification Loss = 20.4925
# Epoch : 10  ===> Reconstruction Loss = 27355.8320, Classification Loss = 19.3664
# Epoch : 11  ===> Reconstruction Loss = 25229.2109, Classification Loss = 14.2594
# Epoch : 12  ===> Reconstruction Loss = 24322.5117, Classification Loss = 10.1903
# Epoch : 13  ===> Reconstruction Loss = 23860.6133, Classification Loss = 8.1430
# Epoch : 14  ===> Reconstruction Loss = 22658.8867, Classification Loss = 7.1064
# Epoch : 15  ===> Reconstruction Loss = 21951.1406, Classification Loss = 8.0814
# Epoch : 16  ===> Reconstruction Loss = 21906.4922, Classification Loss = 7.0723
# Epoch : 17  ===> Reconstruction Loss = 20903.8359, Classification Loss = 7.0662
# Epoch : 18  ===> Reconstruction Loss = 19994.7695, Classification Loss = 7.0533
# Epoch : 19  ===> Reconstruction Loss = 19970.8516, Classification Loss = 4.0437
# Epoch : 20  ===> Reconstruction Loss = 20071.0664, Classification Loss = 4.0402
# Epoch : 21  ===> Reconstruction Loss = 19906.9941, Classification Loss = 3.0395
# Epoch : 22  ===> Reconstruction Loss = 19076.6699, Classification Loss = 3.0385
# Epoch : 23  ===> Reconstruction Loss = 18965.2188, Classification Loss = 3.0362
# Epoch : 24  ===> Reconstruction Loss = 19447.6738, Classification Loss = 3.0290
# Epoch : 25  ===> Reconstruction Loss = 18761.3965, Classification Loss = 3.0210
# Epoch : 26  ===> Reconstruction Loss = 18891.8516, Classification Loss = 3.0155
# Epoch : 27  ===> Reconstruction Loss = 18278.5020, Classification Loss = 1.0145
# Epoch : 28  ===> Reconstruction Loss = 18706.9004, Classification Loss = 2.0137
# Epoch : 29  ===> Reconstruction Loss = 18052.9297, Classification Loss = 1.0092
# Epoch : 30  ===> Reconstruction Loss = 18866.0352, Classification Loss = 2.0082
# Epoch : 31  ===> Reconstruction Loss = 18271.6523, Classification Loss = 3.0092
# Epoch : 32  ===> Reconstruction Loss = 18124.7168, Classification Loss = 4.0086
# Epoch : 33  ===> Reconstruction Loss = 18161.6777, Classification Loss = 3.0083
# Epoch : 34  ===> Reconstruction Loss = 18581.1367, Classification Loss = 4.0069
# Epoch : 35  ===> Reconstruction Loss = 18041.0801, Classification Loss = 4.0078
# Epoch : 36  ===> Reconstruction Loss = 17931.7773, Classification Loss = 3.0094
# Epoch : 37  ===> Reconstruction Loss = 17689.5371, Classification Loss = 2.0070
# Epoch : 38  ===> Reconstruction Loss = 18103.1797, Classification Loss = 3.0066
# Epoch : 39  ===> Reconstruction Loss = 17807.7617, Classification Loss = 2.0060
# Epoch : 40  ===> Reconstruction Loss = 18464.1602, Classification Loss = 4.0056
# Epoch : 41  ===> Reconstruction Loss = 18333.2227, Classification Loss = 2.0036
# Epoch : 42  ===> Reconstruction Loss = 18262.2578, Classification Loss = 1.0016
# Epoch : 43  ===> Reconstruction Loss = 17428.7539, Classification Loss = 2.0016
# Epoch : 44  ===> Reconstruction Loss = 18419.9648, Classification Loss = 2.0011
# Epoch : 45  ===> Reconstruction Loss = 17976.0957, Classification Loss = 2.0002
# Epoch : 46  ===> Reconstruction Loss = 18130.6523, Classification Loss = 2.0016
# Epoch : 47  ===> Reconstruction Loss = 18284.0703, Classification Loss = 2.0006
# Epoch : 48  ===> Reconstruction Loss = 17470.4199, Classification Loss = 1.0010
# Epoch : 49  ===> Reconstruction Loss = 18129.6465, Classification Loss = 1.0010
# Epoch : 50  ===> Reconstruction Loss = 18088.1055, Classification Loss = 1.0004
# Epoch : 51  ===> Reconstruction Loss = 18134.4473, Classification Loss = 0.0000
# Epoch : 52  ===> Reconstruction Loss = 18225.4473, Classification Loss = 1.0005
# Epoch : 53  ===> Reconstruction Loss = 17829.3320, Classification Loss = 0.0000
# Epoch : 54  ===> Reconstruction Loss = 17646.5020, Classification Loss = 1.0000
# Epoch : 55  ===> Reconstruction Loss = 18066.8496, Classification Loss = 1.0004
# Epoch : 56  ===> Reconstruction Loss = 17555.9219, Classification Loss = 1.0002
# Epoch : 57  ===> Reconstruction Loss = 17416.6992, Classification Loss = 2.0006
# Epoch : 58  ===> Reconstruction Loss = 17651.1992, Classification Loss = 2.0020
# Epoch : 59  ===> Reconstruction Loss = 17422.7852, Classification Loss = 1.0001
# Epoch : 60  ===> Reconstruction Loss = 18304.5273, Classification Loss = 2.0011
# Epoch : 61  ===> Reconstruction Loss = 17642.6914, Classification Loss = 0.0000
# Epoch : 62  ===> Reconstruction Loss = 18143.6523, Classification Loss = 0.0000
# Epoch : 63  ===> Reconstruction Loss = 17933.4375, Classification Loss = 0.0000
# Epoch : 64  ===> Reconstruction Loss = 18070.7578, Classification Loss = 1.0002
# Epoch : 65  ===> Reconstruction Loss = 18046.7402, Classification Loss = 1.0022
# Epoch : 66  ===> Reconstruction Loss = 17996.9941, Classification Loss = 2.0018
# Epoch : 67  ===> Reconstruction Loss = 17814.1152, Classification Loss = 2.0027
# Epoch : 68  ===> Reconstruction Loss = 17223.5352, Classification Loss = 2.0031
# Epoch : 69  ===> Reconstruction Loss = 18199.4238, Classification Loss = 1.0009
# Epoch : 70  ===> Reconstruction Loss = 17254.7266, Classification Loss = 1.0004
# Epoch : 71  ===> Reconstruction Loss = 17818.0762, Classification Loss = 4.0043
# Epoch : 72  ===> Reconstruction Loss = 17933.7266, Classification Loss = 2.0015
# Epoch : 73  ===> Reconstruction Loss = 17271.2969, Classification Loss = 3.0028
# Epoch : 74  ===> Reconstruction Loss = 18313.0371, Classification Loss = 2.0015
# Epoch : 75  ===> Reconstruction Loss = 18425.1289, Classification Loss = 4.0061
# Epoch : 76  ===> Reconstruction Loss = 18144.2461, Classification Loss = 4.0032
# Epoch : 77  ===> Reconstruction Loss = 17376.4082, Classification Loss = 0.0000
# Epoch : 78  ===> Reconstruction Loss = 18132.1074, Classification Loss = 1.0001
# Epoch : 79  ===> Reconstruction Loss = 17996.4375, Classification Loss = 0.0000
# Epoch : 80  ===> Reconstruction Loss = 18322.7305, Classification Loss = 0.0000
# Epoch : 81  ===> Reconstruction Loss = 18649.5664, Classification Loss = 0.0000
# Epoch : 82  ===> Reconstruction Loss = 17549.7656, Classification Loss = 2.0025
# Epoch : 83  ===> Reconstruction Loss = 17908.5000, Classification Loss = 2.0057
# Epoch : 84  ===> Reconstruction Loss = 18091.5742, Classification Loss = 3.0111
# Epoch : 85  ===> Reconstruction Loss = 18342.0430, Classification Loss = 4.0132
# Epoch : 86  ===> Reconstruction Loss = 17981.7383, Classification Loss = 2.0071
# Epoch : 87  ===> Reconstruction Loss = 17877.4824, Classification Loss = 2.0029
# Epoch : 88  ===> Reconstruction Loss = 17767.4570, Classification Loss = 1.0016
# Epoch : 89  ===> Reconstruction Loss = 17603.3438, Classification Loss = 3.0022
# Epoch : 90  ===> Reconstruction Loss = 18092.5820, Classification Loss = 1.0003
# Epoch : 91  ===> Reconstruction Loss = 17328.7344, Classification Loss = 1.0017
# Epoch : 92  ===> Reconstruction Loss = 18020.0645, Classification Loss = 1.0002
# Epoch : 93  ===> Reconstruction Loss = 17868.2422, Classification Loss = 1.0021
# Epoch : 94  ===> Reconstruction Loss = 17528.7324, Classification Loss = 2.0037
# Epoch : 95  ===> Reconstruction Loss = 17691.8711, Classification Loss = 1.0031
# Epoch : 96  ===> Reconstruction Loss = 18329.7109, Classification Loss = 1.0003
# Epoch : 97  ===> Reconstruction Loss = 18102.9590, Classification Loss = 2.0023
# Epoch : 98  ===> Reconstruction Loss = 17987.1250, Classification Loss = 1.0022
# Epoch : 99  ===> Reconstruction Loss = 17849.7168, Classification Loss = 0.0000
# Epoch : 100  ===> Reconstruction Loss = 18266.0703, Classification Loss = 0.0000
# Epoch : 1  ===> Reconstruction Loss = 20475.3535
# Epoch : 2  ===> Reconstruction Loss = 14702.9414
# Epoch : 3  ===> Reconstruction Loss = 11866.8164
# Epoch : 4  ===> Reconstruction Loss = 10096.5723
# Epoch : 5  ===> Reconstruction Loss = 9156.5098
# Epoch : 6  ===> Reconstruction Loss = 8375.4688
# Epoch : 7  ===> Reconstruction Loss = 7760.5371
# Epoch : 8  ===> Reconstruction Loss = 7514.0220
# Epoch : 9  ===> Reconstruction Loss = 7494.9668
# Epoch : 10  ===> Reconstruction Loss = 7517.2617
# Epoch : 11  ===> Reconstruction Loss = 7612.2363
# Epoch : 12  ===> Reconstruction Loss = 7663.2485
# Epoch : 13  ===> Reconstruction Loss = 7181.8311
# Epoch : 14  ===> Reconstruction Loss = 7102.2051
# Epoch : 15  ===> Reconstruction Loss = 6931.5669
# Epoch : 16  ===> Reconstruction Loss = 7399.4111
# Epoch : 17  ===> Reconstruction Loss = 7327.4570
# Epoch : 18  ===> Reconstruction Loss = 6943.6943
# Epoch : 19  ===> Reconstruction Loss = 7439.6172
# Epoch : 20  ===> Reconstruction Loss = 6854.1479
# Epoch : 21  ===> Reconstruction Loss = 7256.6201
# Epoch : 22  ===> Reconstruction Loss = 7107.1445
# Epoch : 23  ===> Reconstruction Loss = 7361.5098
# Epoch : 24  ===> Reconstruction Loss = 7287.7891
# Epoch : 25  ===> Reconstruction Loss = 7261.9111
# Epoch : 26  ===> Reconstruction Loss = 7251.0518
# Epoch : 27  ===> Reconstruction Loss = 6920.6655
# Epoch : 28  ===> Reconstruction Loss = 7456.5254
# Epoch : 29  ===> Reconstruction Loss = 7463.9414
# Epoch : 30  ===> Reconstruction Loss = 7183.5786
# Epoch : 31  ===> Reconstruction Loss = 7276.2959
# Epoch : 32  ===> Reconstruction Loss = 7233.3442
# Epoch : 33  ===> Reconstruction Loss = 7169.1406
# Epoch : 34  ===> Reconstruction Loss = 6922.9238
# Epoch : 35  ===> Reconstruction Loss = 7426.3652
# Epoch : 36  ===> Reconstruction Loss = 7253.0527
# Epoch : 37  ===> Reconstruction Loss = 6798.2339
# Epoch : 38  ===> Reconstruction Loss = 6999.7158
# Epoch : 39  ===> Reconstruction Loss = 6943.0146
# Epoch : 40  ===> Reconstruction Loss = 7289.1763
# Epoch : 41  ===> Reconstruction Loss = 7066.6680
# Epoch : 42  ===> Reconstruction Loss = 7426.9707
# Epoch : 43  ===> Reconstruction Loss = 7242.5376
# Epoch : 44  ===> Reconstruction Loss = 7208.0059
# Epoch : 45  ===> Reconstruction Loss = 7311.3750
# Epoch : 46  ===> Reconstruction Loss = 7010.4941
# Epoch : 47  ===> Reconstruction Loss = 7099.1045
# Epoch : 48  ===> Reconstruction Loss = 7244.7510
# Epoch : 49  ===> Reconstruction Loss = 7377.7651
# Epoch : 50  ===> Reconstruction Loss = 7110.8584
#     训练时间: 140.69秒, 内存使用: 41.59MB
#     准确率: 1.0000
#
# === 所有批次和折次处理完成 ===
# 结果已保存至: /public/home/yilab5/Master/methodology/result/result_CPM/res-simdata2/cpmnets_cross_validation_results-high.csv
